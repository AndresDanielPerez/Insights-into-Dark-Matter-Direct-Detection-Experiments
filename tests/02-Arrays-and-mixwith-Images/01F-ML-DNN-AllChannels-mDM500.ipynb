# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import gridspec
from matplotlib import patches
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

import os
import math
import random

import keras
from keras.models import Sequential
from keras.layers import Input, Dense, Conv2D, Flatten, MaxPooling2D
from keras.layers import Dropout
from keras.callbacks import EarlyStopping

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn import preprocessing
from sklearn.metrics import roc_curve, roc_auc_score, auc

import scipy.stats as st
from scipy.stats import poisson
from scipy.interpolate import interp1d
from scipy.stats import norm
# Out:
# 2023-05-18 12:58:18.673457: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-18 12:58:19.166973: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-05-18 12:58:20.539091: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/andres/installROOT/lib
# 2023-05-18 12:58:20.539631: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/andres/installROOT/lib
# 2023-05-18 12:58:20.539665: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
from sklearn.neighbors import KernelDensity # paquete necesario
from sklearn.model_selection import GridSearchCV

import scipy.integrate as integrate

# %%
# !pip install xgboost

import xgboost
from xgboost import XGBRegressor, XGBClassifier
# Out:
# Requirement already satisfied: xgboost in /home/andres/anaconda3/lib/python3.9/site-packages (1.7.4)
# Requirement already satisfied: scipy in /home/andres/anaconda3/lib/python3.9/site-packages (from xgboost) (1.10.0)
# Requirement already satisfied: numpy in /home/andres/anaconda3/lib/python3.9/site-packages (from xgboost) (1.23.5)

# %%
import h5py

import glob
import numpy as np
import os.path as path
import imageio
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D
from keras.callbacks import EarlyStopping, TensorBoard
from datetime import datetime
import keras
from keras import regularizers
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score, average_precision_score, precision_recall_curve, auc,recall_score
from keras.optimizers import Adam
from keras.regularizers import l2
import h5py
from sklearn.model_selection import GridSearchCV
from keras.backend import cast, greater, clip, floatx,epsilon
from keras.wrappers.scikit_learn import KerasClassifier
from keras import backend as K
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# ### Load Data

# %%
filefolder = '../../data2024/processed/'

###################
# BACKGROUND FILE #
###################

filename_B = 'ER/ER_all.hdf5'


###############
# SIGNAL FILE #
###############

# select the DM mass
mDM = 500

filename_S = 'mDM' + str(mDM) + 'GeV/WP_mDM' + str(mDM) + 'GeV_sig1045.hdf5'

# %%
# OPEN THE SAVED FILE TO CHECK IT
f_B = h5py.File(filefolder+filename_B,'r')
f_S = h5py.File(filefolder+filename_S,'r')

# show the groups
print( f_B.keys() )

# should be more than 10k events in each group
print('\n Background Events: ')
for groups1 in f_B.keys():
    print(len(f_B[groups1].keys()))

print('\n Signal Events')
for groups1 in f_S.keys():
    print(len(f_S[groups1].keys()))
# Out:
# <KeysViewHDF5 ['HITS_bot', 'HITS_bot_img', 'HITS_top', 'HITS_top_img', 'peakS1_onlyhits', 'peakS1_raw', 'peakS2_onlyhits', 'peakS2_raw']>
#
#  Background Events:
# 17206
# 17206
# 17206
# 17206
# 17206
# 17206
# 17206
# 17206
#
#  Signal Events
# 12286
# 12286
# 12286
# 12286
# 12286
# 12286
# 12286
# 12286

# %%
################
# ALL THE DATA #
################


# to normalize
scaler = preprocessing.MinMaxScaler()

# Number of data points (per-class) for the ML classifier
num_data = 10000


############
# HITS_bot #
############

hits_bot_B = np.array( f_B['HITS_bot/ev_1'] )
hits_bot_S = np.array( f_S['HITS_bot/ev_1'] )

print('hits_bot length: ', len(hits_bot_S))


for i in range(2,num_data+1):
    # add new event to the matrix as a row
    hits_bot_B = np.row_stack([hits_bot_B,np.array( f_B['HITS_bot/ev_'+str(i)] )])
    hits_bot_S = np.row_stack([hits_bot_S,np.array( f_S['HITS_bot/ev_'+str(i)] )])



# X and Y for the classifier
X_hits_bot = np.row_stack([hits_bot_B,hits_bot_S])
# normalize
X_hits_bot = scaler.fit_transform(X_hits_bot)

del hits_bot_B
del hits_bot_S



############
# HITS_top #
############

hits_top_B = np.array( f_B['HITS_top/ev_1'] )
hits_top_S = np.array( f_S['HITS_top/ev_1'] )

print('hits_top length: ', len(hits_top_S))


for i in range(2,num_data+1):
    # add new event to the matrix as a row
    hits_top_B = np.row_stack([hits_top_B,np.array( f_B['HITS_top/ev_'+str(i)] )])
    hits_top_S = np.row_stack([hits_top_S,np.array( f_S['HITS_top/ev_'+str(i)] )])



# X and Y for the classifier
X_hits_top = np.row_stack([hits_top_B,hits_top_S])
# normalize
X_hits_top = scaler.fit_transform(X_hits_top)

del hits_top_B
del hits_top_S



###################
# peakS1_onlyhits #
###################

# First:
# The max len for the time series

max_pS1_B = 0
max_pS1_S = 0

for i in range(1, num_data+1):
    max_pS1_B = max(max_pS1_B, len( f_B['peakS1_onlyhits/ev_'+str(i)] ))
    max_pS1_S = max(max_pS1_S, len( f_S['peakS1_onlyhits/ev_'+str(i)] ))
    
    
max_pS1_both = max(max_pS1_B,max_pS1_S)

print('max_pS1_both lenght: ', max_pS1_both)



# Second:
# add the events in a matrix, but all with the same length -> fill with zeros

# how many elements do we need to make all the peak (S1 or S2) arrays with the same length
diff_elem_S1_B = max_pS1_both - len( f_B['peakS1_onlyhits/ev_1'][()] )
diff_elem_S1_S = max_pS1_both - len( f_S['peakS1_onlyhits/ev_1'][()] )

# add zeros at the end
peakS1_onlyhits_B = np.pad(f_B['peakS1_onlyhits/ev_1'][()], (0, diff_elem_S1_B), 'constant')
peakS1_onlyhits_S = np.pad(f_S['peakS1_onlyhits/ev_1'][()], (0, diff_elem_S1_S), 'constant')

for i in range(2, num_data+1):
    
    # how many elements do we need to make all the peak (S1 or S2) arrays with the same length
    diff_elem_S1_B = max_pS1_both - len( f_B['peakS1_onlyhits/ev_'+str(i)][()] )
    diff_elem_S1_S = max_pS1_both - len( f_S['peakS1_onlyhits/ev_'+str(i)][()] )
    
    # add zeros at the end
    aux_S1_B = np.pad(f_B['peakS1_onlyhits/ev_'+str(i)][()], (0, diff_elem_S1_B), 'constant')
    aux_S1_S = np.pad(f_S['peakS1_onlyhits/ev_'+str(i)][()], (0, diff_elem_S1_S), 'constant')
    
    # add new event to the matrix as a row
    peakS1_onlyhits_B = np.row_stack([peakS1_onlyhits_B,aux_S1_B])
    peakS1_onlyhits_S = np.row_stack([peakS1_onlyhits_S,aux_S1_S])
    
    
    

# X and Y for the classifier
X_peakS1 = np.row_stack([peakS1_onlyhits_B,peakS1_onlyhits_S])
# normalize
X_peakS1 = scaler.fit_transform(X_peakS1)

del peakS1_onlyhits_B
del peakS1_onlyhits_S




###################
# peakS2_onlyhits #
###################

# First:
# The max len for the time series

max_pS2_B = 0
max_pS2_S = 0

for i in range(1, num_data+1):
    max_pS2_B = max(max_pS2_B, len( f_B['peakS2_onlyhits/ev_'+str(i)] ))
    max_pS2_S = max(max_pS2_S, len( f_S['peakS2_onlyhits/ev_'+str(i)] ))
    
    
max_pS2_both = max(max_pS2_B,max_pS2_S)

print('max_pS2_both lenght: ', max_pS2_both)



# Second:
# add the events in a matrix, but all with the same length -> fill with zeros

# how many elements do we need to make all the peak (S2 or S2) arrays with the same length
diff_elem_S2_B = max_pS2_both - len( f_B['peakS2_onlyhits/ev_1'][()] )
diff_elem_S2_S = max_pS2_both - len( f_S['peakS2_onlyhits/ev_1'][()] )

# add zeros at the end
peakS2_onlyhits_B = np.pad(f_B['peakS2_onlyhits/ev_1'][()], (0, diff_elem_S2_B), 'constant')
peakS2_onlyhits_S = np.pad(f_S['peakS2_onlyhits/ev_1'][()], (0, diff_elem_S2_S), 'constant')

for i in range(2, num_data+1):
    
    # how many elements do we need to make all the peak (S2 or S2) arrays with the same length
    diff_elem_S2_B = max_pS2_both - len( f_B['peakS2_onlyhits/ev_'+str(i)][()] )
    diff_elem_S2_S = max_pS2_both - len( f_S['peakS2_onlyhits/ev_'+str(i)][()] )
    
    # add zeros at the end
    aux_S2_B = np.pad(f_B['peakS2_onlyhits/ev_'+str(i)][()], (0, diff_elem_S2_B), 'constant')
    aux_S2_S = np.pad(f_S['peakS2_onlyhits/ev_'+str(i)][()], (0, diff_elem_S2_S), 'constant')
    
    # add new event to the matrix as a row
    peakS2_onlyhits_B = np.row_stack([peakS2_onlyhits_B,aux_S2_B])
    peakS2_onlyhits_S = np.row_stack([peakS2_onlyhits_S,aux_S2_S])
    
    
    

# X and Y for the classifier
X_peakS2 = np.row_stack([peakS2_onlyhits_B,peakS2_onlyhits_S])
# normalize
X_peakS2 = scaler.fit_transform(X_peakS2)

del peakS2_onlyhits_B
del peakS2_onlyhits_S



# close the h5 files
f_B.close()
f_S.close()





###################
# CONCATENATE ALL #
###################

X_mon = np.concatenate([X_hits_bot,X_hits_top,X_peakS1,X_peakS2],axis=1)

del X_hits_bot
del X_hits_top
del X_peakS1
del X_peakS2

# labels
y_mon = np.concatenate([np.zeros(num_data),np.ones(num_data)])


# divide into train-val and test data samples
test_ratio = 1./3
val_ratio = 0.25


X_mon_aux, X_mon_test, y_mon_aux, y_mon_test = train_test_split(X_mon,
                                                                y_mon,
                                                                test_size=test_ratio,
                                                                random_state=42,
                                                                #stratify = y_mon,
                                                                shuffle=True)

del X_mon
del y_mon

X_mon_train, X_mon_val, y_mon_train, y_mon_val = train_test_split(X_mon_aux,
                                                                  y_mon_aux,
                                                                  test_size=val_ratio,
                                                                  random_state=42,
                                                                  #stratify = y_mon_aux,
                                                                  shuffle=True)

del X_mon_aux
del y_mon_aux

print('')
print('X_mon_train : ', X_mon_train.shape)
print('y_mon_train : ', y_mon_train.shape)
print('X_mon_val : ', X_mon_val.shape)
print('y_mon_val : ', y_mon_val.shape)
print('X_mon_test : ', X_mon_test.shape)
print('y_mon_test : ', y_mon_test.shape)
print('')
# Out:
# hits_bot length:  121
# hits_top length:  127
# max_pS1_both lenght:  168
# max_pS2_both lenght:  2244
#
# X_mon_train :  (9999, 2660)
# y_mon_train :  (9999,)
# X_mon_val :  (3334, 2660)
# y_mon_val :  (3334,)
# X_mon_test :  (6667, 2660)
# y_mon_test :  (6667,)

# %% [markdown]
# ### CLASSIFIER

# %%
X_mon_train.shape[1]
# Out:
# 2660

# %%
#######
# DNN #
#######

n_features = X_mon_train.shape[1]

model = Sequential()
model.add(Dense(256, activation='relu', input_dim=n_features))
model.add(Dropout(0.20))
model.add(Dense(128, activation='relu', input_dim=n_features))
model.add(Dropout(0.20))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.20))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.20))
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.20))
model.add(Dense(1, activation='sigmoid'))



model.summary()



# to stop the training if validation loss does not improve after patience number of epochs
stop_training = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=300, restore_best_weights=True)

model.compile(optimizer='adam',loss='binary_crossentropy', metrics=['accuracy'])


batch_size = 128
tot_epochs = 1500


# Entrenamos el modelo
history = model.fit(X_mon_train,
                    y_mon_train,
                    batch_size=batch_size,
                    epochs=tot_epochs,
                    callbacks=[stop_training],
                    verbose=1,
                    validation_data=(X_mon_val, y_mon_val),
                    shuffle=True)


# Plot de la cost function para la train y test data
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.legend(['train', 'test'], loc='upper left')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# Plot de la accuracy function para la train y test data
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()





#model.save(root_dir + 'CNN-histo-mix-v2/saved-models/' + 'DNN-' + nameMIX_linear +'.h5') # Guardar el modelo.  # Predicción de la red entrenada
y_pred_DNN = model.predict(X_mon_test)

# Compute ROC curve and ROC area for each class
fpr_DNN = dict()
tpr_DNN = dict()
roc_auc_DNN = dict()
fpr_DNN, tpr_DNN, _ = roc_curve(y_mon_test, y_pred_DNN)
roc_auc_DNN = auc(fpr_DNN, tpr_DNN)


plt.figure()
plt.plot(tpr_DNN,1-fpr_DNN,label="$f_{1}$, AUC = %0.2f" % roc_auc_DNN,color="orange",ls=":",lw=4)
plt.plot([1,0],[0,1],ls=":",color="grey")
plt.xlabel("True Positive Rate",fontsize=16)
plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
plt.legend()
plt.xlim([0,1])
plt.ylim([0,1])
plt.yticks([0.2,0.4,0.6,0.8,1.])
plt.legend(frameon=False,fontsize=16)
plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 256)               681216
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 32)                2080
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  dense_9 (Dense)             (None, 16)                528
#
#  dropout_8 (Dropout)         (None, 16)                0
#
#  dense_10 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 724,993
# Trainable params: 724,993
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1500
# 79/79 [==============================] - 1s 6ms/step - loss: 0.4363 - accuracy: 0.8009 - val_loss: 0.3396 - val_accuracy: 0.8617
# Epoch 2/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.3392 - accuracy: 0.8659 - val_loss: 0.3551 - val_accuracy: 0.8308
# Epoch 3/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.3198 - accuracy: 0.8715 - val_loss: 0.2870 - val_accuracy: 0.8785
# Epoch 4/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.3092 - accuracy: 0.8796 - val_loss: 0.3136 - val_accuracy: 0.8698
# Epoch 5/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.2902 - accuracy: 0.8842 - val_loss: 0.2824 - val_accuracy: 0.8830
# Epoch 6/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2834 - accuracy: 0.8923 - val_loss: 0.2644 - val_accuracy: 0.8890
# Epoch 7/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2820 - accuracy: 0.8889 - val_loss: 0.2757 - val_accuracy: 0.8902
# Epoch 8/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.2633 - accuracy: 0.8979 - val_loss: 0.2592 - val_accuracy: 0.8938
# Epoch 9/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2629 - accuracy: 0.8970 - val_loss: 0.2665 - val_accuracy: 0.8902
# Epoch 10/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2516 - accuracy: 0.9017 - val_loss: 0.2725 - val_accuracy: 0.8815
# Epoch 11/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2476 - accuracy: 0.9062 - val_loss: 0.2541 - val_accuracy: 0.8980
# Epoch 12/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2316 - accuracy: 0.9107 - val_loss: 0.2602 - val_accuracy: 0.8932
# Epoch 13/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.2415 - accuracy: 0.9088 - val_loss: 0.2762 - val_accuracy: 0.8875
# Epoch 14/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2350 - accuracy: 0.9095 - val_loss: 0.2578 - val_accuracy: 0.8923
# Epoch 15/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2254 - accuracy: 0.9122 - val_loss: 0.2862 - val_accuracy: 0.8767
# Epoch 16/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.2249 - accuracy: 0.9144 - val_loss: 0.2604 - val_accuracy: 0.8938
# Epoch 17/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2197 - accuracy: 0.9171 - val_loss: 0.2591 - val_accuracy: 0.8965
# Epoch 18/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.2164 - accuracy: 0.9155 - val_loss: 0.2840 - val_accuracy: 0.8887
# Epoch 19/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.2100 - accuracy: 0.9200 - val_loss: 0.2978 - val_accuracy: 0.8860
# Epoch 20/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2023 - accuracy: 0.9237 - val_loss: 0.2836 - val_accuracy: 0.8827
# Epoch 21/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.2177 - accuracy: 0.9180 - val_loss: 0.2898 - val_accuracy: 0.8935
# Epoch 22/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.2000 - accuracy: 0.9247 - val_loss: 0.2965 - val_accuracy: 0.8905
# Epoch 23/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.2078 - accuracy: 0.9221 - val_loss: 0.2729 - val_accuracy: 0.8869
# Epoch 24/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.1934 - accuracy: 0.9268 - val_loss: 0.3143 - val_accuracy: 0.8677
# Epoch 25/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1901 - accuracy: 0.9284 - val_loss: 0.3242 - val_accuracy: 0.8821
# Epoch 26/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1931 - accuracy: 0.9275 - val_loss: 0.2999 - val_accuracy: 0.8851
# Epoch 27/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.1960 - accuracy: 0.9267 - val_loss: 0.2930 - val_accuracy: 0.8893
# Epoch 28/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1809 - accuracy: 0.9330 - val_loss: 0.2967 - val_accuracy: 0.8878
# Epoch 29/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1963 - accuracy: 0.9231 - val_loss: 0.3055 - val_accuracy: 0.8938
# Epoch 30/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.1934 - accuracy: 0.9245 - val_loss: 0.3097 - val_accuracy: 0.8872
# Epoch 31/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1866 - accuracy: 0.9314 - val_loss: 0.3248 - val_accuracy: 0.8815
# Epoch 32/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.2029 - accuracy: 0.9228 - val_loss: 0.3164 - val_accuracy: 0.8845
# Epoch 33/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.1918 - accuracy: 0.9287 - val_loss: 0.3113 - val_accuracy: 0.8869
# Epoch 34/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1727 - accuracy: 0.9364 - val_loss: 0.3320 - val_accuracy: 0.8791
# Epoch 35/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.1723 - accuracy: 0.9381 - val_loss: 0.3074 - val_accuracy: 0.8821
# Epoch 36/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1709 - accuracy: 0.9372 - val_loss: 0.3366 - val_accuracy: 0.8851
# Epoch 37/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1691 - accuracy: 0.9368 - val_loss: 0.3396 - val_accuracy: 0.8866
# Epoch 38/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.1797 - accuracy: 0.9306 - val_loss: 0.3220 - val_accuracy: 0.8872
# Epoch 39/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1686 - accuracy: 0.9377 - val_loss: 0.3221 - val_accuracy: 0.8854
# Epoch 40/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1587 - accuracy: 0.9412 - val_loss: 0.3345 - val_accuracy: 0.8857
# Epoch 41/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.1714 - accuracy: 0.9334 - val_loss: 0.3476 - val_accuracy: 0.8794
# Epoch 42/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1561 - accuracy: 0.9396 - val_loss: 0.3518 - val_accuracy: 0.8659
# Epoch 43/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1595 - accuracy: 0.9406 - val_loss: 0.3490 - val_accuracy: 0.8875
# Epoch 44/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.1595 - accuracy: 0.9380 - val_loss: 0.3481 - val_accuracy: 0.8872
# Epoch 45/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1554 - accuracy: 0.9421 - val_loss: 0.3607 - val_accuracy: 0.8890
# Epoch 46/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1625 - accuracy: 0.9369 - val_loss: 0.3273 - val_accuracy: 0.8872
# Epoch 47/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.1549 - accuracy: 0.9414 - val_loss: 0.3832 - val_accuracy: 0.8662
# Epoch 48/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1636 - accuracy: 0.9370 - val_loss: 0.3477 - val_accuracy: 0.8869
# Epoch 49/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.1504 - accuracy: 0.9410 - val_loss: 0.3843 - val_accuracy: 0.8827
# Epoch 50/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.1604 - accuracy: 0.9409 - val_loss: 0.3646 - val_accuracy: 0.8812
# Epoch 51/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1505 - accuracy: 0.9448 - val_loss: 0.3567 - val_accuracy: 0.8884
# Epoch 52/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1405 - accuracy: 0.9487 - val_loss: 0.3844 - val_accuracy: 0.8773
# Epoch 53/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1469 - accuracy: 0.9450 - val_loss: 0.3682 - val_accuracy: 0.8842
# Epoch 54/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1430 - accuracy: 0.9461 - val_loss: 0.3463 - val_accuracy: 0.8842
# Epoch 55/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.1582 - accuracy: 0.9390 - val_loss: 0.3659 - val_accuracy: 0.8767
# Epoch 56/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1468 - accuracy: 0.9469 - val_loss: 0.3632 - val_accuracy: 0.8845
# Epoch 57/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1364 - accuracy: 0.9497 - val_loss: 0.3831 - val_accuracy: 0.8821
# Epoch 58/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0
1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0984 - accuracy: 0.9630 - val_loss: 0.4599 - val_accuracy: 0.8722
# Epoch 179/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0900 - accuracy: 0.9651 - val_loss: 0.5027 - val_accuracy: 0.8800
# Epoch 180/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0938 - accuracy: 0.9638 - val_loss: 0.4483 - val_accuracy: 0.8767
# Epoch 181/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0786 - accuracy: 0.9691 - val_loss: 0.5185 - val_accuracy: 0.8710
# Epoch 182/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0786 - accuracy: 0.9688 - val_loss: 0.5639 - val_accuracy: 0.8734
# Epoch 183/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0938 - accuracy: 0.9606 - val_loss: 0.4344 - val_accuracy: 0.8758
# Epoch 184/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1043 - accuracy: 0.9566 - val_loss: 0.4714 - val_accuracy: 0.8779
# Epoch 185/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0983 - accuracy: 0.9604 - val_loss: 0.4849 - val_accuracy: 0.8776
# Epoch 186/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0891 - accuracy: 0.9623 - val_loss: 0.6006 - val_accuracy: 0.8578
# Epoch 187/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1125 - accuracy: 0.9558 - val_loss: 0.5350 - val_accuracy: 0.8794
# Epoch 188/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0904 - accuracy: 0.9655 - val_loss: 0.5447 - val_accuracy: 0.8791
# Epoch 189/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1034 - accuracy: 0.9592 - val_loss: 0.4757 - val_accuracy: 0.8608
# Epoch 190/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0853 - accuracy: 0.9636 - val_loss: 0.4544 - val_accuracy: 0.8767
# Epoch 191/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0806 - accuracy: 0.9708 - val_loss: 0.5389 - val_accuracy: 0.8662
# Epoch 192/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0776 - accuracy: 0.9659 - val_loss: 0.5184 - val_accuracy: 0.8773
# Epoch 193/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0830 - accuracy: 0.9627 - val_loss: 0.5264 - val_accuracy: 0.8755
# Epoch 194/1500
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0799 - accuracy: 0.9647 - val_loss: 0.5179 - val_accuracy: 0.8761
# Epoch 195/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0922 - accuracy: 0.9621 - val_loss: 0.4785 - val_accuracy: 0.8779
# Epoch 196/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0921 - accuracy: 0.9642 - val_loss: 0.5518 - val_accuracy: 0.8731
# Epoch 197/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0967 - accuracy: 0.9634 - val_loss: 0.5083 - val_accuracy: 0.8746
# Epoch 198/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0822 - accuracy: 0.9672 - val_loss: 0.5378 - val_accuracy: 0.8683
# Epoch 199/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0728 - accuracy: 0.9733 - val_loss: 0.5346 - val_accuracy: 0.8707
# Epoch 200/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0749 - accuracy: 0.9699 - val_loss: 0.5309 - val_accuracy: 0.8704
# Epoch 201/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0943 - accuracy: 0.9612 - val_loss: 0.4815 - val_accuracy: 0.8665
# Epoch 202/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0892 - accuracy: 0.9669 - val_loss: 0.5466 - val_accuracy: 0.8764
# Epoch 203/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0761 - accuracy: 0.9720 - val_loss: 0.6082 - val_accuracy: 0.8683
# Epoch 204/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0765 - accuracy: 0.9699 - val_loss: 0.5636 - val_accuracy: 0.8764
# Epoch 205/1500
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0882 - accuracy: 0.9653 - val_loss: 0.4868 - val_accuracy: 0.8764
# Epoch 206/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0622 - accuracy: 0.9754 - val_loss: 0.5523 - val_accuracy: 0.8746
# Epoch 207/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0758 - accuracy: 0.9700 - val_loss: 0.5939 - val_accuracy: 0.8722
# Epoch 208/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0866 - accuracy: 0.9680 - val_loss: 0.4618 - val_accuracy: 0.8785
# Epoch 209/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0920 - accuracy: 0.9649 - val_loss: 0.4655 - val_accuracy: 0.8755
# Epoch 210/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0944 - accuracy: 0.9650 - val_loss: 0.4704 - val_accuracy: 0.8752
# Epoch 211/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0843 - accuracy: 0.9666 - val_loss: 0.5479 - val_accuracy: 0.8704
# Epoch 212/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0756 - accuracy: 0.9695 - val_loss: 0.6042 - val_accuracy: 0.8695
# Epoch 213/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0698 - accuracy: 0.9739 - val_loss: 0.6028 - val_accuracy: 0.8719
# Epoch 214/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0810 - accuracy: 0.9664 - val_loss: 0.5484 - val_accuracy: 0.8791
# Epoch 215/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0683 - accuracy: 0.9728 - val_loss: 0.5459 - val_accuracy: 0.8743
# Epoch 216/1500
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0664 - accuracy: 0.9726 - val_loss: 0.6675 - val_accuracy: 0.8755
# Epoch 217/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0718 - accuracy: 0.9702 - val_loss: 0.5767 - val_accuracy: 0.8782
# Epoch 218/1500
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0748 - accuracy: 0.9711 - val_loss: 0.5613 - val_accuracy: 0.8776
# Epoch 219/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0797 - accuracy: 0.9701 - val_loss: 0.5902 - val_accuracy: 0.8731
# Epoch 220/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0654 - accuracy: 0.9748 - val_loss: 0.5958 - val_accuracy: 0.8713
# Epoch 221/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0709 - accuracy: 0.9705 - val_loss: 0.6584 - val_accuracy: 0.8740
# Epoch 222/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0715 - accuracy: 0.9710 - val_loss: 0.5226 - val_accuracy: 0.8749
# Epoch 223/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0858 - accuracy: 0.9670 - val_loss: 0.4754 - val_accuracy: 0.8758
# Epoch 224/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0900 - accuracy: 0.9669 - val_loss: 0.5082 - val_accuracy: 0.8803
# Epoch 225/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0789 - accuracy: 0.9707 - val_loss: 0.5525 - val_accuracy: 0.8737
# Epoch 226/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0831 - accuracy: 0.9709 - val_loss: 0.5236 - val_accuracy: 0.8641
# Epoch 227/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0832 - accuracy: 0.9704 - val_loss: 0.5884 - val_accuracy: 0.8695
# Epoch 228/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0777 - accuracy: 0.9712 - val_loss: 0.5455 - val_accuracy: 0.8689
# Epoch 229/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0837 - accuracy: 0.9704 - val_loss: 0.4806 - val_accuracy: 0.8764
# Epoch 230/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0754 - accuracy: 0.9736 - val_loss: 0.6655 - val_accuracy: 0.8692
# Epoch 231/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0811 - accuracy: 0.9694 - val_loss: 0.5451 - val_accuracy: 0.8734
# Epoch 232/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0726 - accuracy: 0.9734 - val_loss: 0.5873 - val_accuracy: 0.8743
# Epoch 233/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0791 - accuracy: 0.9692 - val_loss: 0.5284 - val_accuracy: 0.8707
# Epoch 234/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0616 - accuracy: 0.9762 - val_loss: 0.6168 - val_accuracy: 0.8761
# Epoch 235/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0630 - accuracy: 0.9750 - val_loss: 0.6645 - val_accuracy: 0.8734
# Epoch 236/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0683 - accuracy: 0.9742 - val_loss: 0.5046 - val_accuracy: 0.8719
# Epoch 237/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0713 - accuracy: 0.9737 - val_loss: 0.5396 - val_accuracy: 0.8653
# Epoch 238/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0762 - accuracy: 0.9717 - val_loss: 0.5145 - val_accuracy: 0.8794
# Epoch 239/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0696 - accuracy: 0.9742 - val_loss: 0.5817 - val_accuracy: 0.8764
# Epoch 240/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0747 - accuracy: 0.9688 - val_loss: 0.6029 - val_accuracy: 0.8755
# Epoch 241/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0610 - accuracy: 0.9774 - val_loss: 0.6318 - val_accuracy: 0.8719
# Epoch 242/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0609 - accuracy: 0.9761 - val_loss: 0.6236 - val_accuracy: 0.8779
# Epoch 243/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0880 - accuracy: 0.9671 - val_loss: 0.4985 - val_accuracy: 0.8752
# Epoch 244/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0689 - accuracy: 0.9747 - val_loss: 0.5725 - val_accuracy: 0.8707
# Epoch 245/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0781 - accuracy: 0.9713 - val_loss: 0.6415 - val_accuracy: 0.8719
# Epoch 246/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0828 - accuracy: 0.9685 - val_loss: 0.5153 - val_accuracy: 0.8695
# Epoch 247/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0777 - accuracy: 0.9729 - val_loss: 0.5409 - val_accuracy: 0.8779
# Epoch 248/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0894 - accuracy: 0.9666 - val_loss: 0.4716 - val_accuracy: 0.8794
# Epoch 249/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0860 - accuracy: 0.9676 - val_loss: 0.5227 - val_accuracy: 0.8662
# Epoch 250/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0837 - accuracy: 0.9671 - val_loss: 0.6093 - val_accuracy: 0.8734
# Epoch 251/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0757 - accuracy: 0.9695 - val_loss: 0.5870 - val_accuracy: 0.8737
# Epoch 252/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0955 - accuracy: 0.9645 - val_loss: 0.5299 - val_accuracy: 0.8740
# Epoch 253/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0860 - accuracy: 0.9681 - val_loss: 0.5109 - val_accuracy: 0.8752
# Epoch 254/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0780 - accuracy: 0.9719 - val_loss: 0.5459 - val_accuracy: 0.8710
# Epoch 255/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0821 - accuracy: 0.9710 - val_loss: 0.5242 - val_accuracy: 0.8761
# Epoch 256/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0804 - accuracy: 0.9684 - val_loss: 0.6104 - val_accuracy: 0.8707
# Epoch 257/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0807 - accuracy: 0.9695 - val_loss: 0.5129 - val_accuracy: 0.8695
# Epoch 258/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0967 - accuracy: 0.9633 - val_loss: 0.5803 - val_accuracy: 0.8686
# Epoch 259/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0806 - accuracy: 0.9723 - val_loss: 0.5738 - val_accuracy: 0.8716
# Epoch 260/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0925 - accuracy: 0.9647 - val_loss: 0.5608 - val_accuracy: 0.8698
# Epoch 261/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0835 - accuracy: 0.9684 - val_loss: 0.4479 - val_accuracy: 0.8779
# Epoch 262/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0698 - accuracy: 0.9743 - val_loss: 0.6042 - val_accuracy: 0.8737
# Epoch 263/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0771 - accuracy: 0.9712 - val_loss: 0.5326 - val_accuracy: 0.8755
# Epoch 264/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0833 - accuracy: 0.9669 - val_loss: 0.5034 - val_accuracy: 0.8698
# Epoch 265/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0957 - accuracy: 0.9658 - val_loss: 0.5755 - val_accuracy: 0.8764
# Epoch 266/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0871 - accuracy: 0.9673 - val_loss: 0.5285 - val_accuracy: 0.8785
# Epoch 267/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0943 - accuracy: 0.9666 - val_loss: 0.5596 - val_accuracy: 0.8755
# Epoch 268/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0717 - accuracy: 0.9728 - val_loss: 0.5326 - val_accuracy: 0.8656
# Epoch 269/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0969 - accuracy: 0.9644 - val_loss: 0.5173 - val_accuracy: 0.8605
# Epoch 270/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1171 - accuracy: 0.9592 - val_loss: 0.4923 - val_accuracy: 0.8719
# Epoch 271/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0813 - accuracy: 0.9714 - val_loss: 0.5491 - val_accuracy: 0.8719
# Epoch 272/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0881 - accuracy: 0.9673 - val_loss: 0.5983 - val_accuracy: 0.8749
# Epoch 273/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0849 - accuracy: 0.9701 - val_loss: 0.5792 - val_accuracy: 0.8692
# Epoch 274/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0706 - accuracy: 0.9765 - val_loss: 0.5310 - val_accuracy: 0.8707
# Epoch 275/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0792 - accuracy: 0.9715 - val_loss: 0.5352 - val_accuracy: 0.8737
# Epoch 276/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0697 - accuracy: 0.9755 - val_loss: 0.5690 - val_accuracy: 0.8632
# Epoch 277/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0741 - accuracy: 0.9730 - val_loss: 0.6740 - val_accuracy: 0.8695
# Epoch 278/1500
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0652 - accuracy: 0.9758 - val_loss: 0.6225 - val_accuracy: 0.8749
# Epoch 279/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0672 - accuracy: 0.9752 - val_loss: 0.5964 - val_accuracy: 0.8722
# Epoch 280/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0607 - accuracy: 0.9779 - val_loss: 0.6840 - val_accuracy: 0.8731
# Epoch 281/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0875 - accuracy: 0.9673 - val_loss: 0.6010 - val_accuracy: 0.8716
# Epoch 282/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0737 - accuracy: 0.9700 - val_loss: 0.5683 - val_accuracy: 0.8725
# Epoch 283/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0799 - accuracy: 0.9670 - val_loss: 0.5329 - val_accuracy: 0.8701
# Epoch 284/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0940 - accuracy: 0.9614 - val_loss: 0.6455 - val_accuracy: 0.8779
# Epoch 285/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0605 - accuracy: 0.9763 - val_loss: 0.6925 - val_accuracy: 0.8752
# Epoch 286/1500
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0676 - accuracy: 0.9760 - val_loss: 0.5664 - val_accuracy: 0.8710
# Epoch 287/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0766 - accuracy: 0.9731 - val_loss: 0.6918 - val_accuracy: 0.8701
# Epoch 288/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0829 - accuracy: 0.9642 - val_loss: 0.5340 - val_accuracy: 0.8716
# Epoch 289/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0857 - accuracy: 0.9629 - val_loss: 0.5020 - val_accuracy: 0.8701
# Epoch 290/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0825 - accuracy: 0.9649 - val_loss: 0.6169 - val_accuracy: 0.8713
# Epoch 291/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0841 - accuracy: 0.9666 - val_loss: 0.5931 - val_accuracy: 0.8623
# Epoch 292/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1007 - accuracy: 0.9609 - val_loss: 0.5313 - val_accuracy: 0.8704
# Epoch 293/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0793 - accuracy: 0.9684 - val_loss: 0.6332 - val_accuracy: 0.8677
# Epoch 294/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0688 - accuracy: 0.9754 - val_loss: 0.5795 - val_accuracy: 0.8776
# Epoch 295/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0659 - accuracy: 0.9757 - val_loss: 0.5847 - val_accuracy: 0.8704
# Epoch 296/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0825 - accuracy: 0.9678 - val_loss: 0.6286 - val_accuracy: 0.8695
# Epoch 297/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0852 - accuracy: 0.9697 - val_loss: 0.5545 - val_accuracy: 0.8716
# Epoch 298/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0822 - accuracy: 0.9716 - val_loss: 0.5850 - val_accuracy: 0.8713
# Epoch 299/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0774 - accuracy: 0.9708 - val_loss: 0.5757 - val_accuracy: 0.8659
# Epoch 300/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.1137 - accuracy: 0.9557 - val_loss: 0.4419 - val_accuracy: 0.8731
# Epoch 301/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0827 - accuracy: 0.9687 - val_loss: 0.5740 - val_accuracy: 0.8725
# Epoch 302/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0642 - accuracy: 0.9759 - val_loss: 0.6593 - val_accuracy: 0.8629
# Epoch 303/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0756 - accuracy: 0.9685 - val_loss: 0.7370 - val_accuracy: 0.8734
# Epoch 304/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0796 - accuracy: 0.9710 - val_loss: 0.6559 - val_accuracy: 0.8665
# Epoch 305/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0763 - accuracy: 0.9701 - val_loss: 0.5738 - val_accuracy: 0.8758
# Epoch 306/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0686 - accuracy: 0.9735 - val_loss: 0.5994 - val_accuracy: 0.8734
# Epoch 307/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0791 - accuracy: 0.9707 - val_loss: 0.5555 - val_accuracy: 0.8722
# Epoch 308/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0795 - accuracy: 0.9694 - val_loss: 0.5685 - val_accuracy: 0.8710
# Epoch 309/1500
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0757 - accuracy: 0.9704 - val_loss: 0.5687 - val_accuracy: 0.8644
# Epoch 310/1500
# 79/79 [==============================] - 0s 4ms/step - loss: 0.0605 - accuracy: 0.9778 - val_loss: 0.6819 - val_accuracy: 0.8719
# Epoch 311/1500
# 77/79 [============================>.] - ETA: 0s - loss: 0.0821 - accuracy: 0.9669Restoring model weights from the end of the best epoch: 11.
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0819 - accuracy: 0.9669 - val_loss: 0.6418 - val_accuracy: 0.8698
# Epoch 311: early stopping
# 209/209 [==============================] - 0s 613us/step

# %%
roc_auc_DNN
# Out:
# 0.9583712889241671

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import auc, precision_recall_curve

precision_DNN, recall_DNN, _ = precision_recall_curve(y_mon_test, y_pred_DNN)
auc_DNN = auc(recall_DNN, precision_DNN)

plt.figure(figsize=(6, 6))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.plot(recall_DNN, precision_DNN, label=f'AP (DNNBoost) = {auc_DNN:.2f}')
plt.title('Precision-Recall Curve', size=16)
plt.xlabel('Recall', size=16)
plt.ylabel('Precision', size=16)
plt.legend(frameon=False,fontsize=16)
plt.show()

# %%
auc_DNN
# Out:
# 0.9466855055593307

# %%
# DNN with the kinematic variables of the leptons

########################
# CLASSIFICATION SCORE #
########################

# Outputs for validation data set

pred_DNN_SM = []
pred_DNN_NP = []

for i in range(len(y_mon_test)):
    if y_mon_test[i] == 0:
        pred_DNN_SM.append(y_pred_DNN[i,0])
    else:
        pred_DNN_NP.append(y_pred_DNN[i,0])
        
        
print('Classification score:')
        
weights = np.ones_like(pred_DNN_SM)/float(len(pred_DNN_SM))
nSM, binsSM, patchesSM = plt.hist(pred_DNN_SM, 50, weights=weights, range=[0,1], histtype='step', color='firebrick', linewidth=2, label='Background')

weights = np.ones_like(pred_DNN_NP)/float(len(pred_DNN_NP))
nNP, binsNP, patchesNP = plt.hist(pred_DNN_NP, 50, weights=weights, range=[0,1], histtype='step', color='forestgreen', linewidth=2, label='Signal')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Classication score (DNN)",fontsize=15)
plt.ylabel("Fraction of events",fontsize=14)
plt.grid()
plt.legend(fontsize=12)

plt.show()
# Out:
# Classification score:
