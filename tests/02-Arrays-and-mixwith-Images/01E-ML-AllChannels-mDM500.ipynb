# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import gridspec
from matplotlib import patches
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

import os
import math
import random

import keras
from keras.models import Sequential
from keras.layers import Input, Dense, Conv2D, Flatten, MaxPooling2D
from keras.layers import Dropout
from keras.callbacks import EarlyStopping

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn import preprocessing
from sklearn.metrics import roc_curve, roc_auc_score, auc

import scipy.stats as st
from scipy.stats import poisson
from scipy.interpolate import interp1d
from scipy.stats import norm

# %%
from sklearn.neighbors import KernelDensity # paquete necesario
from sklearn.model_selection import GridSearchCV

import scipy.integrate as integrate

# %%
# !pip install xgboost

import xgboost
from xgboost import XGBRegressor, XGBClassifier
# Out:
# Requirement already satisfied: xgboost in /home/andres/anaconda3/lib/python3.8/site-packages (1.5.1)
# Requirement already satisfied: scipy in /home/andres/.local/lib/python3.8/site-packages (from xgboost) (1.9.3)
# Requirement already satisfied: numpy in /home/andres/.local/lib/python3.8/site-packages (from xgboost) (1.22.4)
# WARNING: You are using pip version 21.3.1; however, version 23.3.1 is available.
# You should consider upgrading via the '/home/andres/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import h5py

import glob
import numpy as np
import os.path as path
import imageio
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D
from keras.callbacks import EarlyStopping, TensorBoard
from datetime import datetime
import keras
from keras import regularizers
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score, average_precision_score, precision_recall_curve, auc,recall_score
#from keras.optimizers import Adam
from keras.regularizers import l2
import h5py
from sklearn.model_selection import GridSearchCV
from keras.backend import cast, greater, clip, floatx,epsilon
from keras.wrappers.scikit_learn import KerasClassifier
from keras import backend as K
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# ### Load Data

# %%
filefolder = '../../data2024/processed/'

###################
# BACKGROUND FILE #
###################

filename_B = 'ER/ER_all.hdf5'


###############
# SIGNAL FILE #
###############

# select the DM mass
mDM = 500

filename_S = 'mDM' + str(mDM) + 'GeV/WP_mDM' + str(mDM) + 'GeV_sig1045.hdf5'

# %%
# OPEN THE SAVED FILE TO CHECK IT
f_B = h5py.File(filefolder+filename_B,'r')
f_S = h5py.File(filefolder+filename_S,'r')

# show the groups
print( f_B.keys() )

# should be more than 10k events in each group
print('\n Background Events: ')
for groups1 in f_B.keys():
    print(len(f_B[groups1].keys()))

print('\n Signal Events')
for groups1 in f_S.keys():
    print(len(f_S[groups1].keys()))
# Out:
# <KeysViewHDF5 ['HITS_bot', 'HITS_bot_img', 'HITS_top', 'HITS_top_img', 'peakS1_onlyhits', 'peakS1_raw', 'peakS2_onlyhits', 'peakS2_raw']>
#
#  Background Events:
# 21375
# 21375
# 21375
# 21375
# 21375
# 21375
# 21375
# 21375
#
#  Signal Events
# 18407
# 18407
# 18407
# 18407
# 18407
# 18407
# 18407
# 18407

# %%
################
# ALL THE DATA #
################


# to normalize
scaler = preprocessing.MinMaxScaler()

# Number of data points (per-class) for the ML classifier
num_data = 20000
# num_data = 10000


############
# HITS_bot #
############

hits_bot_B = np.array( f_B['HITS_bot/ev_1'] )
hits_bot_S = np.array( f_S['HITS_bot/ev_1'] )

print('hits_bot length: ', len(hits_bot_S))


for i in range(2,num_data+1):
    # add new event to the matrix as a row
    hits_bot_B = np.row_stack([hits_bot_B,np.array( f_B['HITS_bot/ev_'+str(i)] )])
    hits_bot_S = np.row_stack([hits_bot_S,np.array( f_S['HITS_bot/ev_'+str(i)] )])



# X and Y for the classifier
X_hits_bot = np.row_stack([hits_bot_B,hits_bot_S])
# normalize
X_hits_bot = scaler.fit_transform(X_hits_bot)

del hits_bot_B
del hits_bot_S



############
# HITS_top #
############

hits_top_B = np.array( f_B['HITS_top/ev_1'] )
hits_top_S = np.array( f_S['HITS_top/ev_1'] )

print('hits_top length: ', len(hits_top_S))


for i in range(2,num_data+1):
    # add new event to the matrix as a row
    hits_top_B = np.row_stack([hits_top_B,np.array( f_B['HITS_top/ev_'+str(i)] )])
    hits_top_S = np.row_stack([hits_top_S,np.array( f_S['HITS_top/ev_'+str(i)] )])



# X and Y for the classifier
X_hits_top = np.row_stack([hits_top_B,hits_top_S])
# normalize
X_hits_top = scaler.fit_transform(X_hits_top)

del hits_top_B
del hits_top_S



###################
# peakS1_onlyhits #
###################

# First:
# The max len for the time series

max_pS1_B = 0
max_pS1_S = 0

for i in range(1, num_data+1):
    max_pS1_B = max(max_pS1_B, len( f_B['peakS1_onlyhits/ev_'+str(i)] ))
    max_pS1_S = max(max_pS1_S, len( f_S['peakS1_onlyhits/ev_'+str(i)] ))
    
    
max_pS1_both = max(max_pS1_B,max_pS1_S)

print('max_pS1_both lenght: ', max_pS1_both)



# Second:
# add the events in a matrix, but all with the same length -> fill with zeros

# how many elements do we need to make all the peak (S1 or S2) arrays with the same length
diff_elem_S1_B = max_pS1_both - len( f_B['peakS1_onlyhits/ev_1'][()] )
diff_elem_S1_S = max_pS1_both - len( f_S['peakS1_onlyhits/ev_1'][()] )

# add zeros at the end
peakS1_onlyhits_B = np.pad(f_B['peakS1_onlyhits/ev_1'][()], (0, diff_elem_S1_B), 'constant')
peakS1_onlyhits_S = np.pad(f_S['peakS1_onlyhits/ev_1'][()], (0, diff_elem_S1_S), 'constant')

for i in range(2, num_data+1):
    
    # how many elements do we need to make all the peak (S1 or S2) arrays with the same length
    diff_elem_S1_B = max_pS1_both - len( f_B['peakS1_onlyhits/ev_'+str(i)][()] )
    diff_elem_S1_S = max_pS1_both - len( f_S['peakS1_onlyhits/ev_'+str(i)][()] )
    
    # add zeros at the end
    aux_S1_B = np.pad(f_B['peakS1_onlyhits/ev_'+str(i)][()], (0, diff_elem_S1_B), 'constant')
    aux_S1_S = np.pad(f_S['peakS1_onlyhits/ev_'+str(i)][()], (0, diff_elem_S1_S), 'constant')
    
    # add new event to the matrix as a row
    peakS1_onlyhits_B = np.row_stack([peakS1_onlyhits_B,aux_S1_B])
    peakS1_onlyhits_S = np.row_stack([peakS1_onlyhits_S,aux_S1_S])
    
    
    

# X and Y for the classifier
X_peakS1 = np.row_stack([peakS1_onlyhits_B,peakS1_onlyhits_S])
# normalize
X_peakS1 = scaler.fit_transform(X_peakS1)

del peakS1_onlyhits_B
del peakS1_onlyhits_S




###################
# peakS2_onlyhits #
###################

# First:
# The max len for the time series

max_pS2_B = 0
max_pS2_S = 0

for i in range(1, num_data+1):
    max_pS2_B = max(max_pS2_B, len( f_B['peakS2_onlyhits/ev_'+str(i)] ))
    max_pS2_S = max(max_pS2_S, len( f_S['peakS2_onlyhits/ev_'+str(i)] ))
    
    
max_pS2_both = max(max_pS2_B,max_pS2_S)

print('max_pS2_both lenght: ', max_pS2_both)



# Second:
# add the events in a matrix, but all with the same length -> fill with zeros

# how many elements do we need to make all the peak (S2 or S2) arrays with the same length
diff_elem_S2_B = max_pS2_both - len( f_B['peakS2_onlyhits/ev_1'][()] )
diff_elem_S2_S = max_pS2_both - len( f_S['peakS2_onlyhits/ev_1'][()] )

# add zeros at the end
peakS2_onlyhits_B = np.pad(f_B['peakS2_onlyhits/ev_1'][()], (0, diff_elem_S2_B), 'constant')
peakS2_onlyhits_S = np.pad(f_S['peakS2_onlyhits/ev_1'][()], (0, diff_elem_S2_S), 'constant')

for i in range(2, num_data+1):
    
    # how many elements do we need to make all the peak (S2 or S2) arrays with the same length
    diff_elem_S2_B = max_pS2_both - len( f_B['peakS2_onlyhits/ev_'+str(i)][()] )
    diff_elem_S2_S = max_pS2_both - len( f_S['peakS2_onlyhits/ev_'+str(i)][()] )
    
    # add zeros at the end
    aux_S2_B = np.pad(f_B['peakS2_onlyhits/ev_'+str(i)][()], (0, diff_elem_S2_B), 'constant')
    aux_S2_S = np.pad(f_S['peakS2_onlyhits/ev_'+str(i)][()], (0, diff_elem_S2_S), 'constant')
    
    # add new event to the matrix as a row
    peakS2_onlyhits_B = np.row_stack([peakS2_onlyhits_B,aux_S2_B])
    peakS2_onlyhits_S = np.row_stack([peakS2_onlyhits_S,aux_S2_S])
    
    
    

# X and Y for the classifier
X_peakS2 = np.row_stack([peakS2_onlyhits_B,peakS2_onlyhits_S])
# normalize
X_peakS2 = scaler.fit_transform(X_peakS2)

del peakS2_onlyhits_B
del peakS2_onlyhits_S



# close the h5 files
f_B.close()
f_S.close()





###################
# CONCATENATE ALL #
###################

X_mon = np.concatenate([X_hits_bot,X_hits_top,X_peakS1,X_peakS2],axis=1)

del X_hits_bot
del X_hits_top
del X_peakS1
del X_peakS2

# labels
y_mon = np.concatenate([np.zeros(num_data),np.ones(num_data)])


# divide into train-val and test data samples
test_ratio = 0.15
val_ratio = 0.15


X_mon_aux, X_mon_test, y_mon_aux, y_mon_test = train_test_split(X_mon,
                                                                y_mon,
                                                                test_size=test_ratio,
                                                                random_state=42,
                                                                #stratify = y_mon,
                                                                shuffle=True)

del X_mon
del y_mon

X_mon_train, X_mon_val, y_mon_train, y_mon_val = train_test_split(X_mon_aux,
                                                                  y_mon_aux,
                                                                  test_size=val_ratio,
                                                                  random_state=42,
                                                                  #stratify = y_mon_aux,
                                                                  shuffle=True)

del X_mon_aux
del y_mon_aux

print('')
print('X_mon_train : ', X_mon_train.shape)
print('y_mon_train : ', y_mon_train.shape)
print('X_mon_val : ', X_mon_val.shape)
print('y_mon_val : ', y_mon_val.shape)
print('X_mon_test : ', X_mon_test.shape)
print('y_mon_test : ', y_mon_test.shape)
print('')
# Out:
# hits_bot length:  121
# hits_top length:  127
# max_pS1_both lenght:  176
# max_pS2_both lenght:  2214
#
# X_mon_train :  (26588, 2638)
# y_mon_train :  (26588,)
# X_mon_val :  (4692, 2638)
# y_mon_val :  (4692,)
# X_mon_test :  (5520, 2638)
# y_mon_test :  (5520,)

# %% [markdown]
# ### CLASSIFIER

# %%
# XGBoost with only the kinematic variables of the leptons

# CLASSIFIER
classifier = XGBClassifier(
    n_estimators=1500,
    learning_rate=0.1,
    reg_lambda=0.0,reg_alpha=0.0,
    gamma=0.0,objective='binary:logistic',
    max_depth=5,
    #eval_metric=["error", "logloss", "map"]
    eval_metric='logloss')

# FIT
classifier.fit(X_mon_train,y_mon_train,eval_set=[(X_mon_train, y_mon_train), (X_mon_val, y_mon_val)],
        early_stopping_rounds=50,#early stopping
        verbose=True)


# PREDICTIONS
y_pred_xg = classifier.predict_proba(X_mon_test).T[1]


# ROC
fpr_mon_xg, tpr_mon_xg, _ = roc_curve(y_mon_test, y_pred_xg)
roc_auc_xg = auc(fpr_mon_xg, tpr_mon_xg)


# PLOT THE ROC WITH AUC
fig = plt.figure(figsize=(6, 6))
gs = gridspec.GridSpec(1, 1) 
ax0 = plt.subplot(gs[0])
ax0.yaxis.set_ticks_position('both')
ax0.xaxis.set_ticks_position('both')
ax0.tick_params(direction="in",which="both")
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
ax0.minorticks_on()


plt.plot(tpr_mon_xg,1-fpr_mon_xg,label="$f_{1}$, AUC = %0.2f" % roc_auc_xg,color="orange",ls=":",lw=4)
plt.plot([1,0],[0,1],ls=":",color="grey")
plt.xlabel("True Positive Rate",fontsize=16)
plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
plt.legend()
plt.xlim([0,1])
plt.ylim([0,1])
plt.yticks([0.2,0.4,0.6,0.8,1.])
plt.legend(frameon=False,fontsize=16)
plt.show()



# XGBoost with the kinematic variables of the leptons

########################
# CLASSIFICATION SCORE #
########################

# Outputs for validation data set

pred_XG_SM = []
pred_XG_NP = []

for i in range(len(y_mon_test)):
    if y_mon_test[i] == 0:
        pred_XG_SM.append(y_pred_xg[i])
    else:
        pred_XG_NP.append(y_pred_xg[i])
        
        
print('Classification score:')
        
weights = np.ones_like(pred_XG_SM)/float(len(pred_XG_SM))
nSM, binsSM, patchesSM = plt.hist(pred_XG_SM, 50, weights=weights, range=[0,1], histtype='step', color='firebrick', linewidth=2, label='Background')

weights = np.ones_like(pred_XG_NP)/float(len(pred_XG_NP))
nNP, binsNP, patchesNP = plt.hist(pred_XG_NP, 50, weights=weights, range=[0,1], histtype='step', color='forestgreen', linewidth=2, label='Signal')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Classication score (XGBoost)",fontsize=15)
plt.ylabel("Fraction of events",fontsize=14)
plt.grid()
plt.legend(fontsize=12)

plt.show()




print('\n ROC-AUC = ', roc_auc_xg)
# Out:
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [0]	validation_0-logloss:0.64392	validation_1-logloss:0.64667
# [1]	validation_0-logloss:0.60240	validation_1-logloss:0.60727
# [2]	validation_0-logloss:0.56726	validation_1-logloss:0.57487
# [3]	validation_0-logloss:0.53669	validation_1-logloss:0.54709
# [4]	validation_0-logloss:0.50975	validation_1-logloss:0.52245
# [5]	validation_0-logloss:0.48591	validation_1-logloss:0.50083
# [6]	validation_0-logloss:0.46503	validation_1-logloss:0.48230
# [7]	validation_0-logloss:0.44646	validation_1-logloss:0.46598
# [8]	validation_0-logloss:0.42981	validation_1-logloss:0.45167
# [9]	validation_0-logloss:0.41464	validation_1-logloss:0.43898
# [10]	validation_0-logloss:0.40089	validation_1-logloss:0.42780
# [11]	validation_0-logloss:0.38811	validation_1-logloss:0.41706
# [12]	validation_0-logloss:0.37693	validation_1-logloss:0.40843
# [13]	validation_0-logloss:0.36631	validation_1-logloss:0.39976
# [14]	validation_0-logloss:0.35677	validation_1-logloss:0.39133
# [15]	validation_0-logloss:0.34781	validation_1-logloss:0.38457
# [16]	validation_0-logloss:0.33977	validation_1-logloss:0.37866
# [17]	validation_0-logloss:0.33182	validation_1-logloss:0.37289
# [18]	validation_0-logloss:0.32481	validation_1-logloss:0.36796
# [19]	validation_0-logloss:0.31812	validation_1-logloss:0.36330
# [20]	validation_0-logloss:0.31148	validation_1-logloss:0.35832
# [21]	validation_0-logloss:0.30511	validation_1-logloss:0.35402
# [22]	validation_0-logloss:0.29919	validation_1-logloss:0.34970
# [23]	validation_0-logloss:0.29370	validation_1-logloss:0.34550
# [24]	validation_0-logloss:0.28880	validation_1-logloss:0.34149
# [25]	validation_0-logloss:0.28356	validation_1-logloss:0.33772
# [26]	validation_0-logloss:0.27858	validation_1-logloss:0.33433
# [27]	validation_0-logloss:0.27412	validation_1-logloss:0.33121
# [28]	validation_0-logloss:0.26970	validation_1-logloss:0.32839
# [29]	validation_0-logloss:0.26583	validation_1-logloss:0.32586
# [30]	validation_0-logloss:0.26180	validation_1-logloss:0.32270
# [31]	validation_0-logloss:0.25765	validation_1-logloss:0.32048
# [32]	validation_0-logloss:0.25439	validation_1-logloss:0.31862
# [33]	validation_0-logloss:0.25078	validation_1-logloss:0.31635
# [34]	validation_0-logloss:0.24784	validation_1-logloss:0.31477
# [35]	validation_0-logloss:0.24455	validation_1-logloss:0.31305
# [36]	validation_0-logloss:0.24158	validation_1-logloss:0.31114
# [37]	validation_0-logloss:0.23836	validation_1-logloss:0.30929
# [38]	validation_0-logloss:0.23559	validation_1-logloss:0.30782
# [39]	validation_0-logloss:0.23299	validation_1-logloss:0.30617
# [40]	validation_0-logloss:0.23034	validation_1-logloss:0.30473
# [41]	validation_0-logloss:0.22752	validation_1-logloss:0.30297
# [42]	validation_0-logloss:0.22563	validation_1-logloss:0.30157
# [43]	validation_0-logloss:0.22311	validation_1-logloss:0.30034
# [44]	validation_0-logloss:0.22051	validation_1-logloss:0.29845
# [45]	validation_0-logloss:0.21803	validation_1-logloss:0.29727
# [46]	validation_0-logloss:0.21595	validation_1-logloss:0.29609
# [47]	validation_0-logloss:0.21423	validation_1-logloss:0.29508
# [48]	validation_0-logloss:0.21183	validation_1-logloss:0.29382
# [49]	validation_0-logloss:0.20965	validation_1-logloss:0.29268
# [50]	validation_0-logloss:0.20761	validation_1-logloss:0.29157
# [51]	validation_0-logloss:0.20575	validation_1-logloss:0.29063
# [52]	validation_0-logloss:0.20414	validation_1-logloss:0.28969
# [53]	validation_0-logloss:0.20231	validation_1-logloss:0.28868
# [54]	validation_0-logloss:0.20039	validation_1-logloss:0.28780
# [55]	validation_0-logloss:0.19856	validation_1-logloss:0.28694
# [56]	validation_0-logloss:0.19710	validation_1-logloss:0.28619
# [57]	validation_0-logloss:0.19545	validation_1-logloss:0.28534
# [58]	validation_0-logloss:0.19409	validation_1-logloss:0.28469
# [59]	validation_0-logloss:0.19265	validation_1-logloss:0.28390
# [60]	validation_0-logloss:0.19107	validation_1-logloss:0.28305
# [61]	validation_0-logloss:0.18938	validation_1-logloss:0.28227
# [62]	validation_0-logloss:0.18815	validation_1-logloss:0.28180
# [63]	validation_0-logloss:0.18662	validation_1-logloss:0.28111
# [64]	validation_0-logloss:0.18509	validation_1-logloss:0.28057
# [65]	validation_0-logloss:0.18395	validation_1-logloss:0.28005
# [66]	validation_0-logloss:0.18268	validation_1-logloss:0.27974
# [67]	validation_0-logloss:0.18141	validation_1-logloss:0.27923
# [68]	validation_0-logloss:0.17994	validation_1-logloss:0.27877
# [69]	validation_0-logloss:0.17849	validation_1-logloss:0.27798
# [70]	validation_0-logloss:0.17744	validation_1-logloss:0.27741
# [71]	validation_0-logloss:0.17608	validation_1-logloss:0.27693
# [72]	validation_0-logloss:0.17480	validation_1-logloss:0.27657
# [73]	validation_0-logloss:0.17360	validation_1-logloss:0.27584
# [74]	validation_0-logloss:0.17261	validation_1-logloss:0.27561
# [75]	validation_0-logloss:0.17147	validation_1-logloss:0.27495
# [76]	validation_0-logloss:0.17033	validation_1-logloss:0.27456
# [77]	validation_0-logloss:0.16940	validation_1-logloss:0.27453
# [78]	validation_0-logloss:0.16839	validation_1-logloss:0.27433
# [79]	validation_0-logloss:0.16750	validation_1-logloss:0.27426
# [80]	validation_0-logloss:0.16641	validation_1-logloss:0.27386
# [81]	validation_0-logloss:0.16530	validation_1-logloss:0.27350
# [82]	validation_0-logloss:0.16439	validation_1-logloss:0.27301
# [83]	validation_0-logloss:0.16355	validation_1-logloss:0.27276
# [84]	validation_0-logloss:0.16281	validation_1-logloss:0.27218
# [85]	validation_0-logloss:0.16181	validation_1-logloss:0.27178
# [86]	validation_0-logloss:0.16081	validation_1-logloss:0.27126
# [87]	validation_0-logloss:0.16012	validation_1-logloss:0.27102
# [88]	validation_0-logloss:0.15915	validation_1-logloss:0.27068
# [89]	validation_0-logloss:0.15846	validation_1-logloss:0.27056
# [90]	validation_0-logloss:0.15747	validation_1-logloss:0.27022
# [91]	validation_0-logloss:0.15682	validation_1-logloss:0.27012
# [92]	validation_0-logloss:0.15583	validation_1-logloss:0.26970
# [93]	validation_0-logloss:0.15482	validation_1-logloss:0.26975
# [94]	validation_0-logloss:0.15385	validation_1-logloss:0.26957
# [95]	validation_0-logloss:0.15311	validation_1-logloss:0.26920
# [96]	validation_0-logloss:0.15244	validation_1-logloss:0.26926
# [97]	validation_0-logloss:0.15151	validation_1-logloss:0.26904
# [98]	validation_0-logloss:0.15091	validation_1-logloss:0.26885
# [99]	validation_0-logloss:0.15032	validation_1-logloss:0.26873
# [100]	validation_0-logloss:0.14977	validation_1-logloss:0.26869
# [101]	validation_0-logloss:0.14908	validation_1-logloss:0.26847
# [102]	validation_0-logloss:0.14837	validation_1-logloss:0.26835
# [103]	validation_0-logloss:0.14761	validation_1-logloss:0.26847
# [104]	validation_0-logloss:0.14683	validation_1-logloss:0.26854
# [105]	validation_0-logloss:0.14595	validation_1-logloss:0.26832
# [106]	validation_0-logloss:0.14503	validation_1-logloss:0.26833
# [107]	validation_0-logloss:0.14415	validation_1-logloss:0.26837
# [108]	validation_0-logloss:0.14364	validation_1-logloss:0.26813
# [109]	validation_0-logloss:0.14292	validation_1-logloss:0.26764
# [110]	validation_0-logloss:0.14243	validation_1-logloss:0.26747
# [111]	validation_0-logloss:0.14164	validation_1-logloss:0.26739
# [112]	validation_0-logloss:0.14092	validation_1-logloss:0.26721
# [113]	validation_0-logloss:0.14041	validation_1-logloss:0.26728
# [114]	validation_0-logloss:0.13968	validation_1-logloss:0.26733
# [115]	validation_0-logloss:0.13912	validation_1-logloss:0.26740
# [116]	validation_0-logloss:0.13845	validation_1-logloss:0.26747
# [117]	validation_0-logloss:0.13781	validation_1-logloss:0.26731
# [118]	validation_0-logloss:0.13714	validation_1-logloss:0.26716
# [119]	validation_0-logloss:0.13662	validation_1-logloss:0.26725
# [120]	validation_0-logloss:0.13597	validation_1-logloss:0.26711
# [121]	validation_0-logloss:0.13528	validation_1-logloss:0.26691
# [122]	validation_0-logloss:0.13467	validation_1-logloss:0.26677
# [123]	validation_0-logloss:0.13431	validation_1-logloss:0.26685
# [124]	validation_0-logloss:0.13396	validation_1-logloss:0.26659
# [125]	validation_0-logloss:0.13346	validation_1-logloss:0.26661
# [126]	validation_0-logloss:0.13290	validation_1-logloss:0.26650
# [127]	validation_0-logloss:0.13235	validation_1-logloss:0.26625
# [128]	validation_0-logloss:0.13188	validation_1-logloss:0.26606
# [129]	validation_0-logloss:0.13149	validation_1-logloss:0.26601
# [130]	validation_0-logloss:0.13101	validation_1-logloss:0.26607
# [131]	validation_0-logloss:0.13063	validation_1-logloss:0.26604
# [132]	validation_0-logloss:0.13019	validation_1-logloss:0.26596
# [133]	validation_0-logloss:0.12968	validation_1-logloss:0.26566
# [134]	validation_0-logloss:0.12915	validation_1-logloss:0.26565
# [135]	validation_0-logloss:0.12867	validation_1-logloss:0.26555
# [136]	validation_0-logloss:0.12784	validation_1-logloss:0.26538
# [137]	validation_0-logloss:0.12731	validation_1-logloss:0.26526
# [138]	validation_0-logloss:0.12693	validation_1-logloss:0.26515
# [139]	validation_0-logloss:0.12638	validation_1-logloss:0.26509
# [140]	validation_0-logloss:0.12590	validation_1-logloss:0.26492
# [141]	validation_0-logloss:0.12546	validation_1-logloss:0.26479
# [142]	validation_0-logloss:0.12504	validation_1-logloss:0.26511
# [143]	validation_0-logloss:0.12454	validation_1-logloss:0.26510
# [144]	validation_0-logloss:0.12410	validation_1-logloss:0.26500
# [145]	validation_0-logloss:0.12393	validation_1-logloss:0.26513
# [146]	validation_0-logloss:0.12352	validation_1-logloss:0.26505
# [147]	validation_0-logloss:0.12296	validation_1-logloss:0.26492
# [148]	validation_0-logloss:0.12247	validation_1-logloss:0.26465
# [149]	validation_0-logloss:0.12210	validation_1-logloss:0.26480
# [150]	validation_0-logloss:0.12165	validation_1-logloss:0.26466
# [151]	validation_0-logloss:0.12114	validation_1-logloss:0.26488
# [152]	validation_0-logloss:0.12070	validation_1-logloss:0.26490
# [153]	validation_0-logloss:0.12000	validation_1-logloss:0.26464
# [154]	validation_0-logloss:0.11938	validation_1-logloss:0.26468
# [155]	validation_0-logloss:0.11868	validation_1-logloss:0.26479
# [156]	validation_0-logloss:0.11835	validation_1-logloss:0.26476
# [157]	validation_0-logloss:0.11791	validation_1-logloss:0.26455
# [158]	validation_0-logloss:0.11749	validation_1-logloss:0.26430
# [159]	validation_0-logloss:0.11713	validation_1-logloss:0.26427
# [160]	validation_0-logloss:0.11691	validation_1-logloss:0.26434
# [161]	validation_0-logloss:0.11656	validation_1-logloss:0.26434
# [162]	validation_0-logloss:0.11640	validation_1-logloss:0.26440
# [163]	validation_0-logloss:0.11603	validation_1-logloss:0.26417
# [164]	validation_0-logloss:0.11574	validation_1-logloss:0.26426
# [165]	validation_0-logloss:0.11529	validation_1-logloss:0.26419
# [166]	validation_0-logloss:0.11496	validation_1-logloss:0.26417
# [167]	validation_0-logloss:0.11454	validation_1-logloss:0.26422
# [168]	validation_0-logloss:0.11418	validation_1-logloss:0.26400
# [169]	validation_0-logloss:0.11367	validation_1-logloss:0.26376
# [170]	validation_0-logloss:0.11308	validation_1-logloss:0.26394
# [171]	validation_0-logloss:0.11290	validation_1-logloss:0.26396
# [172]	validation_0-logloss:0.11246	validation_1-logloss:0.26407
# [173]	validation_0-logloss:0.11225	validation_1-logloss:0.26411
# [174]	validation_0-logloss:0.11187	validation_1-logloss:0.26417
# [175]	validation_0-logloss:0.11139	validation_1-logloss:0.26407
# [176]	validation_0-logloss:0.11113	validation_1-logloss:0.26397
# [177]	validation_0-logloss:0.11094	validation_1-logloss:0.26389
# [178]	validation_0-logloss:0.11057	validation_1-logloss:0.26403
# [179]	validation_0-logloss:0.11042	validation_1-logloss:0.26388
# [180]	validation_0-logloss:0.10995	validation_1-logloss:0.26379
# [181]	validation_0-logloss:0.10952	validation_1-logloss:0.26373
# [182]	validation_0-logloss:0.10894	validation_1-logloss:0.26367
# [183]	validation_0-logloss:0.10850	validation_1-logloss:0.26347
# [184]	validation_0-logloss:0.10806	validation_1-logloss:0.26336
# [185]	validation_0-logloss:0.10766	validation_1-logloss:0.26350
# [186]	validation_0-logloss:0.10728	validation_1-logloss:0.26331
# [187]	validation_0-logloss:0.10713	validation_1-logloss:0.26338
# [188]	validation_0-logloss:0.10644	validation_1-logloss:0.26330
# [189]	validation_0-logloss:0.10578	validation_1-logloss:0.26299
# [190]	validation_0-logloss:0.10554	validation_1-logloss:0.26302
# [191]	validation_0-logloss:0.10512	validation_1-logloss:0.26313
# [192]	validation_0-logloss:0.10479	validation_1-logloss:0.26313
# [193]	validation_0-logloss:0.10459	validation_1-logloss:0.26315
# [194]	validation_0-logloss:0.10431	validation_1-logloss:0.26307
# [195]	validation_0-logloss:0.10380	validation_1-logloss:0.26313
# [196]	validation_0-logloss:0.10340	validation_1-logloss:0.26320
# [197]	validation_0-logloss:0.10289	validation_1-logloss:0.26295
# [198]	validation_0-logloss:0.10253	validation_1-logloss:0.26282
# [199]	validation_0-logloss:0.10229	validation_1-logloss:0.26295
# [200]	validation_0-logloss:0.10204	validation_1-logloss:0.26291
# [201]	validation_0-logloss:0.10169	validation_1-logloss:0.26304
# [202]	validation_0-logloss:0.10140	validation_1-logloss:0.26289
# [203]	validation_0-logloss:0.10098	validation_1-logloss:0.26295
# [204]	validation_0-logloss:0.10070	validation_1-logloss:0.26306
# [205]	validation_0-logloss:0.10010	validation_1-logloss:0.26280
# [206]	validation_0-logloss:0.09991	validation_1-logloss:0.26277
# [207]	validation_0-logloss:0.09982	validation_1-logloss:0.26284
# [208]	validation_0-logloss:0.09972	validation_1-logloss:0.26284
# [209]	validation_0-logloss:0.09960	validation_1-logloss:0.26294
# [210]	validation_0-logloss:0.09918	validation_1-logloss:0.26310
# [211]	validation_0-logloss:0.09898	validation_1-logloss:0.26314
# [212]	validation_0-logloss:0.09882	validation_1-logloss:0.26309
# [213]	validation_0-logloss:0.09849	validation_1-logloss:0.26326
# [214]	validation_0-logloss:0.09828	validation_1-logloss:0.26330
# [215]	validation_0-logloss:0.09792	validation_1-logloss:0.26323
# [216]	validation_0-logloss:0.09765	validation_1-logloss:0.26315
# [217]	validation_0-logloss:0.09711	validation_1-logloss:0.26297
# [218]	validation_0-logloss:0.09680	validation_1-logloss:0.26284
# [219]	validation_0-logloss:0.09668	validation_1-logloss:0.26287
# [220]	validation_0-logloss:0.09620	validation_1-logloss:0.26298
# [221]	validation_0-logloss:0.09587	validation_1-logloss:0.26282
# [222]	validation_0-logloss:0.09555	validation_1-logloss:0.26305
# [223]	validation_0-logloss:0.09530	validation_1-logloss:0.26301
# [224]	validation_0-logloss:0.09494	validation_1-logloss:0.26315
# [225]	validation_0-logloss:0.09464	validation_1-logloss:0.26315
# [226]	validation_0-logloss:0.09435	validation_1-logloss:0.26310
# [227]	validation_0-logloss:0.09401	validation_1-logloss:0.26320
# [228]	validation_0-logloss:0.09354	validation_1-logloss:0.26325
# [229]	validation_0-logloss:0.09333	validation_1-logloss:0.26315
# [230]	validation_0-logloss:0.09278	validation_1-logloss:0.26316
# [231]	validation_0-logloss:0.09257	validation_1-logloss:0.26312
# [232]	validation_0-logloss:0.09231	validation_1-logloss:0.26328
# [233]	validation_0-logloss:0.09201	validation_1-logloss:0.26343
# [234]	validation_0-logloss:0.09190	validation_1-logloss:0.26343
# [235]	validation_0-logloss:0.09144	validation_1-logloss:0.26346
# [236]	validation_0-logloss:0.09107	validation_1-logloss:0.26324
# [237]	validation_0-logloss:0.09088	validation_1-logloss:0.26335
# [238]	validation_0-logloss:0.09062	validation_1-logloss:0.26327
# [239]	validation_0-logloss:0.09044	validation_1-logloss:0.26327
# [240]	validation_0-logloss:0.09012	validation_1-logloss:0.26326
# [241]	validation_0-logloss:0.08964	validation_1-logloss:0.26315
# [242]	validation_0-logloss:0.08936	validation_1-logloss:0.26339
# [243]	validation_0-logloss:0.08913	validation_1-logloss:0.26342
# [244]	validation_0-logloss:0.08897	validation_1-logloss:0.26350
# [245]	validation_0-logloss:0.08871	validation_1-logloss:0.26350
# [246]	validation_0-logloss:0.08837	validation_1-logloss:0.26357
# [247]	validation_0-logloss:0.08805	validation_1-logloss:0.26377
# [248]	validation_0-logloss:0.08773	validation_1-logloss:0.26386
# [249]	validation_0-logloss:0.08731	validation_1-logloss:0.26388
# [250]	validation_0-logloss:0.08707	validation_1-logloss:0.26387
# [251]	validation_0-logloss:0.08684	validation_1-logloss:0.26389
# [252]	validation_0-logloss:0.08651	validation_1-logloss:0.26384
# [253]	validation_0-logloss:0.08607	validation_1-logloss:0.26377
# [254]	validation_0-logloss:0.08582	validation_1-logloss:0.26375
# [255]	validation_0-logloss:0.08558	validation_1-logloss:0.26377
# [256]	validation_0-logloss:0.08544	validation_1-logloss:0.26376
# Classification score:
#  ROC-AUC =  0.9601453119067114

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import auc, precision_recall_curve

precision_xg, recall_xg, _ = precision_recall_curve(y_mon_test, y_pred_xg)
auc_xg = auc(recall_xg, precision_xg)

plt.figure(figsize=(6, 6))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.plot(recall_xg, precision_xg, label=f'AP (XGBoost) = {auc_xg:.2f}')
plt.title('Precision-Recall Curve', size=16)
plt.xlabel('Recall', size=16)
plt.ylabel('Precision', size=16)
plt.legend(frameon=False,fontsize=16)
plt.show()


print('\n AP = ', auc_xg)
# Out:
#  AP =  0.9559613322121732

# %% [markdown]
# ## DNN

# %%
# define the keras model
model = Sequential()
model.add(Dense(64, input_shape=(X_mon_train.shape[1],), activation='relu'))
model.add(Dropout(0.20))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.20))
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.20))
model.add(Dense(8, activation='relu'))
model.add(Dropout(0.20))
model.add(Dense(1, activation='sigmoid'))

# Print the model summary
model.summary()

# to stop the training if validation loss does not improve after patience number of epochs
stop_training = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50, restore_best_weights=True)

# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])


batch_size = 128
tot_epochs = 500


# Entrenamos el modelo
history = model.fit(X_mon_train,
                    y_mon_train,
                    batch_size=batch_size,
                    epochs=tot_epochs,
                    callbacks=[stop_training],
                    verbose=1,
                    validation_data=(X_mon_val, y_mon_val),
                    shuffle=True)


# Plot de la cost function para la train y test data
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.legend(['train', 'test'], loc='upper left')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# Plot de la accuracy function para la train y test data
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


#model.save(root_dir + 'CNN-histo-mix-v2/saved-models/' + 'conv-' + nameMIX_linear +'.h5') # Guardar el modelo.  # Predicción de la red entrenada
y_pred_dnn = model.predict(X_mon_test)

# Compute ROC curve and ROC area for each class
fpr_dnn = dict()
tpr_dnn = dict()
roc_auc_dnn = dict()
fpr_dnn, tpr_dnn, _ = roc_curve(y_mon_test, y_pred_dnn)
roc_auc_dnn = auc(fpr_dnn, tpr_dnn)


plt.figure()
plt.plot(tpr_dnn,1-fpr_dnn,label="$f_{1}$, AUC = %0.2f" % roc_auc_dnn,color="orange",ls=":",lw=4)
plt.plot([1,0],[0,1],ls=":",color="grey")
plt.xlabel("True Positive Rate",fontsize=16)
plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
plt.legend()
plt.xlim([0,1])
plt.ylim([0,1])
plt.yticks([0.2,0.4,0.6,0.8,1.])
plt.legend(frameon=False,fontsize=16)
plt.show()








########################
# CLASSIFICATION SCORE #
########################

# Outputs for validation data set

pred_XG_SM = []
pred_XG_NP = []

for i in range(len(y_mon_test)):
    if y_mon_test[i] == 0:
        pred_XG_SM.append(y_pred_dnn[i,0])
    else:
        pred_XG_NP.append(y_pred_dnn[i,0])
        
        
print('Classification score:')
        
weights = np.ones_like(pred_XG_SM)/float(len(pred_XG_SM))
nSM, binsSM, patchesSM = plt.hist(pred_XG_SM, 50, weights=weights, range=[0,1], histtype='step', color='firebrick', linewidth=2, label='Background')

weights = np.ones_like(pred_XG_NP)/float(len(pred_XG_NP))
nNP, binsNP, patchesNP = plt.hist(pred_XG_NP, 50, weights=weights, range=[0,1], histtype='step', color='forestgreen', linewidth=2, label='Signal')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Classication score (DNN)",fontsize=15)
plt.ylabel("Fraction of events",fontsize=14)
plt.grid()
plt.legend(fontsize=12)

plt.show()






print('\n ROC-AUC = ', roc_auc_dnn)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                168896
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                528
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 171,649
# Trainable params: 171,649
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 208/208 [==============================] - 10s 3ms/step - loss: 0.4992 - accuracy: 0.7632 - val_loss: 0.3105 - val_accuracy: 0.8615
# Epoch 2/500
# 208/208 [==============================] - 0s 1ms/step - loss: 0.3357 - accuracy: 0.8661 - val_loss: 0.2949 - val_accuracy: 0.8698
# Epoch 3/500
# 208/208 [==============================] - 0s 1ms/step - loss: 0.3192 - accuracy: 0.8755 - val_loss: 0.2840 - val_accuracy: 0.8751
# Epoch 4/500
# 208/208 [==============================] - 0s 1ms/step - loss: 0.2904 - accuracy: 0.8903 - val_loss: 0.2836 - val_accuracy: 0.8785
# Epoch 5/500
# 208/208 [==============================] - 0s 1ms/step - loss: 0.2952 - accuracy: 0.8844 - val_loss: 0.2736 - val_accuracy: 0.8813
# Epoch 6/500
# 208/208 [==============================] - 0s 1ms/step - loss: 0.2872 - accuracy: 0.8876 - val_loss: 0.2689 - val_accuracy: 0.8845
# Epoch 7/500
# 208/208 [==============================] - 0s 1ms/step - loss: 0.2714 - accuracy: 0.8980 - val_loss: 0.2707 - val_accuracy: 0.8824
# Epoch 8/500
# 208/208 [==============================] - 0s 1ms/step - loss: 0.2754 - accuracy: 0.8909 - val_loss: 0.2586 - val_accuracy: 0.8879
# Epoch 9/500
# 208/208 [==============================] - 0s 1ms/step - loss: 0.2738 - accuracy: 0.8960 - val_loss: 0.2833 - val_accuracy: 0.8766
# Epoch 49/500
# 208/208 [==============================] - 0s 1ms/step - loss: 0.2024 - accuracy: 0.9238 - val_loss: 0.2914 - val_accuracy: 0.8832
# Epoch 50/500
# 208/208 [==============================] - 0s 1ms/step - loss: 0.2026 - accuracy: 0.9273 - val_loss: 0.3046 - val_accuracy: 0.8804
# Epoch 51/500
# 208/208 [==============================] - 0s 1ms/step - loss: 0.2004 - accuracy: 0.9247 - val_loss: 0.2956 - val_accuracy: 0.8862
# Epoch 52/500
# 208/208 [==============================] - 0s 1ms/step - loss: 0.1958 - accuracy: 0.9278 - val_loss: 0.2876 - val_accuracy: 0.8819
# Epoch 53/500
# 208/208 [==============================] - 0s 1ms/step - loss: 0.1974 - accuracy: 0.9252 - val_loss: 0.3076 - val_accuracy: 0.8792
# Epoch 54/500
# 208/208 [==============================] - 0s 1ms/step - loss: 0.2094 - accuracy: 0.9194 - val_loss: 0.3001 - val_accuracy: 0.8806
# Epoch 55/500
# 208/208 [==============================] - 0s 1ms/step - loss: 0.2017 - accuracy: 0.9250 - val_loss: 0.2958 - val_accuracy: 0.8792
# Epoch 56/500
# 208/208 [==============================] - 0s 1ms/step - loss: 0.1924 - accuracy: 0.9290 - val_loss: 0.2915 - val_accuracy: 0.8834
# Epoch 57/500
# 208/208 [==============================] - 0s 1ms/step - loss: 0.2014 - accuracy: 0.9240 - val_loss: 0.2943 - val_accuracy: 0.8849
# Epoch 58/500
# 208/208 [==============================] - 0s 1ms/step - loss: 0.1945 - accuracy: 0.9297 - val_loss: 0.2966 - val_accuracy: 0.8836
# Epoch 59/500
# 208/208 [==============================] - 0s 1ms/step - loss: 0.1958 - accuracy: 0.9264 - val_loss: 0.3201 - val_accuracy: 0.8868
# Epoch 60/500
# 208/208 [==============================] - 0s 1ms/step - loss: 0.1919 - accuracy: 0.9260 - val_loss: 0.3038 - val_accuracy: 0.8819
# Restoring model weights from the end of the best epoch.
# Epoch 00060: early stopping
# Classification score:
#  ROC-AUC =  0.9607685686391183

# %% [markdown]
# ## CNN

# %%
from keras.layers import Input, Dense, Conv1D, Conv2D, Flatten, MaxPooling1D, MaxPooling2D

# %%
# prepare the dataset
X_mon_train_cn = X_mon_train.reshape(X_mon_train.shape[0], X_mon_train.shape[1], 1)
X_mon_test_cn = X_mon_test.reshape(X_mon_test.shape[0], X_mon_test.shape[1], 1)
X_mon_val_cn = X_mon_val.reshape(X_mon_val.shape[0], X_mon_val.shape[1], 1)

# %%
# define the keras model
model = Sequential()
model.add(Conv1D(16, 2, input_shape=(X_mon_train.shape[1],1), activation='relu', strides = (1),kernel_regularizer=l2(0.005)))
model.add(MaxPooling1D(2, strides = (1)))
model.add(Flatten())
model.add(Dense(10, activation='relu'))
model.add(Dropout(0.20))
model.add(Dense(1, activation='sigmoid'))


# Print the model summary
#model.summary()

# to stop the training if validation loss does not improve after patience number of epochs
stop_training = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50, restore_best_weights=True)

# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])


batch_size = 128
tot_epochs = 500


# Entrenamos el modelo
history = model.fit(X_mon_train_cn,
                    y_mon_train,
                    batch_size=batch_size,
                    epochs=tot_epochs,
                    callbacks=[stop_training],
                    verbose=1,
                    validation_data=(X_mon_val_cn, y_mon_val),
                    shuffle=True)


# Plot de la cost function para la train y test data
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.legend(['train', 'test'], loc='upper left')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# Plot de la accuracy function para la train y test data
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


#model.save(root_dir + 'CNN-histo-mix-v2/saved-models/' + 'conv-' + nameMIX_linear +'.h5') # Guardar el modelo.  # Predicción de la red entrenada
y_pred_cnn = model.predict(X_mon_test_cn)

# Compute ROC curve and ROC area for each class
fpr_cnn = dict()
tpr_cnn = dict()
roc_auc_cnn = dict()
fpr_cnn, tpr_cnn, _ = roc_curve(y_mon_test, y_pred_cnn)
roc_auc_cnn = auc(fpr_cnn, tpr_cnn)


plt.figure()
plt.plot(tpr_cnn,1-fpr_cnn,label="$f_{1}$, AUC = %0.2f" % roc_auc_cnn,color="orange",ls=":",lw=4)
plt.plot([1,0],[0,1],ls=":",color="grey")
plt.xlabel("True Positive Rate",fontsize=16)
plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
plt.legend()
plt.xlim([0,1])
plt.ylim([0,1])
plt.yticks([0.2,0.4,0.6,0.8,1.])
plt.legend(frameon=False,fontsize=16)
plt.show()








########################
# CLASSIFICATION SCORE #
########################

# Outputs for validation data set

pred_XG_SM = []
pred_XG_NP = []

for i in range(len(y_mon_test)):
    if y_mon_test[i] == 0:
        pred_XG_SM.append(y_pred_cnn[i,0])
    else:
        pred_XG_NP.append(y_pred_cnn[i,0])
        
        
print('Classification score:')
        
weights = np.ones_like(pred_XG_SM)/float(len(pred_XG_SM))
nSM, binsSM, patchesSM = plt.hist(pred_XG_SM, 50, weights=weights, range=[0,1], histtype='step', color='firebrick', linewidth=2, label='Background')

weights = np.ones_like(pred_XG_NP)/float(len(pred_XG_NP))
nNP, binsNP, patchesNP = plt.hist(pred_XG_NP, 50, weights=weights, range=[0,1], histtype='step', color='forestgreen', linewidth=2, label='Signal')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Classication score (CNN)",fontsize=15)
plt.ylabel("Fraction of events",fontsize=14)
plt.grid()
plt.legend(fontsize=12)

plt.show()






print('\n ROC-AUC = ', roc_auc_cnn)
# Out:
# Epoch 1/500
# 2/2 [==============================] - 1s 171ms/step - loss: 0.6922 - accuracy: 0.4809 - val_loss: 0.5823 - val_accuracy: 0.5769
# Epoch 2/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.6416 - accuracy: 0.4870 - val_loss: 0.5851 - val_accuracy: 0.8462
# Epoch 3/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5756 - accuracy: 0.7960 - val_loss: 0.5307 - val_accuracy: 0.6538
# Epoch 4/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5857 - accuracy: 0.5966 - val_loss: 0.5048 - val_accuracy: 0.6538
# Epoch 5/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.5479 - accuracy: 0.6565 - val_loss: 0.4981 - val_accuracy: 0.8077
# Epoch 6/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5140 - accuracy: 0.7645 - val_loss: 0.5129 - val_accuracy: 0.8846
# Epoch 7/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5190 - accuracy: 0.8605 - val_loss: 0.5139 - val_accuracy: 0.8846
# Epoch 8/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5010 - accuracy: 0.8553 - val_loss: 0.4802 - val_accuracy: 0.8846
# Epoch 9/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0
500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2856 - accuracy: 1.0000 - val_loss: 0.3581 - val_accuracy: 0.9231
# Epoch 188/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2861 - accuracy: 1.0000 - val_loss: 0.3549 - val_accuracy: 0.9615
# Epoch 189/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2840 - accuracy: 1.0000 - val_loss: 0.3509 - val_accuracy: 0.9615
# Epoch 190/500
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2869 - accuracy: 0.9928 - val_loss: 0.3461 - val_accuracy: 0.9615
# Epoch 191/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2824 - accuracy: 1.0000 - val_loss: 0.3441 - val_accuracy: 0.9615
# Epoch 192/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2869 - accuracy: 0.9928 - val_loss: 0.3424 - val_accuracy: 0.9615
# Epoch 193/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2802 - accuracy: 1.0000 - val_loss: 0.3403 - val_accuracy: 0.9615
# Epoch 194/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2862 - accuracy: 1.0000 - val_loss: 0.3404 - val_accuracy: 0.9615
# Epoch 195/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2815 - accuracy: 1.0000 - val_loss: 0.3422 - val_accuracy: 0.9615
# Epoch 196/500
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2830 - accuracy: 1.0000 - val_loss: 0.3441 - val_accuracy: 0.9615
# Epoch 197/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2796 - accuracy: 1.0000 - val_loss: 0.3456 - val_accuracy: 0.9615
# Epoch 198/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2802 - accuracy: 1.0000 - val_loss: 0.3493 - val_accuracy: 0.9615
# Epoch 199/500
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2782 - accuracy: 1.0000 - val_loss: 0.3520 - val_accuracy: 0.9615
# Epoch 200/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2800 - accuracy: 1.0000 - val_loss: 0.3527 - val_accuracy: 0.9615
# Epoch 201/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2761 - accuracy: 1.0000 - val_loss: 0.3524 - val_accuracy: 0.9615
# Epoch 202/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2782 - accuracy: 1.0000 - val_loss: 0.3498 - val_accuracy: 0.9231
# Epoch 203/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2739 - accuracy: 1.0000 - val_loss: 0.3470 - val_accuracy: 0.9231
# Epoch 204/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2786 - accuracy: 0.9928 - val_loss: 0.3448 - val_accuracy: 0.9231
# Epoch 205/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2804 - accuracy: 1.0000 - val_loss: 0.3435 - val_accuracy: 0.9231
# Epoch 206/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2780 - accuracy: 1.0000 - val_loss: 0.3421 - val_accuracy: 0.9231
# Epoch 207/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2840 - accuracy: 0.9855 - val_loss: 0.3407 - val_accuracy: 0.9231
# Epoch 208/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2825 - accuracy: 0.9928 - val_loss: 0.3385 - val_accuracy: 0.9231
# Epoch 209/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2795 - accuracy: 0.9928 - val_loss: 0.3371 - val_accuracy: 0.9231
# Epoch 210/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2752 - accuracy: 1.0000 - val_loss: 0.3391 - val_accuracy: 0.9231
# Epoch 211/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2688 - accuracy: 1.0000 - val_loss: 0.3406 - val_accuracy: 0.9231
# Epoch 212/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2704 - accuracy: 1.0000 - val_loss: 0.3411 - val_accuracy: 0.9231
# Epoch 213/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2747 - accuracy: 1.0000 - val_loss: 0.3404 - val_accuracy: 0.9231
# Epoch 214/500
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2697 - accuracy: 1.0000 - val_loss: 0.3401 - val_accuracy: 0.8846
# Epoch 215/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2772 - accuracy: 0.9928 - val_loss: 0.3390 - val_accuracy: 0.9231
# Epoch 216/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2736 - accuracy: 1.0000 - val_loss: 0.3378 - val_accuracy: 0.9231
# Epoch 217/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2704 - accuracy: 1.0000 - val_loss: 0.3367 - val_accuracy: 0.9231
# Epoch 218/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2748 - accuracy: 1.0000 - val_loss: 0.3361 - val_accuracy: 0.9231
# Epoch 219/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2652 - accuracy: 1.0000 - val_loss: 0.3355 - val_accuracy: 0.9231
# Epoch 220/500
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2717 - accuracy: 1.0000 - val_loss: 0.3364 - val_accuracy: 0.9231
# Epoch 221/500
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2676 - accuracy: 1.0000 - val_loss: 0.3393 - val_accuracy: 0.9231
# Epoch 222/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2668 - accuracy: 1.0000 - val_loss: 0.3408 - val_accuracy: 0.9615
# Epoch 223/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2683 - accuracy: 1.0000 - val_loss: 0.3412 - val_accuracy: 0.9231
# Epoch 224/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2657 - accuracy: 1.0000 - val_loss: 0.3433 - val_accuracy: 0.9615
# Epoch 225/500
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2613 - accuracy: 1.0000 - val_loss: 0.3479 - val_accuracy: 0.9615
# Epoch 226/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2645 - accuracy: 1.0000 - val_loss: 0.3510 - val_accuracy: 0.9231
# Epoch 227/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2648 - accuracy: 1.0000 - val_loss: 0.3491 - val_accuracy: 0.9231
# Epoch 228/500
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2645 - accuracy: 1.0000 - val_loss: 0.3449 - val_accuracy: 0.9615
# Epoch 229/500
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2743 - accuracy: 0.9928 - val_loss: 0.3442 - val_accuracy: 0.9231
# Epoch 230/500
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2686 - accuracy: 1.0000 - val_loss: 0.3412 - val_accuracy: 0.9231
# Epoch 231/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2699 - accuracy: 1.0000 - val_loss: 0.3368 - val_accuracy: 0.9231
# Epoch 232/500
# 2/2 [==============================] - 0s 19ms/step - loss: 0.2625 - accuracy: 1.0000 - val_loss: 0.3343 - val_accuracy: 0.9231
# Epoch 233/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2636 - accuracy: 1.0000 - val_loss: 0.3339 - val_accuracy: 0.8846
# Epoch 234/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2629 - accuracy: 1.0000 - val_loss: 0.3338 - val_accuracy: 0.8846
# Epoch 235/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2631 - accuracy: 1.0000 - val_loss: 0.3318 - val_accuracy: 0.9231
# Epoch 236/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2607 - accuracy: 1.0000 - val_loss: 0.3313 - val_accuracy: 0.9231
# Epoch 237/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2615 - accuracy: 1.0000 - val_loss: 0.3325 - val_accuracy: 0.8846
# Epoch 238/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2664 - accuracy: 0.9954 - val_loss: 0.3324 - val_accuracy: 0.9231
# Epoch 239/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2649 - accuracy: 1.0000 - val_loss: 0.3321 - val_accuracy: 0.9231
# Epoch 240/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2604 - accuracy: 1.0000 - val_loss: 0.3313 - val_accuracy: 0.9231
# Epoch 241/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2629 - accuracy: 1.0000 - val_loss: 0.3307 - val_accuracy: 0.9231
# Epoch 242/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2602 - accuracy: 1.0000 - val_loss: 0.3296 - val_accuracy: 0.9231
# Epoch 243/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2595 - accuracy: 1.0000 - val_loss: 0.3257 - val_accuracy: 0.9615
# Epoch 244/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2599 - accuracy: 1.0000 - val_loss: 0.3228 - val_accuracy: 0.9615
# Epoch 245/500
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2572 - accuracy: 1.0000 - val_loss: 0.3199 - val_accuracy: 0.9615
# Epoch 246/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2565 - accuracy: 1.0000 - val_loss: 0.3192 - val_accuracy: 0.9615
# Epoch 247/500
# 2/2 [==============================] - 0s 16ms/step - loss: 0.
500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2404 - accuracy: 1.0000 - val_loss: 0.3700 - val_accuracy: 0.8077
# Restoring model weights from the end of the best epoch.
# Epoch 00305: early stopping
# Classification score:
#  ROC-AUC =  0.9017857142857143

# %%
# define the keras model
model = Sequential()
model.add(Conv1D(16, 3, input_shape=(X_mon_train.shape[1],1), activation='relu', strides = (1),kernel_regularizer=l2(0.005)))
model.add(MaxPooling1D(2, strides = (1)))
model.add(Flatten())
model.add(Dense(10, activation='relu'))
model.add(Dropout(0.20))
model.add(Dense(1, activation='sigmoid'))


# Print the model summary
#model.summary()

# to stop the training if validation loss does not improve after patience number of epochs
stop_training = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50, restore_best_weights=True)

# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])


batch_size = 128
tot_epochs = 500


# Entrenamos el modelo
history = model.fit(X_mon_train_cn,
                    y_mon_train,
                    batch_size=batch_size,
                    epochs=tot_epochs,
                    callbacks=[stop_training],
                    verbose=1,
                    validation_data=(X_mon_val_cn, y_mon_val),
                    shuffle=True)


# Plot de la cost function para la train y test data
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.legend(['train', 'test'], loc='upper left')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# Plot de la accuracy function para la train y test data
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


#model.save(root_dir + 'CNN-histo-mix-v2/saved-models/' + 'conv-' + nameMIX_linear +'.h5') # Guardar el modelo.  # Predicción de la red entrenada
y_pred_cnn = model.predict(X_mon_test_cn)

# Compute ROC curve and ROC area for each class
fpr_cnn = dict()
tpr_cnn = dict()
roc_auc_cnn = dict()
fpr_cnn, tpr_cnn, _ = roc_curve(y_mon_test, y_pred_cnn)
roc_auc_cnn = auc(fpr_cnn, tpr_cnn)


plt.figure()
plt.plot(tpr_cnn,1-fpr_cnn,label="$f_{1}$, AUC = %0.2f" % roc_auc_cnn,color="orange",ls=":",lw=4)
plt.plot([1,0],[0,1],ls=":",color="grey")
plt.xlabel("True Positive Rate",fontsize=16)
plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
plt.legend()
plt.xlim([0,1])
plt.ylim([0,1])
plt.yticks([0.2,0.4,0.6,0.8,1.])
plt.legend(frameon=False,fontsize=16)
plt.show()








########################
# CLASSIFICATION SCORE #
########################

# Outputs for validation data set

pred_XG_SM = []
pred_XG_NP = []

for i in range(len(y_mon_test)):
    if y_mon_test[i] == 0:
        pred_XG_SM.append(y_pred_cnn[i,0])
    else:
        pred_XG_NP.append(y_pred_cnn[i,0])
        
        
print('Classification score:')
        
weights = np.ones_like(pred_XG_SM)/float(len(pred_XG_SM))
nSM, binsSM, patchesSM = plt.hist(pred_XG_SM, 50, weights=weights, range=[0,1], histtype='step', color='firebrick', linewidth=2, label='Background')

weights = np.ones_like(pred_XG_NP)/float(len(pred_XG_NP))
nNP, binsNP, patchesNP = plt.hist(pred_XG_NP, 50, weights=weights, range=[0,1], histtype='step', color='forestgreen', linewidth=2, label='Signal')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Classication score (CNN)",fontsize=15)
plt.ylabel("Fraction of events",fontsize=14)
plt.grid()
plt.legend(fontsize=12)

plt.show()






print('\n ROC-AUC = ', roc_auc_cnn)
# Out:
# Epoch 1/500
# 2/2 [==============================] - 1s 174ms/step - loss: 0.7058 - accuracy: 0.3770 - val_loss: 0.5652 - val_accuracy: 0.8077
# Epoch 2/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5705 - accuracy: 0.7428 - val_loss: 0.5265 - val_accuracy: 0.7692
# Epoch 3/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.4812 - accuracy: 0.8058 - val_loss: 0.6173 - val_accuracy: 0.5769
# Epoch 4/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0
500
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0442 - accuracy: 1.0000 - val_loss: 0.4557 - val_accuracy: 0.8462
# Epoch 66/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0396 - accuracy: 1.0000 - val_loss: 0.4505 - val_accuracy: 0.8462
# Epoch 67/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0390 - accuracy: 1.0000 - val_loss: 0.4440 - val_accuracy: 0.8462
# Epoch 68/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0386 - accuracy: 1.0000 - val_loss: 0.4429 - val_accuracy: 0.8462
# Epoch 69/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0407 - accuracy: 0.9928 - val_loss: 0.4069 - val_accuracy: 0.8462
# Epoch 70/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0371 - accuracy: 1.0000 - val_loss: 0.3805 - val_accuracy: 0.8846
# Epoch 71/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0370 - accuracy: 1.0000 - val_loss: 0.4034 - val_accuracy: 0.8462
# Epoch 72/500
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0432 - accuracy: 0.9928 - val_loss: 0.4393 - val_accuracy: 0.8462
# Epoch 73/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0410 - accuracy: 0.9928 - val_loss: 0.4477 - val_accuracy: 0.8462
# Restoring model weights from the end of the best epoch.
# Epoch 00073: early stopping
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f46a02213a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Classification score:
#  ROC-AUC =  0.9375

# %%
# define the keras model
model = Sequential()
model.add(Conv1D(16, 10, input_shape=(X_mon_train.shape[1],1), activation='relu', strides = (1),kernel_regularizer=l2(0.005)))
model.add(MaxPooling1D(2, strides = (1)))
model.add(Flatten())
model.add(Dense(10, activation='relu'))
model.add(Dropout(0.20))
model.add(Dense(1, activation='sigmoid'))


# Print the model summary
#model.summary()

# to stop the training if validation loss does not improve after patience number of epochs
stop_training = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50, restore_best_weights=True)

# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])


batch_size = 128
tot_epochs = 500


# Entrenamos el modelo
history = model.fit(X_mon_train_cn,
                    y_mon_train,
                    batch_size=batch_size,
                    epochs=tot_epochs,
                    callbacks=[stop_training],
                    verbose=1,
                    validation_data=(X_mon_val_cn, y_mon_val),
                    shuffle=True)


# Plot de la cost function para la train y test data
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.legend(['train', 'test'], loc='upper left')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# Plot de la accuracy function para la train y test data
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


#model.save(root_dir + 'CNN-histo-mix-v2/saved-models/' + 'conv-' + nameMIX_linear +'.h5') # Guardar el modelo.  # Predicción de la red entrenada
y_pred_cnn = model.predict(X_mon_test_cn)

# Compute ROC curve and ROC area for each class
fpr_cnn = dict()
tpr_cnn = dict()
roc_auc_cnn = dict()
fpr_cnn, tpr_cnn, _ = roc_curve(y_mon_test, y_pred_cnn)
roc_auc_cnn = auc(fpr_cnn, tpr_cnn)


plt.figure()
plt.plot(tpr_cnn,1-fpr_cnn,label="$f_{1}$, AUC = %0.2f" % roc_auc_cnn,color="orange",ls=":",lw=4)
plt.plot([1,0],[0,1],ls=":",color="grey")
plt.xlabel("True Positive Rate",fontsize=16)
plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
plt.legend()
plt.xlim([0,1])
plt.ylim([0,1])
plt.yticks([0.2,0.4,0.6,0.8,1.])
plt.legend(frameon=False,fontsize=16)
plt.show()








########################
# CLASSIFICATION SCORE #
########################

# Outputs for validation data set

pred_XG_SM = []
pred_XG_NP = []

for i in range(len(y_mon_test)):
    if y_mon_test[i] == 0:
        pred_XG_SM.append(y_pred_cnn[i,0])
    else:
        pred_XG_NP.append(y_pred_cnn[i,0])
        
        
print('Classification score:')
        
weights = np.ones_like(pred_XG_SM)/float(len(pred_XG_SM))
nSM, binsSM, patchesSM = plt.hist(pred_XG_SM, 50, weights=weights, range=[0,1], histtype='step', color='firebrick', linewidth=2, label='Background')

weights = np.ones_like(pred_XG_NP)/float(len(pred_XG_NP))
nNP, binsNP, patchesNP = plt.hist(pred_XG_NP, 50, weights=weights, range=[0,1], histtype='step', color='forestgreen', linewidth=2, label='Signal')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Classication score (CNN)",fontsize=15)
plt.ylabel("Fraction of events",fontsize=14)
plt.grid()
plt.legend(fontsize=12)

plt.show()






print('\n ROC-AUC = ', roc_auc_cnn)
# Out:
# Epoch 1/500
# 2/2 [==============================] - 1s 189ms/step - loss: 0.7108 - accuracy: 0.4783 - val_loss: 0.6350 - val_accuracy: 0.6538
# Epoch 2/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.6421 - accuracy: 0.6328 - val_loss: 0.6162 - val_accuracy: 0.9231
# Epoch 3/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5956 - accuracy: 0.8047 - val_loss: 0.6192 - val_accuracy: 0.7308
# Epoch 4/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5827 - accuracy: 0.8099 - val_loss: 0.5686 - val_accuracy: 0.8462
# Epoch 5/500
# 2/2 [==============================] - 0s 17ms/step - loss: 0.5270 - accuracy: 0.8414 - val_loss: 0.5141 - val_accuracy: 0.8846
# Epoch 6/500
# 2/2 [==============================] - 0s 16ms/step - loss: 0.4994 - accuracy: 0.8270 - val_loss: 0.4782 - val_accuracy: 0.8846
# Epoch 7/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.4727 - accuracy: 0.8125 - val_loss: 0.4522 - val_accuracy: 0.8846
# Epoch 8/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.4225 - accuracy: 0.8652 - val_loss: 0.4505 - val_accuracy: 0.8846
# Epoch 9/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.4130 - accuracy: 0.8342 - val_loss: 0.4691 - val_accuracy: 0.7308
# Epoch 10/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.3739 - accuracy: 0.8342 - val_loss: 0.4571 - val_accuracy: 0.7308
# Epoch 11/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.3550 - accuracy: 0.8559 - val_loss: 0.4061 - val_accuracy: 0.8077
# Epoch 12/500
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2928 - accuracy: 0.9060 - val_loss: 0.3512 - val_accuracy: 0.8846
# Epoch 13/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.3116 - accuracy: 0.8750 - val_loss: 0.3128 - val_accuracy: 0.8846
# Epoch 14/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2768 - accuracy: 0.8796 - val_loss: 0.2958 - val_accuracy: 0.9231
# Epoch 15/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.3050 - accuracy: 0.8921 - val_loss: 0.3144 - val_accuracy: 0.8846
# Epoch 16/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2975 - accuracy: 0.8750 - val_loss: 0.3884 - val_accuracy: 0.7308
# Epoch 17/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2805 - accuracy: 0.8678 - val_loss: 0.4241 - val_accuracy: 0.7308
# Epoch 18/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2880 - accuracy: 0.8730 - val_loss: 0.3559 - val_accuracy: 0.8846
# Epoch 19/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2384 - accuracy: 0.9375 - val_loss: 0.3148 - val_accuracy: 0.8846
# Epoch 20/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2392 - accuracy: 0.9303 - val_loss: 0.3375 - val_accuracy: 0.8846
# Epoch 21/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2291 - accuracy: 0.9158 - val_loss: 0.3347 - val_accuracy: 0.8846
# Epoch 22/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2392 - accuracy: 0.9256 - val_loss: 0.3018 - val_accuracy: 0.9231
# Epoch 23/500
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2318 - accuracy: 0.9329 - val_loss: 0.2852 - val_accuracy: 0.9231
# Epoch 24/500
# 2/2 [==============================] - 0s 14ms/step - loss: 0.
500
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0978 - accuracy: 0.9783 - val_loss: 0.2889 - val_accuracy: 0.8846
# Epoch 87/500
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0945 - accuracy: 1.0000 - val_loss: 0.3142 - val_accuracy: 0.8846
# Restoring model weights from the end of the best epoch.
# Epoch 00087: early stopping
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f46c867f0d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Classification score:
#  ROC-AUC =  0.9285714285714286

# %%
# define the keras model
model = Sequential()
model.add(Conv1D(32, 3, input_shape=(X_mon_train.shape[1],1), activation='relu', strides = (1),kernel_regularizer=l2(0.005)))
model.add(MaxPooling1D(2, strides = (1)))
model.add(Conv1D(16, 3, strides = (1),kernel_regularizer=l2(0.005), activation='relu'))
model.add(MaxPooling1D(2, strides = (1)))
model.add(Flatten())
model.add(Dense(10, activation='relu'))
model.add(Dropout(0.20))
model.add(Dense(1, activation='sigmoid'))


# Print the model summary
#model.summary()

# to stop the training if validation loss does not improve after patience number of epochs
stop_training = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50, restore_best_weights=True)

# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])


batch_size = 128
tot_epochs = 500


# Entrenamos el modelo
history = model.fit(X_mon_train_cn,
                    y_mon_train,
                    batch_size=batch_size,
                    epochs=tot_epochs,
                    callbacks=[stop_training],
                    verbose=1,
                    validation_data=(X_mon_val_cn, y_mon_val),
                    shuffle=True)


# Plot de la cost function para la train y test data
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.legend(['train', 'test'], loc='upper left')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# Plot de la accuracy function para la train y test data
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


#model.save(root_dir + 'CNN-histo-mix-v2/saved-models/' + 'conv-' + nameMIX_linear +'.h5') # Guardar el modelo.  # Predicción de la red entrenada
y_pred_cnn = model.predict(X_mon_test_cn)

# Compute ROC curve and ROC area for each class
fpr_cnn = dict()
tpr_cnn = dict()
roc_auc_cnn = dict()
fpr_cnn, tpr_cnn, _ = roc_curve(y_mon_test, y_pred_cnn)
roc_auc_cnn = auc(fpr_cnn, tpr_cnn)


plt.figure()
plt.plot(tpr_cnn,1-fpr_cnn,label="$f_{1}$, AUC = %0.2f" % roc_auc_cnn,color="orange",ls=":",lw=4)
plt.plot([1,0],[0,1],ls=":",color="grey")
plt.xlabel("True Positive Rate",fontsize=16)
plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
plt.legend()
plt.xlim([0,1])
plt.ylim([0,1])
plt.yticks([0.2,0.4,0.6,0.8,1.])
plt.legend(frameon=False,fontsize=16)
plt.show()








########################
# CLASSIFICATION SCORE #
########################

# Outputs for validation data set

pred_XG_SM = []
pred_XG_NP = []

for i in range(len(y_mon_test)):
    if y_mon_test[i] == 0:
        pred_XG_SM.append(y_pred_cnn[i,0])
    else:
        pred_XG_NP.append(y_pred_cnn[i,0])
        
        
print('Classification score:')
        
weights = np.ones_like(pred_XG_SM)/float(len(pred_XG_SM))
nSM, binsSM, patchesSM = plt.hist(pred_XG_SM, 50, weights=weights, range=[0,1], histtype='step', color='firebrick', linewidth=2, label='Background')

weights = np.ones_like(pred_XG_NP)/float(len(pred_XG_NP))
nNP, binsNP, patchesNP = plt.hist(pred_XG_NP, 50, weights=weights, range=[0,1], histtype='step', color='forestgreen', linewidth=2, label='Signal')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt
500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1365 - accuracy: 0.9881 - val_loss: 0.3050 - val_accuracy: 0.8846
# Epoch 76/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1334 - accuracy: 0.9855 - val_loss: 0.2714 - val_accuracy: 0.8846
# Epoch 77/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1543 - accuracy: 0.9855 - val_loss: 0.2698 - val_accuracy: 0.9231
# Epoch 78/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1551 - accuracy: 0.9928 - val_loss: 0.2822 - val_accuracy: 0.8846
# Epoch 79/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1383 - accuracy: 0.9928 - val_loss: 0.2956 - val_accuracy: 0.8846
# Epoch 80/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1542 - accuracy: 0.9881 - val_loss: 0.2994 - val_accuracy: 0.8846
# Epoch 81/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1068 - accuracy: 1.0000 - val_loss: 0.2972 - val_accuracy: 0.8846
# Epoch 82/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1121 - accuracy: 1.0000 - val_loss: 0.3008 - val_accuracy: 0.8846
# Epoch 83/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1501 - accuracy: 1.0000 - val_loss: 0.2956 - val_accuracy: 0.8846
# Epoch 84/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1049 - accuracy: 1.0000 - val_loss: 0.2948 - val_accuracy: 0.8846
# Epoch 85/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1241 - accuracy: 0.9928 - val_loss: 0.3255 - val_accuracy: 0.8846
# Epoch 86/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1647 - accuracy: 0.9638 - val_loss: 0.3914 - val_accuracy: 0.8462
# Epoch 87/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0947 - accuracy: 1.0000 - val_loss: 0.4190 - val_accuracy: 0.8462
# Epoch 88/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1082 - accuracy: 1.0000 - val_loss: 0.3946 - val_accuracy: 0.8462
# Epoch 89/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1110 - accuracy: 1.0000 - val_loss: 0.3638 - val_accuracy: 0.8846
# Epoch 90/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1232 - accuracy: 1.0000 - val_loss: 0.3368 - val_accuracy: 0.8846
# Epoch 91/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1472 - accuracy: 0.9928 - val_loss: 0.2966 - val_accuracy: 0.9231
# Epoch 92/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1331 - accuracy: 0.9711 - val_loss: 0.3122 - val_accuracy: 0.8846
# Epoch 93/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1284 - accuracy: 0.9638 - val_loss: 0.3805 - val_accuracy: 0.8846
# Epoch 94/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1198 - accuracy: 0.9855 - val_loss: 0.4523 - val_accuracy: 0.8462
# Epoch 95/500
# 2/2 [==============================] - 0s 21ms/step - loss: 0.1336 - accuracy: 0.9928 - val_loss: 0.4548 - val_accuracy: 0.8462
# Epoch 96/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1353 - accuracy: 0.9855 - val_loss: 0.3905 - val_accuracy: 0.8462
# Epoch 97/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1163 - accuracy: 0.9928 - val_loss: 0.3355 - val_accuracy: 0.8846
# Restoring model weights from the end of the best epoch.
# Epoch 00097: early stopping
# Classification score:
#  ROC-AUC =  0.9285714285714286

# %% [markdown]
# ### GRID

# %%
learning_rate_value = [0.001,0.01,0.05,0.1,0.5]
alpha_value = [0.0, 0.005, 0.01]
lambda_value = [0.0, 0.005, 0.01]
gamma_value = [0.0, 0.005, 0.01]

depth_value = [3,5,10,15]

#estimators = [100,500,1000,1500]
estimators = [2500]

print('Num iterations: ', len(learning_rate_value)*len(alpha_value)*len(lambda_value)*len(gamma_value)*len(depth_value)*len(estimators))
# Out:
# Num iterations:  540

# %%
# ROC_AUC_store = []


ev_count = 0

for i in range(len(learning_rate_value)):
    for j in range(len(alpha_value)):
        for k in range(len(lambda_value)):
            for l in range(len(gamma_value)):
                for m in range(len(depth_value)):
                    for n in range(len(estimators)):
                        
                        ev_count += 1
                        
                        if ev_count > -1:

                            # XGBoost with only the kinematic variables of the leptons

                            # CLASSIFIER
                            classifier = XGBClassifier(
                                n_estimators=estimators[n],
                                learning_rate=learning_rate_value[i],
                                reg_lambda=lambda_value[k],reg_alpha=alpha_value[j],
                                gamma=gamma_value[l],objective='binary:logistic',
                                max_depth=depth_value[m],
                                #early_stopping_rounds=50,
                                eval_metric='logloss')

                            # FIT
                            classifier.fit(X_mon_train,y_mon_train,
                                           eval_set=[(X_mon_train, y_mon_train), (X_mon_val, y_mon_val)],
                                           early_stopping_rounds=50,
                                           verbose=0)

                            # PREDICTIONS
                            y_pred_xg = classifier.predict_proba(X_mon_test).T[1]


                            # ROC
                            fpr_mon_xg, tpr_mon_xg, _ = roc_curve(y_mon_test, y_pred_xg)
                            roc_auc_xg = auc(fpr_mon_xg, tpr_mon_xg)


#                             # PLOT THE ROC WITH AUC
#                             fig = plt.figure(figsize=(6, 6))
#                             gs = gridspec.GridSpec(1, 1) 
#                             ax0 = plt.subplot(gs[0])
#                             ax0.yaxis.set_ticks_position('both')
#                             ax0.xaxis.set_ticks_position('both')
#                             ax0.tick_params(direction="in",which="both")
#                             plt.xticks(fontsize=16)
#                             plt.yticks(fontsize=16)
#                             ax0.minorticks_on()


#                             plt.plot(tpr_mon_xg,1-fpr_mon_xg,label="$f_{1}$, AUC = %0.2f" % roc_auc_xg,color="orange",ls=":",lw=4)
#                             plt.plot([1,0],[0,1],ls=":",color="grey")
#                             plt.xlabel("True Positive Rate",fontsize=16)
#                             plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
#                             plt.legend()
#                             plt.xlim([0,1])
#                             plt.ylim([0,1])
#                             plt.yticks([0.2,0.4,0.6,0.8,1.])
#                             plt.legend(frameon=False,fontsize=16)
#                             plt.show()


#                             ROC_AUC_store.append(roc_auc_xg)



                            with open('gridXGBoostall.dat', 'a') as file:
                                file.write( "%0.4f %0.4f %0.4f %0.4f %0.4f %d %d\n" % (roc_auc_xg, learning_rate_value[i], alpha_value[j], lambda_value[k], gamma_value[l], depth_value[m], estimators[n]) )

                            print(' ')
                            print('roc_auc_xg: ', roc_auc_xg)
                            print('############################### \n')
# Out:
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9279449176019675
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9467990574078928
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9551667418548604
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9536430649263621
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9279449176019675
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9467990574078928
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.955270727389317
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9535826692876624
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9279449176019675
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9467990574078928
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.955285301119525
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.953618906670882
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.927947149614702
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9468270232145081
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.955211119519818
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9534629283691969
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.927947149614702
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9468270232145081
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9551607022909904
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9535296918089333
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.927947149614702
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9468270232145081
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9552782768441546
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9531100077674042
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9279594913321756
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9468317498297105
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9551660853805266
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9535199103413615
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9279594913321756
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9468317498297105
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9553145798748076
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9535495829812444
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9279594913321756
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9468317498297105
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9552742723507189
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9536199570298161
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9279514166978711
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9468057534460964
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9552670511330484
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9534138897364701
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9279514166978711
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9468057534460964
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9551906375206067
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.953453869023392
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9279514166978711
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9468057534460964
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9553237705154793
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9535465631993093
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9279435390058668
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9467968253951582
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9552287130319609
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9534831477786746
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9279435390058668
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9467968253951582
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9550760171019442
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9535330398280353
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9279435390058668
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9467968253951582
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9551700242265289
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9535086189828219
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9279494472748699
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9468043092025623
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.955111729305697
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9537041170393953
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9279494472748699
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9468043092025623
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9551856483156707
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.953493520073147
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9279494472748699
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9468043092025623
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9551361501509104
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9534224895502416
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9279577188514745
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9468026023692946
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9551851231362039
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9535927789924012
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9279577188514745
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9468026023692946
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9551936573025416
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9533296640794575
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9279577188514745
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9468026023692946
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9553512111426279
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9534676549843997
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9279472152621354
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9467994512924929
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9553080151314707
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9533996442434292
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9279472152621354
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9467994512924929
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# ...
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9494311256013961
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9357946437996525
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9329051720199085
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9531614753551657
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9494311256013961
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9394261941662014
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9337442775132333
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9538061331508509
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9507927190169061
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.938323054695866
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9396872083612773
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9538061331508509
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9507927190169061
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9401657781505386
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9377230371548717
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9538061331508509
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9507927190169061
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9416496070869818
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9341270676972089
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9529613163308231
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.949903393237054
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9376666460096077
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9366575136638567
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9529613163308231
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.949903393237054
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9376677620159749
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9363357755929145
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9529613163308231
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.949903393237054
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9373769438861494
# ###############################
# /home/andres/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#
# roc_auc_xg:  0.9401955820852882
# ###############################

# %%
ev_count = 0

for i in range(len(learning_rate_value)):
    for j in range(len(alpha_value)):
        for k in range(len(lambda_value)):
            for l in range(len(gamma_value)):
                for m in range(len(depth_value)):
                    for n in range(len(estimators)):
                        
                        ev_count += 1
                        
                        if ev_count > 262:
                            
                            print(ev_count)
                            print(learning_rate_value[i])
                            print(alpha_value[j])
                            print(lambda_value[k])
                            print(gamma_value[l])
                            print(depth_value[m])
                            print(estimators[n])
                            print('------------------')
                            
                            break
# Out:
# 263
# 0.05
# 0.005
# 0.0
# 0.01
# 10
# 2500
# ------------------
# 264
# 0.05
# 0.005
# 0.0
# 0.01
# 15
# 2500
# ------------------
# 265
# 0.05
# 0.005
# 0.005
# 0.0
# 3
# 2500
# ------------------
# 266
# 0.05
# 0.005
# 0.005
# 0.0
# 5
# 2500
# ------------------
# 267
# 0.05
# 0.005
# 0.005
# 0.0
# 10
# 2500
# ------------------
# 268
# 0.05
# 0.005
# 0.005
# 0.0
# 15
# 2500
# ------------------
# 269
# 0.05
# 0.005
# 0.005
# 0.005
# 3
# 2500
# ------------------
# 270
# 0.05
# 0.005
# 0.005
# 0.005
# 5
# 2500
# ------------------
# 271
# 0.05
# 0.005
# 0.005
# 0.005
# 10
# 2500
# ------------------
# 272
# 0.05
# 0.005
# 0.005
# 0.005
# 15
# 2500
# ------------------
# 273
# 0.05
# 0.005
# 0.005
# 0.01
# 3
# 2500
# ------------------
# 274
# 0.05
# ------------------
# 527
# 0.5
# 0.01
# 0.005
# 0.01
# 10
# 2500
# ------------------
# 528
# 0.5
# 0.01
# 0.005
# 0.01
# 15
# 2500
# ------------------
# 529
# 0.5
# 0.01
# 0.01
# 0.0
# 3
# 2500
# ------------------
# 530
# 0.5
# 0.01
# 0.01
# 0.0
# 5
# 2500
# ------------------
# 531
# 0.5
# 0.01
# 0.01
# 0.0
# 10
# 2500
# ------------------
# 532
# 0.5
# 0.01
# 0.01
# 0.0
# 15
# 2500
# ------------------
# 533
# 0.5
# 0.01
# 0.01
# 0.005
# 3
# 2500
# ------------------
# 534
# 0.5
# 0.01
# 0.01
# 0.005
# 5
# 2500
# ------------------
# 535
# 0.5
# 0.01
# 0.01
# 0.005
# 10
# 2500
# ------------------
# 536
# 0.5
# 0.01
# 0.01
# 0.005
# 15
# 2500
# ------------------
# 537
# 0.5
# 0.01
# 0.01
# 0.01
# 3
# 2500
# ------------------
# 538
# 0.5
# 0.01
# 0.01
# 0.01
# 5
# 2500
# ------------------
# 539
# 0.5
# 0.01
# 0.01
# 0.01
# 10
# 2500
# ------------------
# 540
# 0.5
# 0.01
# 0.01
# 0.01
# 15
# 2500
# ------------------

# %% [markdown]
# ### LOAD AND PLOT

# %%
data_grid_XG = np.loadtxt('gridXGBoostall.dat', delimiter=' ')
print('# classifiers: ', len(data_grid_XG))


index_max = -99
max_roc_auc_grid = -99

for i in range(len(data_grid_XG)):
    if data_grid_XG[i][0] > max_roc_auc_grid:
        index_max = i
        max_roc_auc_grid = data_grid_XG[i][0]
        
print('\nParameters with max ROC-AUC')
print('ROC-AUC: ', data_grid_XG[index_max][0])

print('\nlearning_rate_value: ', data_grid_XG[index_max][1])
print('alpha_value: ', data_grid_XG[index_max][2])
print('lambda_value: ', data_grid_XG[index_max][3])
print('gamma_value: ', data_grid_XG[index_max][4])
print('depth_value: ', data_grid_XG[index_max][5])
print('estimators: ', data_grid_XG[index_max][6])
# Out:
# # classifiers:  540
#
# Parameters with max ROC-AUC
# ROC-AUC:  0.9617
#
# learning_rate_value:  0.01
# alpha_value:  0.0
# lambda_value:  0.01
# gamma_value:  0.0
# depth_value:  5.0
# estimators:  2500.0

# %%
plotus = [i if i == data_grid_XG[index_max][0] else 0 for i in data_grid_XG[:,0]]
print('# model with max ROC-AUC: ', (sum(plotus)/data_grid_XG[index_max][0]))

plt.plot(data_grid_XG[:,0], '.', lw=2, color='r', label="ROC-AUC")
plt.plot(plotus, '.', lw=5, color='blue', marker='x', label="ROC-AUC")

plt.grid()
#plt.title(title,fontsize=14)
plt.xlabel("iteration",fontsize=14)
plt.ylabel("ROC-AUC",fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.xscale('log')
#plt.yscale('log')
plt.ylim([0.925,0.965])
plt.legend(loc='lower right',fontsize=12)
plt.show()
# Out:
# # model with max ROC-AUC:  4.0
# <ipython-input-27-60a35967c3c6>:5: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "." (-> marker='.'). The keyword argument will take precedence.
#   plt.plot(plotus, '.', lw=5, color='blue', marker='x', label="ROC-AUC")
