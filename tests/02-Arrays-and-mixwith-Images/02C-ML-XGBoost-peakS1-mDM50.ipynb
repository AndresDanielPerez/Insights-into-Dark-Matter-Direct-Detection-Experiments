# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import gridspec
from matplotlib import patches
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

import os
import math
import random

import keras
from keras.models import Sequential
from keras.layers import Input, Dense, Conv2D, Flatten, MaxPooling2D
from keras.layers import Dropout
from keras.callbacks import EarlyStopping

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn import preprocessing
from sklearn.metrics import roc_curve, roc_auc_score, auc

import scipy.stats as st
from scipy.stats import poisson
from scipy.interpolate import interp1d
from scipy.stats import norm
# Out:
# 2023-05-18 02:10:01.354020: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-18 02:10:01.489441: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-05-18 02:10:01.872764: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/andres/installROOT/lib
# 2023-05-18 02:10:01.872828: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/andres/installROOT/lib
# 2023-05-18 02:10:01.872833: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
from sklearn.neighbors import KernelDensity # paquete necesario
from sklearn.model_selection import GridSearchCV

import scipy.integrate as integrate

# %%
# !pip install xgboost

import xgboost
from xgboost import XGBRegressor, XGBClassifier
# Out:
# Requirement already satisfied: xgboost in /home/andres/anaconda3/lib/python3.9/site-packages (1.7.4)
# Requirement already satisfied: scipy in /home/andres/anaconda3/lib/python3.9/site-packages (from xgboost) (1.10.0)
# Requirement already satisfied: numpy in /home/andres/anaconda3/lib/python3.9/site-packages (from xgboost) (1.23.5)

# %%
import h5py

import glob
import numpy as np
import os.path as path
import imageio
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D
from keras.callbacks import EarlyStopping, TensorBoard
from datetime import datetime
import keras
from keras import regularizers
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score, average_precision_score, precision_recall_curve, auc,recall_score
from keras.optimizers import Adam
from keras.regularizers import l2
import h5py
from sklearn.model_selection import GridSearchCV
from keras.backend import cast, greater, clip, floatx,epsilon
from keras.wrappers.scikit_learn import KerasClassifier
from keras import backend as K
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# ### Load Data

# %%
filefolder = '../../data2024/processed/'

###################
# BACKGROUND FILE #
###################

filename_B = 'ER/ER_all.hdf5'


###############
# SIGNAL FILE #
###############

# select the DM mass
mDM = 50

filename_S = 'mDM' + str(mDM) + 'GeV/WP_mDM' + str(mDM) + 'GeV_sig1045.hdf5'

# %%
# OPEN THE SAVED FILE TO CHECK IT
f_B = h5py.File(filefolder+filename_B,'r')
f_S = h5py.File(filefolder+filename_S,'r')

# show the groups
print( f_B.keys() )

# should be more than 10k events in each group
print('\n Background Events: ')
for groups1 in f_B.keys():
    print(len(f_B[groups1].keys()))

print('\n Signal Events')
for groups1 in f_S.keys():
    print(len(f_S[groups1].keys()))
# Out:
# <KeysViewHDF5 ['HITS_bot', 'HITS_bot_img', 'HITS_top', 'HITS_top_img', 'peakS1_onlyhits', 'peakS1_raw', 'peakS2_onlyhits', 'peakS2_raw']>
#
#  Background Events:
# 17206
# 17206
# 17206
# 17206
# 17206
# 17206
# 17206
# 17206
#
#  Signal Events
# 12157
# 12157
# 12157
# 12157
# 12157
# 12157
# 12157
# 12157

# %%
#############################
# ONLY peakS1_onlyhits DATA #
#############################

# to normalize
scaler = preprocessing.MinMaxScaler()

# Number of data points (per-class) for the ML classifier
num_data = 10000


# First:
# The max len for the time series

max_pS1_B = 0
max_pS1_S = 0

for i in range(1, num_data+1):
    max_pS1_B = max(max_pS1_B, len( f_B['peakS1_onlyhits/ev_'+str(i)] ))
    max_pS1_S = max(max_pS1_S, len( f_S['peakS1_onlyhits/ev_'+str(i)] ))
    
    
max_pS1_both = max(max_pS1_B,max_pS1_S)

print('max_pS1_both lenght: ', max_pS1_both)



# Second:
# add the events in a matrix, but all with the same length -> fill with zeros

# how many elements do we need to make all the peak (S1 or S2) arrays with the same length
diff_elem_S1_B = max_pS1_both - len( f_B['peakS1_onlyhits/ev_1'][()] )
diff_elem_S1_S = max_pS1_both - len( f_S['peakS1_onlyhits/ev_1'][()] )

# add zeros at the end
peakS1_onlyhits_B = np.pad(f_B['peakS1_onlyhits/ev_1'][()], (0, diff_elem_S1_B), 'constant')
peakS1_onlyhits_S = np.pad(f_S['peakS1_onlyhits/ev_1'][()], (0, diff_elem_S1_S), 'constant')

for i in range(2, num_data+1):
    
    # how many elements do we need to make all the peak (S1 or S2) arrays with the same length
    diff_elem_S1_B = max_pS1_both - len( f_B['peakS1_onlyhits/ev_'+str(i)][()] )
    diff_elem_S1_S = max_pS1_both - len( f_S['peakS1_onlyhits/ev_'+str(i)][()] )
    
    # add zeros at the end
    aux_S1_B = np.pad(f_B['peakS1_onlyhits/ev_'+str(i)][()], (0, diff_elem_S1_B), 'constant')
    aux_S1_S = np.pad(f_S['peakS1_onlyhits/ev_'+str(i)][()], (0, diff_elem_S1_S), 'constant')
    
    # add new event to the matrix as a row
    peakS1_onlyhits_B = np.row_stack([peakS1_onlyhits_B,aux_S1_B])
    peakS1_onlyhits_S = np.row_stack([peakS1_onlyhits_S,aux_S1_S])
    
    
    

# close the h5 files
f_B.close()
f_S.close()
    
    
    

# X and Y for the classifier
X_mon = np.row_stack([peakS1_onlyhits_B,peakS1_onlyhits_S])
# normalize
X_mon = scaler.fit_transform(X_mon)

del peakS1_onlyhits_B
del peakS1_onlyhits_S

# labels
y_mon = np.concatenate([np.zeros(num_data),np.ones(num_data)])



# divide into train-val and test data samples
test_ratio = 1./3
val_ratio = 0.25


X_mon_aux, X_mon_test, y_mon_aux, y_mon_test = train_test_split(X_mon,
                                                                y_mon,
                                                                test_size=test_ratio,
                                                                random_state=42,
                                                                #stratify = y_mon,
                                                                shuffle=True)

del X_mon
del y_mon

X_mon_train, X_mon_val, y_mon_train, y_mon_val = train_test_split(X_mon_aux,
                                                                  y_mon_aux,
                                                                  test_size=val_ratio,
                                                                  random_state=42,
                                                                  #stratify = y_mon_aux,
                                                                  shuffle=True)

del X_mon_aux
del y_mon_aux

print('')
print('X_mon_train : ', X_mon_train.shape)
print('y_mon_train : ', y_mon_train.shape)
print('X_mon_val : ', X_mon_val.shape)
print('y_mon_val : ', y_mon_val.shape)
print('X_mon_test : ', X_mon_test.shape)
print('y_mon_test : ', y_mon_test.shape)
print('')
# Out:
# max_pS1_both lenght:  169
#
# X_mon_train :  (9999, 169)
# y_mon_train :  (9999,)
# X_mon_val :  (3334, 169)
# y_mon_val :  (3334,)
# X_mon_test :  (6667, 169)
# y_mon_test :  (6667,)

# %% [markdown]
# ### CLASSIFIER

# %%
# XGBoost with only the kinematic variables of the leptons

# CLASSIFIER
classifier = XGBClassifier(
    n_estimators=500,
    learning_rate=0.1,
    reg_lambda=0.0,reg_alpha=0.0,
    gamma=0.0,objective='binary:logistic',
    max_depth=5)

# FIT
classifier.fit(X_mon_train,y_mon_train,eval_set=[(X_mon_train, y_mon_train), (X_mon_val, y_mon_val)],
        eval_metric=["error", "logloss", "map"],early_stopping_rounds=50,#early stopping
        verbose=True)

# PREDICTIONS
y_pred_xg = classifier.predict_proba(X_mon_test).T[1]


# ROC
fpr_mon_xg, tpr_mon_xg, _ = roc_curve(y_mon_test, y_pred_xg)
roc_auc_xg = auc(fpr_mon_xg, tpr_mon_xg)


# PLOT THE ROC WITH AUC
fig = plt.figure(figsize=(6, 6))
gs = gridspec.GridSpec(1, 1) 
ax0 = plt.subplot(gs[0])
ax0.yaxis.set_ticks_position('both')
ax0.xaxis.set_ticks_position('both')
ax0.tick_params(direction="in",which="both")
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
ax0.minorticks_on()


plt.plot(tpr_mon_xg,1-fpr_mon_xg,label="$f_{1}$, AUC = %0.2f" % roc_auc_xg,color="orange",ls=":",lw=4)
plt.plot([1,0],[0,1],ls=":",color="grey")
plt.xlabel("True Positive Rate",fontsize=16)
plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
plt.legend()
plt.xlim([0,1])
plt.ylim([0,1])
plt.yticks([0.2,0.4,0.6,0.8,1.])
plt.legend(frameon=False,fontsize=16)
plt.show()
# Out:
# [0]	validation_0-error:0.24482	validation_0-logloss:0.66296	validation_0-map:0.75520	validation_1-error:0.25435	validation_1-logloss:0.66438	validation_1-map:0.75131
# [1]	validation_0-error:0.23852	validation_0-logloss:0.63801	validation_0-map:0.76704	validation_1-error:0.25645	validation_1-logloss:0.64129	validation_1-map:0.75829
# /home/andres/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# /home/andres/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [2]	validation_0-error:0.23602	validation_0-logloss:0.61691	validation_0-map:0.76947	validation_1-error:0.25195	validation_1-logloss:0.62175	validation_1-map:0.76266
# [3]	validation_0-error:0.23672	validation_0-logloss:0.59917	validation_0-map:0.77708	validation_1-error:0.25435	validation_1-logloss:0.60591	validation_1-map:0.76921
# [4]	validation_0-error:0.23662	validation_0-logloss:0.58403	validation_0-map:0.77855	validation_1-error:0.25075	validation_1-logloss:0.59243	validation_1-map:0.77006
# [5]	validation_0-error:0.23402	validation_0-logloss:0.57085	validation_0-map:0.77998	validation_1-error:0.25135	validation_1-logloss:0.58065	validation_1-map:0.77085
# [6]	validation_0-error:0.23172	validation_0-logloss:0.55950	validation_0-map:0.78154	validation_1-error:0.25015	validation_1-logloss:0.57084	validation_1-map:0.76887
# [7]	validation_0-error:0.23122	validation_0-logloss:0.54957	validation_0-map:0.78294	validation_1-error:0.25195	validation_1-logloss:0.56320	validation_1-map:0.76945
# [8]	validation_0-error:0.23012	validation_0-logloss:0.54089	validation_0-map:0.78691	validation_1-error:0.24865	validation_1-logloss:0.55614	validation_1-map:0.76624
# [9]	validation_0-error:0.22832	validation_0-logloss:0.53318	validation_0-map:0.79056	validation_1-error:0.24955	validation_1-logloss:0.55039	validation_1-map:0.76438
# [10]	validation_0-error:0.22762	validation_0-logloss:0.52656	validation_0-map:0.79162	validation_1-error:0.25165	validation_1-logloss:0.54563	validation_1-map:0.76305
# [11]	validation_0-error:0.22842	validation_0-logloss:0.52051	validation_0-map:0.79397	validation_1-error:0.25165	validation_1-logloss:0.54172	validation_1-map:0.75730
# [12]	validation_0-error:0.22612	validation_0-logloss:0.51498	validation_0-map:0.79502	validation_1-error:0.24985	validation_1-logloss:0.53801	validation_1-map:0.76628
# [13]	validation_0-error:0.22562	validation_0-logloss:0.51006	validation_0-map:0.79716	validation_1-error:0.24835	validation_1-logloss:0.53529	validation_1-map:0.76622
# [14]	validation_0-error:0.22502	validation_0-logloss:0.50578	validation_0-map:0.79653	validation_1-error:0.24805	validation_1-logloss:0.53257	validation_1-map:0.77037
# [15]	validation_0-error:0.22372	validation_0-logloss:0.50193	validation_0-map:0.79875	validation_1-error:0.24895	validation_1-logloss:0.53073	validation_1-map:0.76899
# [16]	validation_0-error:0.22322	validation_0-logloss:0.49830	validation_0-map:0.80090	validation_1-error:0.24895	validation_1-logloss:0.52866	validation_1-map:0.77203
# [17]	validation_0-error:0.22202	validation_0-logloss:0.49472	validation_0-map:0.80162	validation_1-error:0.25045	validation_1-logloss:0.52764	validation_1-map:0.77206
# [18]	validation_0-error:0.22082	validation_0-logloss:0.49178	validation_0-map:0.80215	validation_1-error:0.25045	validation_1-logloss:0.52620	validation_1-map:0.77192
# [19]	validation_0-error:0.22002	validation_0-logloss:0.48891	validation_0-map:0.80483	validation_1-error:0.25105	validation_1-logloss:0.52518	validation_1-map:0.77003
# [20]	validation_0-error:0.21932	validation_0-logloss:0.48667	validation_0-map:0.80511	validation_1-error:0.25165	validation_1-logloss:0.52452	validation_1-map:0.76984
# [21]	validation_0-error:0.21952	validation_0-logloss:0.48406	validation_0-map:0.80571	validation_1-error:0.25075	validation_1-logloss:0.52395	validation_1-map:0.76801
# [22]	validation_0-error:0.21832	validation_0-logloss:0.48195	validation_0-map:0.80713	validation_1-error:0.25105	validation_1-logloss:0.52314	validation_1-map:0.76832
# [23]	validation_0-error:0.21832	validation_0-logloss:0.47963	validation_0-map:0.80725	validation_1-error:0.25075	validation_1-logloss:0.52239	validation_1-map:0.76878
# [24]	validation_0-error:0.21722	validation_0-logloss:0.47776	validation_0-map:0.80720	validation_1-error:0.25075	validation_1-logloss:0.52204	validation_1-map:0.76927
# [25]	validation_0-error:0.21642	validation_0-logloss:0.47582	validation_0-map:0.80971	validation_1-error:0.25195	validation_1-logloss:0.52190	validation_1-map:0.76684
# [26]	validation_0-error:0.21572	validation_0-logloss:0.47404	validation_0-map:0.81227	validation_1-error:0.25225	validation_1-logloss:0.52164	validation_1-map:0.76137
# [27]	validation_0-error:0.21572	validation_0-logloss:0.47251	validation_0-map:0.81539	validation_1-error:0.25225	validation_1-logloss:0.52158	validation_1-map:0.76047
# [28]	validation_0-error:0.21552	validation_0-logloss:0.47091	validation_0-map:0.81822	validation_1-error:0.25315	validation_1-logloss:0.52132	validation_1-map:0.76030
# [29]	validation_0-error:0.21582	validation_0-logloss:0.46945	validation_0-map:0.81806	validation_1-error:0.25255	validation_1-logloss:0.52091	validation_1-map:0.76134
# [30]	validation_0-error:0.21502	validation_0-logloss:0.46752	validation_0-map:0.81882	validation_1-error:0.25345	validation_1-logloss:0.52058	validation_1-map:0.76123
# [31]	validation_0-error:0.21452	validation_0-logloss:0.46633	validation_0-map:0.81937	validation_1-error:0.25255	validation_1-logloss:0.52039	validation_1-map:0.76099
# [32]	validation_0-error:0.21472	validation_0-logloss:0.46509	validation_0-map:0.81954	validation_1-error:0.25285	validation_1-logloss:0.52045	validation_1-map:0.76078
# [33]	validation_0-error:0.21372	validation_0-logloss:0.46390	validation_0-map:0.82244	validation_1-error:0.25195	validation_1-logloss:0.52045	validation_1-map:0.75957
# [34]	validation_0-error:0.21302	validation_0-logloss:0.46280	validation_0-map:0.82413	validation_1-error:0.25195	validation_1-logloss:0.52031	validation_1-map:0.76066
# [35]	validation_0-error:0.21292	validation_0-logloss:0.46161	validation_0-map:0.82532	validation_1-error:0.25285	validation_1-logloss:0.52003	validation_1-map:0.76107
# [36]	validation_0-error:0.21232	validation_0-logloss:0.46012	validation_0-map:0.82709	validation_1-error:0.25315	validation_1-logloss:0.52013	validation_1-map:0.76069
# [37]	validation_0-error:0.21212	validation_0-logloss:0.45898	validation_0-map:0.82855	validation_1-error:0.25405	validation_1-logloss:0.52003	validation_1-map:0.76099
# [38]	validation_0-error:0.21172	validation_0-logloss:0.45789	validation_0-map:0.82877	validation_1-error:0.25345	validation_1-logloss:0.52029	validation_1-map:0.76097
# [39]	validation_0-error:0.21092	validation_0-logloss:0.45633	validation_0-map:0.82919	validation_1-error:0.25315	validation_1-logloss:0.52027	validation_1-map:0.76028
# [40]	validation_0-error:0.21062	validation_0-logloss:0.45552	validation_0-map:0.82996	validation_1-error:0.25255	validation_1-logloss:0.52029	validation_1-map:0.75990
# [41]	validation_0-error:0.20982	validation_0-logloss:0.45430	validation_0-map:0.83126	validation_1-error:0.25165	validation_1-logloss:0.52072	validation_1-map:0.75947
# [42]	validation_0-error:0.20942	validation_0-logloss:0.45394	validation_0-map:0.83149	validation_1-error:0.25195	validation_1-logloss:0.52087	validation_1-map:0.75946
# [43]	validation_0-error:0.20912	validation_0-logloss:0.45234	validation_0-map:0.83659	validation_1-error:0.25165	validation_1-logloss:0.52115	validation_1-map:0.76027
# [44]	validation_0-error:0.20862	validation_0-logloss:0.45161	validation_0-map:0.83681	validation_1-error:0.25075	validation_1-logloss:0.52116	validation_1-map:0.76023
# [45]	validation_0-error:0.20722	validation_0-logloss:0.45011	validation_0-map:0.83879	validation_1-error:0.25225	validation_1-logloss:0.52115	validation_1-map:0.76005
# [46]	validation_0-error:0.20732	validation_0-logloss:0.44965	validation_0-map:0.84007	validation_1-error:0.25225	validation_1-logloss:0.52129	validation_1-map:0.75872
# [47]	validation_0-error:0.20682	validation_0-logloss:0.44819	validation_0-map:0.84380	validation_1-error:0.25285	validation_1-logloss:0.52152	validation_1-map:0.75785
# [48]	validation_0-error:0.20662	validation_0-logloss:0.44784	validation_0-map:0.84433	validation_1-error:0.25225	validation_1-logloss:0.52156	validation_1-map:0.75751
# [49]	validation_0-error:0.20642	validation_0-logloss:0.44731	validation_0-map:0.84507	validation_1-error:0.25225	validation_1-logloss:0.52166	validation_1-map:0.75805
# [50]	validation_0-error:0.20622	validation_0-logloss:0.44696	validation_0-map:0.84531	validation_1-error:0.25255	validation_1-logloss:0.52156	validation_1-map:0.75806
# [51]	validation_0-error:0.20622	validation_0-logloss:0.44610	validation_0-map:0.84680	validation_1-error:0.25405	validation_1-logloss:0.52175	validation_1-map:0.75733
# [52]	validation_0-error:0.20572	validation_0-logloss:0.44496	validation_0-map:0.84754	validation_1-error:0.25435	validation_1-logloss:0.52182	validation_1-map:0.75722
# [53]	validation_0-error:0.20582	validation_0-logloss:0.44446	validation_0-map:0.84884	validation_1-error:0.25375	validation_1-logloss:0.52190	validation_1-map:0.75728
# [54]	validation_0-error:0.20552	validation_0-logloss:0.44380	validation_0-map:0.84895	validation_1-error:0.25465	validation_1-logloss:0.52224	validation_1-map:0.75723
# [55]	validation_0-error:0.20562	validation_0-logloss:0.44348	validation_0-map:0.84962	validation_1-error:0.25435	validation_1-logloss:0.52213	validation_1-map:0.75850
# [56]	validation_0-error:0.20522	validation_0-logloss:0.44301	validation_0-map:0.85030	validation_1-error:0.25495	validation_1-logloss:0.52242	validation_1-map:0.75731
# [57]	validation_0-error:0.20402	validation_0-logloss:0.44218	validation_0-map:0.85094	validation_1-error:0.25435	validation_1-logloss:0.52254	validation_1-map:0.75719
# [58]	validation_0-error:0.20412	validation_0-logloss:0.44177	validation_0-map:0.85115	validation_1-error:0.25435	validation_1-logloss:0.52237	validation_1-map:0.75732
# [59]	validation_0-error:0.20432	validation_0-logloss:0.44137	validation_0-map:0.85172	validation_1-error:0.25495	validation_1-logloss:0.52261	validation_1-map:0.75650
# [60]	validation_0-error:0.20272	validation_0-logloss:0.44054	validation_0-map:0.85271	validation_1-error:0.25435	validation_1-logloss:0.52266	validation_1-map:0.75748
# [61]	validation_0-error:0.20272	validation_0-logloss:0.44019	validation_0-map:0.85316	validation_1-error:0.25435	validation_1-logloss:0.52281	validation_1-map:0.75749
# [62]	validation_0-error:0.20252	validation_0-logloss:0.43991	validation_0-map:0.85352	validation_1-error:0.25435	validation_1-logloss:0.52310	validation_1-map:0.75678
# [63]	validation_0-error:0.20162	validation_0-logloss:0.43883	validation_0-map:0.85394	validation_1-error:0.25375	validation_1-logloss:0.52336	validation_1-map:0.75665
# [64]	validation_0-error:0.20142	validation_0-logloss:0.43833	validation_0-map:0.85507	validation_1-error:0.25405	validation_1-logloss:0.52329	validation_1-map:0.75759
# [65]	validation_0-error:0.20062	validation_0-logloss:0.43760	validation_0-map:0.85564	validation_1-error:0.25315	validation_1-logloss:0.52312	validation_1-map:0.75779
# [66]	validation_0-error:0.20082	validation_0-logloss:0.43600	validation_0-map:0.86015	validation_1-error:0.25285	validation_1-logloss:0.52323	validation_1-map:0.75720

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import auc, precision_recall_curve

precision_xg, recall_xg, _ = precision_recall_curve(y_mon_test, y_pred_xg)
auc_xg = auc(recall_xg, precision_xg)

plt.figure(figsize=(6, 6))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.plot(recall_xg, precision_xg, label=f'AP (XGBoost) = {auc_xg:.2f}')
plt.title('Precision-Recall Curve', size=16)
plt.xlabel('Recall', size=16)
plt.ylabel('Precision', size=16)
plt.legend(frameon=False,fontsize=16)
plt.show()

# %%
predictions = [round(value) for value in y_pred_xg]
accuracy = accuracy_score(y_mon_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))

results = classifier.evals_result()
epochs = len(results["validation_0"]["error"])
x_axis = range(0, epochs)


# plot log loss
fig, ax = plt.subplots(figsize=(7,5))
ax.plot(x_axis, results["validation_0"]["logloss"], label="Train")
ax.plot(x_axis, results["validation_1"]["logloss"], label="Validation")
ax.legend()
plt.ylabel("Log Loss")
plt.title("XGBoost Log Loss")
plt.show()

# plot classification error
fig, ax = plt.subplots(figsize=(7,5))
ax.plot(x_axis, results["validation_0"]["error"], label="Train")
ax.plot(x_axis, results["validation_1"]["error"], label="Validation")
ax.legend()
plt.ylabel("Classification Error")
plt.title("XGBoost Classification Error")
plt.show()
# Out:
# Accuracy: 74.61%

# %%
# XGBoost with the kinematic variables of the leptons

########################
# CLASSIFICATION SCORE #
########################

# Outputs for validation data set

pred_XG_SM = []
pred_XG_NP = []

for i in range(len(y_mon_test)):
    if y_mon_test[i] == 0:
        pred_XG_SM.append(y_pred_xg[i])
    else:
        pred_XG_NP.append(y_pred_xg[i])
        
        
print('Classification score:')
        
weights = np.ones_like(pred_XG_SM)/float(len(pred_XG_SM))
nSM, binsSM, patchesSM = plt.hist(pred_XG_SM, 50, weights=weights, range=[0,1], histtype='step', color='firebrick', linewidth=2, label='Background')

weights = np.ones_like(pred_XG_NP)/float(len(pred_XG_NP))
nNP, binsNP, patchesNP = plt.hist(pred_XG_NP, 50, weights=weights, range=[0,1], histtype='step', color='forestgreen', linewidth=2, label='Signal')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Classication score (XGBoost)",fontsize=15)
plt.ylabel("Fraction of events",fontsize=14)
plt.grid()
plt.legend(fontsize=12)

plt.show()
# Out:
# Classification score:
