# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import gridspec
from matplotlib import patches
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

import os
import math
import random

import keras
from keras.models import Sequential
from keras.layers import Input, Dense, Conv2D, Flatten, MaxPooling2D
from keras.layers import Dropout
from keras.callbacks import EarlyStopping

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn import preprocessing
from sklearn.metrics import roc_curve, roc_auc_score, auc

import scipy.stats as st
from scipy.stats import poisson
from scipy.interpolate import interp1d
from scipy.stats import norm
# Out:
# 2023-04-25 03:10:07.081335: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-25 03:10:07.189228: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-25 03:10:07.546085: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/andres/installROOT/lib
# 2023-04-25 03:10:07.546148: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/andres/installROOT/lib
# 2023-04-25 03:10:07.546152: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
from sklearn.neighbors import KernelDensity # paquete necesario
from sklearn.model_selection import GridSearchCV

import scipy.integrate as integrate

# %%
# !pip install xgboost

import xgboost
from xgboost import XGBRegressor, XGBClassifier
# Out:
# Requirement already satisfied: xgboost in /home/andres/anaconda3/lib/python3.9/site-packages (1.7.4)
# Requirement already satisfied: scipy in /home/andres/anaconda3/lib/python3.9/site-packages (from xgboost) (1.10.0)
# Requirement already satisfied: numpy in /home/andres/anaconda3/lib/python3.9/site-packages (from xgboost) (1.23.5)

# %%
import h5py

import glob
import numpy as np
import os.path as path
import imageio
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D
from keras.callbacks import EarlyStopping, TensorBoard
from datetime import datetime
import keras
from keras import regularizers
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score, average_precision_score, precision_recall_curve, auc,recall_score
from keras.optimizers import Adam
from keras.regularizers import l2
import h5py
from sklearn.model_selection import GridSearchCV
from keras.backend import cast, greater, clip, floatx,epsilon
from keras.wrappers.scikit_learn import KerasClassifier
from keras import backend as K
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# ### Load Data

# %%
filefolder = '../../data2024/processed/'

###################
# BACKGROUND FILE #
###################

filename_B = 'ER/ER_all.hdf5'


###############
# SIGNAL FILE #
###############

# select the DM mass
mDM = 500

filename_S = 'mDM' + str(mDM) + 'GeV/WP_mDM' + str(mDM) + 'GeV_sig1045.hdf5'

# %%
# OPEN THE SAVED FILE TO CHECK IT
f_B = h5py.File(filefolder+filename_B,'r')
f_S = h5py.File(filefolder+filename_S,'r')

# show the groups
print( f_B.keys() )

# should be more than 10k events in each group
print('\n Background Events: ')
for groups1 in f_B.keys():
    print(len(f_B[groups1].keys()))

print('\n Signal Events')
for groups1 in f_S.keys():
    print(len(f_S[groups1].keys()))
# Out:
# <KeysViewHDF5 ['HITS_bot', 'HITS_bot_img', 'HITS_top', 'HITS_top_img', 'peakS1_onlyhits', 'peakS1_raw', 'peakS2_onlyhits', 'peakS2_raw']>
#
#  Background Events:
# 17206
# 17206
# 17206
# 17206
# 17206
# 17206
# 17206
# 17206
#
#  Signal Events
# 12286
# 12286
# 12286
# 12286
# 12286
# 12286
# 12286
# 12286

# %%
######################
# ONLY HITS_top DATA #
######################

# to normalize
scaler = preprocessing.MinMaxScaler()

# Number of data points (per-class) for the ML classifier
num_data = 10000



hits_top_B = np.array( f_B['HITS_top/ev_1'] )
hits_top_S = np.array( f_S['HITS_top/ev_1'] )


for i in range(2,num_data+1):
    # add new event to the matrix as a row
    hits_top_B = np.row_stack([hits_top_B,np.array( f_B['HITS_top/ev_'+str(i)] )])
    hits_top_S = np.row_stack([hits_top_S,np.array( f_S['HITS_top/ev_'+str(i)] )])
    
    

# close the h5 files
f_B.close()
f_S.close()



# X and Y for the classifier
X_mon = np.row_stack([hits_top_B,hits_top_S])
# normalize
X_mon = scaler.fit_transform(X_mon)

del hits_top_B
del hits_top_S

# labels
y_mon = np.concatenate([np.zeros(num_data),np.ones(num_data)])



# divide into train-val and test data samples
test_ratio = 1./3
val_ratio = 0.25


X_mon_aux, X_mon_test, y_mon_aux, y_mon_test = train_test_split(X_mon,
                                                                y_mon,
                                                                test_size=test_ratio,
                                                                random_state=42,
                                                                #stratify = y_mon,
                                                                shuffle=True)

del X_mon
del y_mon

X_mon_train, X_mon_val, y_mon_train, y_mon_val = train_test_split(X_mon_aux,
                                                                  y_mon_aux,
                                                                  test_size=val_ratio,
                                                                  random_state=42,
                                                                  #stratify = y_mon_aux,
                                                                  shuffle=True)

del X_mon_aux
del y_mon_aux

print('')
print('X_mon_train : ', X_mon_train.shape)
print('y_mon_train : ', y_mon_train.shape)
print('X_mon_val : ', X_mon_val.shape)
print('y_mon_val : ', y_mon_val.shape)
print('X_mon_test : ', X_mon_test.shape)
print('y_mon_test : ', y_mon_test.shape)
print('')
# Out:
# X_mon_train :  (9999, 127)
# y_mon_train :  (9999,)
# X_mon_val :  (3334, 127)
# y_mon_val :  (3334,)
# X_mon_test :  (6667, 127)
# y_mon_test :  (6667,)

# %% [markdown]
# ### CLASSIFIER

# %%
# XGBoost with only the kinematic variables of the leptons

# CLASSIFIER
classifier = XGBClassifier(
    n_estimators=500,
    learning_rate=0.1,
    reg_lambda=0.0,reg_alpha=0.0,
    gamma=0.0,objective='binary:logistic',
    max_depth=5)

# FIT
classifier.fit(X_mon_train,y_mon_train,eval_set=[(X_mon_train, y_mon_train), (X_mon_val, y_mon_val)],
        eval_metric=["error", "logloss", "map"],early_stopping_rounds=50,#early stopping
        verbose=True)

# PREDICTIONS
y_pred_xg = classifier.predict_proba(X_mon_test).T[1]


# ROC
fpr_mon_xg, tpr_mon_xg, _ = roc_curve(y_mon_test, y_pred_xg)
roc_auc_xg = auc(fpr_mon_xg, tpr_mon_xg)


# PLOT THE ROC WITH AUC
fig = plt.figure(figsize=(6, 6))
gs = gridspec.GridSpec(1, 1) 
ax0 = plt.subplot(gs[0])
ax0.yaxis.set_ticks_position('both')
ax0.xaxis.set_ticks_position('both')
ax0.tick_params(direction="in",which="both")
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
ax0.minorticks_on()


plt.plot(tpr_mon_xg,1-fpr_mon_xg,label="$f_{1}$, AUC = %0.2f" % roc_auc_xg,color="orange",ls=":",lw=4)
plt.plot([1,0],[0,1],ls=":",color="grey")
plt.xlabel("True Positive Rate",fontsize=16)
plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
plt.legend()
plt.xlim([0,1])
plt.ylim([0,1])
plt.yticks([0.2,0.4,0.6,0.8,1.])
plt.legend(frameon=False,fontsize=16)
plt.show()
# Out:
# [0]	validation_0-error:0.21282	validation_0-logloss:0.65670	validation_0-map:0.83901	validation_1-error:0.24895	validation_1-logloss:0.66079	validation_1-map:0.79975
# [1]	validation_0-error:0.19092	validation_0-logloss:0.62525	validation_0-map:0.87068	validation_1-error:0.22855	validation_1-logloss:0.63376	validation_1-map:0.81826
# /home/andres/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# /home/andres/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [2]	validation_0-error:0.17752	validation_0-logloss:0.59746	validation_0-map:0.88986	validation_1-error:0.22106	validation_1-logloss:0.60927	validation_1-map:0.84570
# [3]	validation_0-error:0.16942	validation_0-logloss:0.57238	validation_0-map:0.90161	validation_1-error:0.21086	validation_1-logloss:0.58761	validation_1-map:0.85511
# [4]	validation_0-error:0.16572	validation_0-logloss:0.55024	validation_0-map:0.90649	validation_1-error:0.20966	validation_1-logloss:0.56901	validation_1-map:0.86188
# [5]	validation_0-error:0.16112	validation_0-logloss:0.53024	validation_0-map:0.91090	validation_1-error:0.20756	validation_1-logloss:0.55357	validation_1-map:0.86479
# [6]	validation_0-error:0.15782	validation_0-logloss:0.51175	validation_0-map:0.91626	validation_1-error:0.20756	validation_1-logloss:0.53902	validation_1-map:0.86834
# [7]	validation_0-error:0.15282	validation_0-logloss:0.49519	validation_0-map:0.91958	validation_1-error:0.20636	validation_1-logloss:0.52553	validation_1-map:0.87151
# [8]	validation_0-error:0.14971	validation_0-logloss:0.47989	validation_0-map:0.92455	validation_1-error:0.20486	validation_1-logloss:0.51348	validation_1-map:0.87389
# [9]	validation_0-error:0.14811	validation_0-logloss:0.46622	validation_0-map:0.92704	validation_1-error:0.20276	validation_1-logloss:0.50398	validation_1-map:0.87507
# [10]	validation_0-error:0.14641	validation_0-logloss:0.45392	validation_0-map:0.92877	validation_1-error:0.19916	validation_1-logloss:0.49523	validation_1-map:0.87512
# [11]	validation_0-error:0.14491	validation_0-logloss:0.44257	validation_0-map:0.93034	validation_1-error:0.19766	validation_1-logloss:0.48666	validation_1-map:0.87728
# [12]	validation_0-error:0.14471	validation_0-logloss:0.43217	validation_0-map:0.93228	validation_1-error:0.19676	validation_1-logloss:0.47971	validation_1-map:0.87758
# [13]	validation_0-error:0.14211	validation_0-logloss:0.42236	validation_0-map:0.93362	validation_1-error:0.19736	validation_1-logloss:0.47329	validation_1-map:0.87706
# [14]	validation_0-error:0.14311	validation_0-logloss:0.41349	validation_0-map:0.93502	validation_1-error:0.19736	validation_1-logloss:0.46792	validation_1-map:0.87734
# [15]	validation_0-error:0.14111	validation_0-logloss:0.40522	validation_0-map:0.93602	validation_1-error:0.19946	validation_1-logloss:0.46189	validation_1-map:0.87819
# [16]	validation_0-error:0.13891	validation_0-logloss:0.39768	validation_0-map:0.93679	validation_1-error:0.19706	validation_1-logloss:0.45684	validation_1-map:0.87890
# [17]	validation_0-error:0.13731	validation_0-logloss:0.39067	validation_0-map:0.93798	validation_1-error:0.19706	validation_1-logloss:0.45256	validation_1-map:0.88023
# [18]	validation_0-error:0.13731	validation_0-logloss:0.38417	validation_0-map:0.93893	validation_1-error:0.19706	validation_1-logloss:0.44926	validation_1-map:0.88026
# [19]	validation_0-error:0.13631	validation_0-logloss:0.37778	validation_0-map:0.94006	validation_1-error:0.19766	validation_1-logloss:0.44537	validation_1-map:0.88111
# [20]	validation_0-error:0.13551	validation_0-logloss:0.37203	validation_0-map:0.94113	validation_1-error:0.20006	validation_1-logloss:0.44200	validation_1-map:0.88138
# [21]	validation_0-error:0.13421	validation_0-logloss:0.36652	validation_0-map:0.94196	validation_1-error:0.19796	validation_1-logloss:0.43849	validation_1-map:0.88174
# [22]	validation_0-error:0.13271	validation_0-logloss:0.36167	validation_0-map:0.94282	validation_1-error:0.19826	validation_1-logloss:0.43573	validation_1-map:0.88205
# [23]	validation_0-error:0.13291	validation_0-logloss:0.35672	validation_0-map:0.94362	validation_1-error:0.19916	validation_1-logloss:0.43312	validation_1-map:0.88231
# [24]	validation_0-error:0.13351	validation_0-logloss:0.35208	validation_0-map:0.94448	validation_1-error:0.19706	validation_1-logloss:0.43102	validation_1-map:0.88183
# [25]	validation_0-error:0.13191	validation_0-logloss:0.34780	validation_0-map:0.94514	validation_1-error:0.19766	validation_1-logloss:0.42911	validation_1-map:0.88206
# [26]	validation_0-error:0.13081	validation_0-logloss:0.34399	validation_0-map:0.94572	validation_1-error:0.19616	validation_1-logloss:0.42752	validation_1-map:0.88242
# [27]	validation_0-error:0.13151	validation_0-logloss:0.34055	validation_0-map:0.94618	validation_1-error:0.19616	validation_1-logloss:0.42633	validation_1-map:0.88219
# [28]	validation_0-error:0.12971	validation_0-logloss:0.33708	validation_0-map:0.94687	validation_1-error:0.19526	validation_1-logloss:0.42547	validation_1-map:0.88170
# [29]	validation_0-error:0.12941	validation_0-logloss:0.33377	validation_0-map:0.94734	validation_1-error:0.19616	validation_1-logloss:0.42409	validation_1-map:0.88162
# [30]	validation_0-error:0.12921	validation_0-logloss:0.33021	validation_0-map:0.94818	validation_1-error:0.19496	validation_1-logloss:0.42262	validation_1-map:0.88185
# [31]	validation_0-error:0.12811	validation_0-logloss:0.32700	validation_0-map:0.94892	validation_1-error:0.19556	validation_1-logloss:0.42171	validation_1-map:0.88190
# [32]	validation_0-error:0.12781	validation_0-logloss:0.32411	validation_0-map:0.94954	validation_1-error:0.19526	validation_1-logloss:0.42049	validation_1-map:0.88234
# [33]	validation_0-error:0.12631	validation_0-logloss:0.32145	validation_0-map:0.94996	validation_1-error:0.19616	validation_1-logloss:0.41995	validation_1-map:0.88260
# [34]	validation_0-error:0.12521	validation_0-logloss:0.31872	validation_0-map:0.95071	validation_1-error:0.19466	validation_1-logloss:0.41934	validation_1-map:0.88260
# [35]	validation_0-error:0.12451	validation_0-logloss:0.31596	validation_0-map:0.95140	validation_1-error:0.19436	validation_1-logloss:0.41866	validation_1-map:0.88309
# [36]	validation_0-error:0.12361	validation_0-logloss:0.31354	validation_0-map:0.95202	validation_1-error:0.19526	validation_1-logloss:0.41822	validation_1-map:0.88307
# [37]	validation_0-error:0.12241	validation_0-logloss:0.31078	validation_0-map:0.95262	validation_1-error:0.19496	validation_1-logloss:0.41771	validation_1-map:0.88317
# [38]	validation_0-error:0.12231	validation_0-logloss:0.30860	validation_0-map:0.95304	validation_1-error:0.19556	validation_1-logloss:0.41751	validation_1-map:0.88270
# [39]	validation_0-error:0.12091	validation_0-logloss:0.30615	validation_0-map:0.95365	validation_1-error:0.19436	validation_1-logloss:0.41746	validation_1-map:0.88267
# [40]	validation_0-error:0.12071	validation_0-logloss:0.30378	validation_0-map:0.95423	validation_1-error:0.19586	validation_1-logloss:0.41689	validation_1-map:0.88268
# [41]	validation_0-error:0.11961	validation_0-logloss:0.30163	validation_0-map:0.95461	validation_1-error:0.19646	validation_1-logloss:0.41663	validation_1-map:0.88281
# [42]	validation_0-error:0.11921	validation_0-logloss:0.29966	validation_0-map:0.95525	validation_1-error:0.19646	validation_1-logloss:0.41653	validation_1-map:0.88280
# [43]	validation_0-error:0.11951	validation_0-logloss:0.29816	validation_0-map:0.95556	validation_1-error:0.19586	validation_1-logloss:0.41686	validation_1-map:0.88222
# [44]	validation_0-error:0.11901	validation_0-logloss:0.29697	validation_0-map:0.95575	validation_1-error:0.19496	validation_1-logloss:0.41697	validation_1-map:0.88215
# [45]	validation_0-error:0.11791	validation_0-logloss:0.29524	validation_0-map:0.95625	validation_1-error:0.19586	validation_1-logloss:0.41694	validation_1-map:0.88205
# [46]	validation_0-error:0.11801	validation_0-logloss:0.29443	validation_0-map:0.95640	validation_1-error:0.19616	validation_1-logloss:0.41714	validation_1-map:0.88198
# [47]	validation_0-error:0.11701	validation_0-logloss:0.29269	validation_0-map:0.95700	validation_1-error:0.19466	validation_1-logloss:0.41694	validation_1-map:0.88178
# [48]	validation_0-error:0.11591	validation_0-logloss:0.29176	validation_0-map:0.95716	validation_1-error:0.19526	validation_1-logloss:0.41735	validation_1-map:0.88153
# [49]	validation_0-error:0.11551	validation_0-logloss:0.29046	validation_0-map:0.95747	validation_1-error:0.19676	validation_1-logloss:0.41717	validation_1-map:0.88161
# [50]	validation_0-error:0.11511	validation_0-logloss:0.28921	validation_0-map:0.95778	validation_1-error:0.19706	validation_1-logloss:0.41685	validation_1-map:0.88158
# [51]	validation_0-error:0.11451	validation_0-logloss:0.28782	validation_0-map:0.95815	validation_1-error:0.19676	validation_1-logloss:0.41685	validation_1-map:0.88152
# [52]	validation_0-error:0.11381	validation_0-logloss:0.28699	validation_0-map:0.95834	validation_1-error:0.19586	validation_1-logloss:0.41666	validation_1-map:0.88149
# [53]	validation_0-error:0.11351	validation_0-logloss:0.28635	validation_0-map:0.95850	validation_1-error:0.19616	validation_1-logloss:0.41653	validation_1-map:0.88155
# [54]	validation_0-error:0.11291	validation_0-logloss:0.28562	validation_0-map:0.95867	validation_1-error:0.19616	validation_1-logloss:0.41697	validation_1-map:0.88141
# [55]	validation_0-error:0.11311	validation_0-logloss:0.28464	validation_0-map:0.95883	validation_1-error:0.19736	validation_1-logloss:0.41684	validation_1-map:0.88143
# [56]	validation_0-error:0.11291	validation_0-logloss:0.28403	validation_0-map:0.95892	validation_1-error:0.19796	validation_1-logloss:0.41688	validation_1-map:0.88144
# [57]	validation_0-error:0.11201	validation_0-logloss:0.28333	validation_0-map:0.95904	validation_1-error:0.19796	validation_1-logloss:0.41673	validation_1-map:0.88148
# [58]	validation_0-error:0.11211	validation_0-logloss:0.28301	validation_0-map:0.95905	validation_1-error:0.19796	validation_1-logloss:0.41683	validation_1-map:0.88141
# [59]	validation_0-error:0.11211	validation_0-logloss:0.28254	validation_0-map:0.95914	validation_1-error:0.19766	validation_1-logloss:0.41662	validation_1-map:0.88150
# [60]	validation_0-error:0.11191	validation_0-logloss:0.28182	validation_0-map:0.95930	validation_1-error:0.19706	validation_1-logloss:0.41663	validation_1-map:0.88153
# [61]	validation_0-error:0.11221	validation_0-logloss:0.28105	validation_0-map:0.95949	validation_1-error:0.19706	validation_1-logloss:0.41682	validation_1-map:0.88130
# [62]	validation_0-error:0.11211	validation_0-logloss:0.28067	validation_0-map:0.95957	validation_1-error:0.19646	validation_1-logloss:0.41697	validation_1-map:0.88122
# [63]	validation_0-error:0.11191	validation_0-logloss:0.28008	validation_0-map:0.95972	validation_1-error:0.19616	validation_1-logloss:0.41697	validation_1-map:0.88122
# [64]	validation_0-error:0.11191	validation_0-logloss:0.27948	validation_0-map:0.95992	validation_1-error:0.19616	validation_1-logloss:0.41718	validation_1-map:0.88117
# [65]	validation_0-error:0.11161	validation_0-logloss:0.27906	validation_0-map:0.95996	validation_1-error:0.19646	validation_1-logloss:0.41723	validation_1-map:0.88117
# [66]	validation_0-error:0.10931	validation_0-logloss:0.27775	validation_0-map:0.96043	validation_1-error:0.19556	validation_1-logloss:0.41716	validation_1-map:0.88121
# [67]	validation_0-error:0.10851	validation_0-logloss:0.27717	validation_0-map:0.96060	validation_1-error:0.19526	validation_1-logloss:0.41722	validation_1-map:0.88119
# [68]	validation_0-error:0.10771	validation_0-logloss:0.27669	validation_0-map:0.96066	validation_1-error:0.19676	validation_1-logloss:0.41729	validation_1-map:0.88112
# [69]	validation_0-error:0.10771	validation_0-logloss:0.27622	validation_0-map:0.96081	validation_1-error:0.19646	validation_1-logloss:0.41723	validation_1-map:0.88114
# [70]	validation_0-error:0.10751	validation_0-logloss:0.27601	validation_0-map:0.96083	validation_1-error:0.19616	validation_1-logloss:0.41722	validation_1-map:0.88113
# [71]	validation_0-error:0.10771	validation_0-logloss:0.27575	validation_0-map:0.96089	validation_1-error:0.19616	validation_1-logloss:0.41733	validation_1-map:0.88108
# [72]	validation_0-error:0.10771	validation_0-logloss:0.27528	validation_0-map:0.96109	validation_1-error:0.19706	validation_1-logloss:0.41725	validation_1-map:0.88102
# [73]	validation_0-error:0.10761	validation_0-logloss:0.27493	validation_0-map:0.96117	validation_1-error:0.19676	validation_1-logloss:0.41737	validation_1-map:0.88100
# [74]	validation_0-error:0.10691	validation_0-logloss:0.27441	validation_0-map:0.96139	validation_1-error:0.19676	validation_1-logloss:0.41734	validation_1-map:0.88113
# [75]	validation_0-error:0.10611	validation_0-logloss:0.27392	validation_0-map:0.96152	validation_1-error:0.19736	validation_1-logloss:0.41725	validation_1-map:0.88116
# [76]	validation_0-error:0.10601	validation_0-logloss:0.27269	validation_0-map:0.96202	validation_1-error:0.19676	validation_1-logloss:0.41752	validation_1-map:0.88117
# [77]	validation_0-error:0.10521	validation_0-logloss:0.27179	validation_0-map:0.96230	validation_1-error:0.19646	validation_1-logloss:0.41763	validation_1-map:0.88105
# [78]	validation_0-error:0.10531	validation_0-logloss:0.27161	validation_0-map:0.96235	validation_1-error:0.19676	validation_1-logloss:0.41763	validation_1-map:0.88107
# [79]	validation_0-error:0.10511	validation_0-logloss:0.27080	validation_0-map:0.96255	validation_1-error:0.19736	validation_1-logloss:0.41763	validation_1-map:0.88110
# [80]	validation_0-error:0.10451	validation_0-logloss:0.27024	validation_0-map:0.96273	validation_1-error:0.19706	validation_1-logloss:0.41753	validation_1-map:0.88114
# [81]	validation_0-error:0.10361	validation_0-logloss:0.26964	validation_0-map:0.96297	validation_1-error:0.19616	validation_1-logloss:0.41751	validation_1-map:0.88113
# [82]	validation_0-error:0.10361	validation_0-logloss:0.26937	validation_0-map:0.96302	validation_1-error:0.19676	validation_1-logloss:0.41759	validation_1-map:0.88111
# [83]	validation_0-error:0.10351	validation_0-logloss:0.26910	validation_0-map:0.96305	validation_1-error:0.19676	validation_1-logloss:0.41755	validation_1-map:0.88113
# [84]	validation_0-error:0.10371	validation_0-logloss:0.26887	validation_0-map:0.96309	validation_1-error:0.19646	validation_1-logloss:0.41763	validation_1-map:0.88111
# [85]	validation_0-error:0.10301	validation_0-logloss:0.26828	validation_0-map:0.96328	validation_1-error:0.19526	validation_1-logloss:0.41756	validation_1-map:0.88109
# [86]	validation_0-error:0.10221	validation_0-logloss:0.26747	validation_0-map:0.96358	validation_1-error:0.19496	validation_1-logloss:0.41747	validation_1-map:0.88116
# [87]	validation_0-error:0.10121	validation_0-logloss:0.26610	validation_0-map:0.96408	validation_1-error:0.19526	validation_1-logloss:0.41770	validation_1-map:0.88107

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import auc, precision_recall_curve

precision_xg, recall_xg, _ = precision_recall_curve(y_mon_test, y_pred_xg)
auc_xg = auc(recall_xg, precision_xg)

plt.figure(figsize=(6, 6))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.plot(recall_xg, precision_xg, label=f'AP (XGBoost) = {auc_xg:.2f}')
plt.title('Precision-Recall Curve', size=16)
plt.xlabel('Recall', size=16)
plt.ylabel('Precision', size=16)
plt.legend(frameon=False,fontsize=16)
plt.show()

# %%
predictions = [round(value) for value in y_pred_xg]
accuracy = accuracy_score(y_mon_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))

results = classifier.evals_result()
epochs = len(results["validation_0"]["error"])
x_axis = range(0, epochs)


# plot log loss
fig, ax = plt.subplots(figsize=(7,5))
ax.plot(x_axis, results["validation_0"]["logloss"], label="Train")
ax.plot(x_axis, results["validation_1"]["logloss"], label="Validation")
ax.legend()
plt.ylabel("Log Loss")
plt.title("XGBoost Log Loss")
plt.show()

# plot classification error
fig, ax = plt.subplots(figsize=(7,5))
ax.plot(x_axis, results["validation_0"]["error"], label="Train")
ax.plot(x_axis, results["validation_1"]["error"], label="Validation")
ax.legend()
plt.ylabel("Classification Error")
plt.title("XGBoost Classification Error")
plt.show()
# Out:
# Accuracy: 80.43%

# %%
# XGBoost with the kinematic variables of the leptons

########################
# CLASSIFICATION SCORE #
########################

# Outputs for validation data set

pred_XG_SM = []
pred_XG_NP = []

for i in range(len(y_mon_test)):
    if y_mon_test[i] == 0:
        pred_XG_SM.append(y_pred_xg[i])
    else:
        pred_XG_NP.append(y_pred_xg[i])
        
        
print('Classification score:')
        
weights = np.ones_like(pred_XG_SM)/float(len(pred_XG_SM))
nSM, binsSM, patchesSM = plt.hist(pred_XG_SM, 50, weights=weights, range=[0,1], histtype='step', color='firebrick', linewidth=2, label='Background')

weights = np.ones_like(pred_XG_NP)/float(len(pred_XG_NP))
nNP, binsNP, patchesNP = plt.hist(pred_XG_NP, 50, weights=weights, range=[0,1], histtype='step', color='forestgreen', linewidth=2, label='Signal')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Classication score (XGBoost)",fontsize=15)
plt.ylabel("Fraction of events",fontsize=14)
plt.grid()
plt.legend(fontsize=12)

plt.show()
# Out:
# Classification score:
