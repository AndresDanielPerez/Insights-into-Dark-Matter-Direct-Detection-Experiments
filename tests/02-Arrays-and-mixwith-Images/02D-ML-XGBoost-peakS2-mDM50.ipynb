# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import gridspec
from matplotlib import patches
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

import os
import math
import random

import keras
from keras.models import Sequential
from keras.layers import Input, Dense, Conv2D, Flatten, MaxPooling2D
from keras.layers import Dropout
from keras.callbacks import EarlyStopping

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn import preprocessing
from sklearn.metrics import roc_curve, roc_auc_score, auc

import scipy.stats as st
from scipy.stats import poisson
from scipy.interpolate import interp1d
from scipy.stats import norm
# Out:
# 2023-05-18 02:10:17.177511: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-18 02:10:17.311648: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-05-18 02:10:17.942661: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/andres/installROOT/lib
# 2023-05-18 02:10:17.942795: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/andres/installROOT/lib
# 2023-05-18 02:10:17.942804: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
from sklearn.neighbors import KernelDensity # paquete necesario
from sklearn.model_selection import GridSearchCV

import scipy.integrate as integrate

# %%
# !pip install xgboost

import xgboost
from xgboost import XGBRegressor, XGBClassifier
# Out:
# Requirement already satisfied: xgboost in /home/andres/anaconda3/lib/python3.9/site-packages (1.7.4)
# Requirement already satisfied: numpy in /home/andres/anaconda3/lib/python3.9/site-packages (from xgboost) (1.23.5)
# Requirement already satisfied: scipy in /home/andres/anaconda3/lib/python3.9/site-packages (from xgboost) (1.10.0)

# %%
import h5py

import glob
import numpy as np
import os.path as path
import imageio
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D
from keras.callbacks import EarlyStopping, TensorBoard
from datetime import datetime
import keras
from keras import regularizers
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score, average_precision_score, precision_recall_curve, auc,recall_score
from keras.optimizers import Adam
from keras.regularizers import l2
import h5py
from sklearn.model_selection import GridSearchCV
from keras.backend import cast, greater, clip, floatx,epsilon
from keras.wrappers.scikit_learn import KerasClassifier
from keras import backend as K
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# ### Load Data

# %%
filefolder = '../../data2024/processed/'

###################
# BACKGROUND FILE #
###################

filename_B = 'ER/ER_all.hdf5'


###############
# SIGNAL FILE #
###############

# select the DM mass
mDM = 50

filename_S = 'mDM' + str(mDM) + 'GeV/WP_mDM' + str(mDM) + 'GeV_sig1045.hdf5'

# %%
# OPEN THE SAVED FILE TO CHECK IT
f_B = h5py.File(filefolder+filename_B,'r')
f_S = h5py.File(filefolder+filename_S,'r')

# show the groups
print( f_B.keys() )

# should be more than 10k events in each group
print('\n Background Events: ')
for groups1 in f_B.keys():
    print(len(f_B[groups1].keys()))

print('\n Signal Events')
for groups1 in f_S.keys():
    print(len(f_S[groups1].keys()))
# Out:
# <KeysViewHDF5 ['HITS_bot', 'HITS_bot_img', 'HITS_top', 'HITS_top_img', 'peakS1_onlyhits', 'peakS1_raw', 'peakS2_onlyhits', 'peakS2_raw']>
#
#  Background Events:
# 17206
# 17206
# 17206
# 17206
# 17206
# 17206
# 17206
# 17206
#
#  Signal Events
# 12157
# 12157
# 12157
# 12157
# 12157
# 12157
# 12157
# 12157

# %%
#############################
# ONLY peakS2_onlyhits DATA #
#############################

# to normalize
scaler = preprocessing.MinMaxScaler()

# Number of data points (per-class) for the ML classifier
num_data = 10000


# First:
# The max len for the time series

max_pS2_B = 0
max_pS2_S = 0

for i in range(1, num_data+1):
    max_pS2_B = max(max_pS2_B, len( f_B['peakS2_onlyhits/ev_'+str(i)] ))
    max_pS2_S = max(max_pS2_S, len( f_S['peakS2_onlyhits/ev_'+str(i)] ))
    
    
max_pS2_both = max(max_pS2_B,max_pS2_S)

print('max_pS2_both lenght: ', max_pS2_both)



# Second:
# add the events in a matrix, but all with the same length -> fill with zeros

# how many elements do we need to make all the peak (S2 or S2) arrays with the same length
diff_elem_S2_B = max_pS2_both - len( f_B['peakS2_onlyhits/ev_1'][()] )
diff_elem_S2_S = max_pS2_both - len( f_S['peakS2_onlyhits/ev_1'][()] )

# add zeros at the end
peakS2_onlyhits_B = np.pad(f_B['peakS2_onlyhits/ev_1'][()], (0, diff_elem_S2_B), 'constant')
peakS2_onlyhits_S = np.pad(f_S['peakS2_onlyhits/ev_1'][()], (0, diff_elem_S2_S), 'constant')

for i in range(2, num_data+1):
    
    # how many elements do we need to make all the peak (S2 or S2) arrays with the same length
    diff_elem_S2_B = max_pS2_both - len( f_B['peakS2_onlyhits/ev_'+str(i)][()] )
    diff_elem_S2_S = max_pS2_both - len( f_S['peakS2_onlyhits/ev_'+str(i)][()] )
    
    # add zeros at the end
    aux_S2_B = np.pad(f_B['peakS2_onlyhits/ev_'+str(i)][()], (0, diff_elem_S2_B), 'constant')
    aux_S2_S = np.pad(f_S['peakS2_onlyhits/ev_'+str(i)][()], (0, diff_elem_S2_S), 'constant')
    
    # add new event to the matrix as a row
    peakS2_onlyhits_B = np.row_stack([peakS2_onlyhits_B,aux_S2_B])
    peakS2_onlyhits_S = np.row_stack([peakS2_onlyhits_S,aux_S2_S])
    
    

# close the h5 files
f_B.close()
f_S.close()

    
    

# X and Y for the classifier
X_mon = np.row_stack([peakS2_onlyhits_B,peakS2_onlyhits_S])
# normalize
X_mon = scaler.fit_transform(X_mon)

del peakS2_onlyhits_B
del peakS2_onlyhits_S

# labels
y_mon = np.concatenate([np.zeros(num_data),np.ones(num_data)])



# divide into train-val and test data samples
test_ratio = 1./3
val_ratio = 0.25


X_mon_aux, X_mon_test, y_mon_aux, y_mon_test = train_test_split(X_mon,
                                                                y_mon,
                                                                test_size=test_ratio,
                                                                random_state=42,
                                                                #stratify = y_mon,
                                                                shuffle=True)

del X_mon
del y_mon

X_mon_train, X_mon_val, y_mon_train, y_mon_val = train_test_split(X_mon_aux,
                                                                  y_mon_aux,
                                                                  test_size=val_ratio,
                                                                  random_state=42,
                                                                  #stratify = y_mon_aux,
                                                                  shuffle=True)

del X_mon_aux
del y_mon_aux

print('')
print('X_mon_train : ', X_mon_train.shape)
print('y_mon_train : ', y_mon_train.shape)
print('X_mon_val : ', X_mon_val.shape)
print('y_mon_val : ', y_mon_val.shape)
print('X_mon_test : ', X_mon_test.shape)
print('y_mon_test : ', y_mon_test.shape)
print('')
# Out:
# max_pS2_both lenght:  2244
#
# X_mon_train :  (9999, 2244)
# y_mon_train :  (9999,)
# X_mon_val :  (3334, 2244)
# y_mon_val :  (3334,)
# X_mon_test :  (6667, 2244)
# y_mon_test :  (6667,)

# %% [markdown]
# ### CLASSIFIER

# %%
# XGBoost with only the kinematic variables of the leptons

# CLASSIFIER
classifier = XGBClassifier(
    n_estimators=500,
    learning_rate=0.1,
    reg_lambda=0.0,reg_alpha=0.0,
    gamma=0.0,objective='binary:logistic',
    max_depth=5)

# FIT
classifier.fit(X_mon_train,y_mon_train,eval_set=[(X_mon_train, y_mon_train), (X_mon_val, y_mon_val)],
        eval_metric=["error", "logloss", "map"],early_stopping_rounds=50,#early stopping
        verbose=True)

# PREDICTIONS
y_pred_xg = classifier.predict_proba(X_mon_test).T[1]


# ROC
fpr_mon_xg, tpr_mon_xg, _ = roc_curve(y_mon_test, y_pred_xg)
roc_auc_xg = auc(fpr_mon_xg, tpr_mon_xg)


# PLOT THE ROC WITH AUC
fig = plt.figure(figsize=(6, 6))
gs = gridspec.GridSpec(1, 1) 
ax0 = plt.subplot(gs[0])
ax0.yaxis.set_ticks_position('both')
ax0.xaxis.set_ticks_position('both')
ax0.tick_params(direction="in",which="both")
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
ax0.minorticks_on()


plt.plot(tpr_mon_xg,1-fpr_mon_xg,label="$f_{1}$, AUC = %0.2f" % roc_auc_xg,color="orange",ls=":",lw=4)
plt.plot([1,0],[0,1],ls=":",color="grey")
plt.xlabel("True Positive Rate",fontsize=16)
plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
plt.legend()
plt.xlim([0,1])
plt.ylim([0,1])
plt.yticks([0.2,0.4,0.6,0.8,1.])
plt.legend(frameon=False,fontsize=16)
plt.show()
# Out:
# /home/andres/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# /home/andres/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-error:0.11681	validation_0-logloss:0.63129	validation_0-map:0.90842	validation_1-error:0.14037	validation_1-logloss:0.63496	validation_1-map:0.89374
# [1]	validation_0-error:0.10721	validation_0-logloss:0.57997	validation_0-map:0.92015	validation_1-error:0.13017	validation_1-logloss:0.58733	validation_1-map:0.91288
# [2]	validation_0-error:0.10421	validation_0-logloss:0.53610	validation_0-map:0.93619	validation_1-error:0.12897	validation_1-logloss:0.54688	validation_1-map:0.92253
# [3]	validation_0-error:0.09901	validation_0-logloss:0.49919	validation_0-map:0.94709	validation_1-error:0.12627	validation_1-logloss:0.51354	validation_1-map:0.92685
# [4]	validation_0-error:0.09671	validation_0-logloss:0.46717	validation_0-map:0.95326	validation_1-error:0.12388	validation_1-logloss:0.48438	validation_1-map:0.93064
# [5]	validation_0-error:0.09471	validation_0-logloss:0.43915	validation_0-map:0.95593	validation_1-error:0.12388	validation_1-logloss:0.45971	validation_1-map:0.93164
# [6]	validation_0-error:0.09231	validation_0-logloss:0.41430	validation_0-map:0.95781	validation_1-error:0.12028	validation_1-logloss:0.43707	validation_1-map:0.93394
# [7]	validation_0-error:0.09161	validation_0-logloss:0.39218	validation_0-map:0.96001	validation_1-error:0.12058	validation_1-logloss:0.41787	validation_1-map:0.93511
# [8]	validation_0-error:0.09051	validation_0-logloss:0.37271	validation_0-map:0.96140	validation_1-error:0.11638	validation_1-logloss:0.40147	validation_1-map:0.93448
# [9]	validation_0-error:0.08801	validation_0-logloss:0.35560	validation_0-map:0.96260	validation_1-error:0.11818	validation_1-logloss:0.38736	validation_1-map:0.93507
# [10]	validation_0-error:0.08741	validation_0-logloss:0.34025	validation_0-map:0.96347	validation_1-error:0.11548	validation_1-logloss:0.37477	validation_1-map:0.93923
# [11]	validation_0-error:0.08561	validation_0-logloss:0.32660	validation_0-map:0.96448	validation_1-error:0.11338	validation_1-logloss:0.36317	validation_1-map:0.94135
# [12]	validation_0-error:0.08441	validation_0-logloss:0.31407	validation_0-map:0.96491	validation_1-error:0.11428	validation_1-logloss:0.35291	validation_1-map:0.94160
# [13]	validation_0-error:0.08351	validation_0-logloss:0.30310	validation_0-map:0.96690	validation_1-error:0.11398	validation_1-logloss:0.34389	validation_1-map:0.94201
# [14]	validation_0-error:0.08251	validation_0-logloss:0.29299	validation_0-map:0.96852	validation_1-error:0.11638	validation_1-logloss:0.33649	validation_1-map:0.94231
# [15]	validation_0-error:0.08101	validation_0-logloss:0.28328	validation_0-map:0.96938	validation_1-error:0.11518	validation_1-logloss:0.32891	validation_1-map:0.94301
# [16]	validation_0-error:0.07991	validation_0-logloss:0.27476	validation_0-map:0.96992	validation_1-error:0.11458	validation_1-logloss:0.32332	validation_1-map:0.94299
# [17]	validation_0-error:0.07961	validation_0-logloss:0.26705	validation_0-map:0.97064	validation_1-error:0.11428	validation_1-logloss:0.31793	validation_1-map:0.94328
# [18]	validation_0-error:0.07881	validation_0-logloss:0.25996	validation_0-map:0.97114	validation_1-error:0.11308	validation_1-logloss:0.31305	validation_1-map:0.94358
# [19]	validation_0-error:0.07801	validation_0-logloss:0.25295	validation_0-map:0.97171	validation_1-error:0.11308	validation_1-logloss:0.30838	validation_1-map:0.94394
# [20]	validation_0-error:0.07721	validation_0-logloss:0.24692	validation_0-map:0.97256	validation_1-error:0.11308	validation_1-logloss:0.30433	validation_1-map:0.94500
# [21]	validation_0-error:0.07721	validation_0-logloss:0.24148	validation_0-map:0.97320	validation_1-error:0.11188	validation_1-logloss:0.30094	validation_1-map:0.94494
# [22]	validation_0-error:0.07651	validation_0-logloss:0.23622	validation_0-map:0.97381	validation_1-error:0.11188	validation_1-logloss:0.29748	validation_1-map:0.94541
# [23]	validation_0-error:0.07541	validation_0-logloss:0.23131	validation_0-map:0.97492	validation_1-error:0.11368	validation_1-logloss:0.29459	validation_1-map:0.94564
# [24]	validation_0-error:0.07471	validation_0-logloss:0.22678	validation_0-map:0.97558	validation_1-error:0.11188	validation_1-logloss:0.29244	validation_1-map:0.94570
# [25]	validation_0-error:0.07361	validation_0-logloss:0.22295	validation_0-map:0.97608	validation_1-error:0.11128	validation_1-logloss:0.29035	validation_1-map:0.94577
# [26]	validation_0-error:0.07371	validation_0-logloss:0.21910	validation_0-map:0.97635	validation_1-error:0.11278	validation_1-logloss:0.28857	validation_1-map:0.94603
# [27]	validation_0-error:0.07211	validation_0-logloss:0.21530	validation_0-map:0.97694	validation_1-error:0.11218	validation_1-logloss:0.28686	validation_1-map:0.94662
# [28]	validation_0-error:0.07161	validation_0-logloss:0.21180	validation_0-map:0.97755	validation_1-error:0.11218	validation_1-logloss:0.28528	validation_1-map:0.94665
# [29]	validation_0-error:0.07101	validation_0-logloss:0.20860	validation_0-map:0.97805	validation_1-error:0.11188	validation_1-logloss:0.28361	validation_1-map:0.94731
# [30]	validation_0-error:0.07131	validation_0-logloss:0.20550	validation_0-map:0.97891	validation_1-error:0.11338	validation_1-logloss:0.28241	validation_1-map:0.94721
# [31]	validation_0-error:0.07031	validation_0-logloss:0.20288	validation_0-map:0.97921	validation_1-error:0.11218	validation_1-logloss:0.28119	validation_1-map:0.94773
# [32]	validation_0-error:0.07001	validation_0-logloss:0.20064	validation_0-map:0.97961	validation_1-error:0.11338	validation_1-logloss:0.28049	validation_1-map:0.94781
# [33]	validation_0-error:0.06981	validation_0-logloss:0.19801	validation_0-map:0.98005	validation_1-error:0.11278	validation_1-logloss:0.27948	validation_1-map:0.94784
# [34]	validation_0-error:0.06881	validation_0-logloss:0.19486	validation_0-map:0.98080	validation_1-error:0.11158	validation_1-logloss:0.27818	validation_1-map:0.94818
# [35]	validation_0-error:0.06831	validation_0-logloss:0.19312	validation_0-map:0.98100	validation_1-error:0.11218	validation_1-logloss:0.27745	validation_1-map:0.94818
# [36]	validation_0-error:0.06831	validation_0-logloss:0.19026	validation_0-map:0.98161	validation_1-error:0.11338	validation_1-logloss:0.27696	validation_1-map:0.94809
# [37]	validation_0-error:0.06831	validation_0-logloss:0.18816	validation_0-map:0.98202	validation_1-error:0.11308	validation_1-logloss:0.27620	validation_1-map:0.94843
# [38]	validation_0-error:0.06711	validation_0-logloss:0.18585	validation_0-map:0.98258	validation_1-error:0.11308	validation_1-logloss:0.27563	validation_1-map:0.94850
# [39]	validation_0-error:0.06671	validation_0-logloss:0.18402	validation_0-map:0.98293	validation_1-error:0.11248	validation_1-logloss:0.27502	validation_1-map:0.94865
# [40]	validation_0-error:0.06571	validation_0-logloss:0.18158	validation_0-map:0.98361	validation_1-error:0.11308	validation_1-logloss:0.27444	validation_1-map:0.94885
# [41]	validation_0-error:0.06561	validation_0-logloss:0.18018	validation_0-map:0.98383	validation_1-error:0.11368	validation_1-logloss:0.27428	validation_1-map:0.94890
# [42]	validation_0-error:0.06541	validation_0-logloss:0.17875	validation_0-map:0.98400	validation_1-error:0.11308	validation_1-logloss:0.27374	validation_1-map:0.94917
# [43]	validation_0-error:0.06451	validation_0-logloss:0.17675	validation_0-map:0.98431	validation_1-error:0.11278	validation_1-logloss:0.27407	validation_1-map:0.94901
# [44]	validation_0-error:0.06381	validation_0-logloss:0.17571	validation_0-map:0.98441	validation_1-error:0.11278	validation_1-logloss:0.27369	validation_1-map:0.94905
# [45]	validation_0-error:0.06321	validation_0-logloss:0.17452	validation_0-map:0.98458	validation_1-error:0.11248	validation_1-logloss:0.27312	validation_1-map:0.94915
# [46]	validation_0-error:0.06331	validation_0-logloss:0.17294	validation_0-map:0.98493	validation_1-error:0.11158	validation_1-logloss:0.27281	validation_1-map:0.94954
# [47]	validation_0-error:0.06271	validation_0-logloss:0.17194	validation_0-map:0.98513	validation_1-error:0.11218	validation_1-logloss:0.27253	validation_1-map:0.94967
# [48]	validation_0-error:0.06231	validation_0-logloss:0.17024	validation_0-map:0.98549	validation_1-error:0.11218	validation_1-logloss:0.27233	validation_1-map:0.94960
# [49]	validation_0-error:0.06221	validation_0-logloss:0.16894	validation_0-map:0.98583	validation_1-error:0.11428	validation_1-logloss:0.27244	validation_1-map:0.94952
# [50]	validation_0-error:0.06191	validation_0-logloss:0.16807	validation_0-map:0.98601	validation_1-error:0.11488	validation_1-logloss:0.27242	validation_1-map:0.94956
# [51]	validation_0-error:0.06121	validation_0-logloss:0.16724	validation_0-map:0.98616	validation_1-error:0.11488	validation_1-logloss:0.27246	validation_1-map:0.94966
# [52]	validation_0-error:0.06081	validation_0-logloss:0.16584	validation_0-map:0.98664	validation_1-error:0.11578	validation_1-logloss:0.27218	validation_1-map:0.94996
# [53]	validation_0-error:0.06061	validation_0-logloss:0.16521	validation_0-map:0.98677	validation_1-error:0.11638	validation_1-logloss:0.27227	validation_1-map:0.94996
# [54]	validation_0-error:0.06041	validation_0-logloss:0.16342	validation_0-map:0.98740	validation_1-error:0.11518	validation_1-logloss:0.27223	validation_1-map:0.95004
# [55]	validation_0-error:0.06001	validation_0-logloss:0.16215	validation_0-map:0.98777	validation_1-error:0.11398	validation_1-logloss:0.27190	validation_1-map:0.95020
# [56]	validation_0-error:0.05951	validation_0-logloss:0.16123	validation_0-map:0.98799	validation_1-error:0.11398	validation_1-logloss:0.27186	validation_1-map:0.95018
# [57]	validation_0-error:0.05901	validation_0-logloss:0.16017	validation_0-map:0.98818	validation_1-error:0.11398	validation_1-logloss:0.27189	validation_1-map:0.95015
# [58]	validation_0-error:0.05821	validation_0-logloss:0.15902	validation_0-map:0.98844	validation_1-error:0.11518	validation_1-logloss:0.27211	validation_1-map:0.95010
# [59]	validation_0-error:0.05791	validation_0-logloss:0.15859	validation_0-map:0.98851	validation_1-error:0.11518	validation_1-logloss:0.27210	validation_1-map:0.95014
# [60]	validation_0-error:0.05761	validation_0-logloss:0.15778	validation_0-map:0.98865	validation_1-error:0.11518	validation_1-logloss:0.27215	validation_1-map:0.95013
# [61]	validation_0-error:0.05671	validation_0-logloss:0.15651	validation_0-map:0.98895	validation_1-error:0.11518	validation_1-logloss:0.27209	validation_1-map:0.95011
# [62]	validation_0-error:0.05591	validation_0-logloss:0.15555	validation_0-map:0.98919	validation_1-error:0.11458	validation_1-logloss:0.27206	validation_1-map:0.95027
# [63]	validation_0-error:0.05461	validation_0-logloss:0.15446	validation_0-map:0.98949	validation_1-error:0.11548	validation_1-logloss:0.27251	validation_1-map:0.95020
# [64]	validation_0-error:0.05411	validation_0-logloss:0.15331	validation_0-map:0.98975	validation_1-error:0.11698	validation_1-logloss:0.27240	validation_1-map:0.95026
# [65]	validation_0-error:0.05361	validation_0-logloss:0.15226	validation_0-map:0.99006	validation_1-error:0.11698	validation_1-logloss:0.27239	validation_1-map:0.95025
# [66]	validation_0-error:0.05331	validation_0-logloss:0.15129	validation_0-map:0.99028	validation_1-error:0.11698	validation_1-logloss:0.27249	validation_1-map:0.95008
# [67]	validation_0-error:0.05251	validation_0-logloss:0.15040	validation_0-map:0.99053	validation_1-error:0.11638	validation_1-logloss:0.27271	validation_1-map:0.94996
# [68]	validation_0-error:0.05221	validation_0-logloss:0.14968	validation_0-map:0.99066	validation_1-error:0.11518	validation_1-logloss:0.27271	validation_1-map:0.94993
# [69]	validation_0-error:0.05211	validation_0-logloss:0.14928	validation_0-map:0.99075	validation_1-error:0.11548	validation_1-logloss:0.27271	validation_1-map:0.94986
# [70]	validation_0-error:0.05101	validation_0-logloss:0.14783	validation_0-map:0.99105	validation_1-error:0.11458	validation_1-logloss:0.27224	validation_1-map:0.95010
# [71]	validation_0-error:0.04990	validation_0-logloss:0.14661	validation_0-map:0.99137	validation_1-error:0.11368	validation_1-logloss:0.27189	validation_1-map:0.95013
# [72]	validation_0-error:0.04950	validation_0-logloss:0.14608	validation_0-map:0.99145	validation_1-error:0.11368	validation_1-logloss:0.27201	validation_1-map:0.95002
# [73]	validation_0-error:0.04950	validation_0-logloss:0.14540	validation_0-map:0.99159	validation_1-error:0.11368	validation_1-logloss:0.27197	validation_1-map:0.95004
# [74]	validation_0-error:0.04920	validation_0-logloss:0.14488	validation_0-map:0.99173	validation_1-error:0.11398	validation_1-logloss:0.27201	validation_1-map:0.94987
# [75]	validation_0-error:0.04870	validation_0-logloss:0.14428	validation_0-map:0.99185	validation_1-error:0.11398	validation_1-logloss:0.27208	validation_1-map:0.94989
# [76]	validation_0-error:0.04830	validation_0-logloss:0.14359	validation_0-map:0.99197	validation_1-error:0.11398	validation_1-logloss:0.27216	validation_1-map:0.94985
# [77]	validation_0-error:0.04810	validation_0-logloss:0.14328	validation_0-map:0.99202	validation_1-error:0.11398	validation_1-logloss:0.27220	validation_1-map:0.94986
# [78]	validation_0-error:0.04700	validation_0-logloss:0.14244	validation_0-map:0.99214	validation_1-error:0.11428	validation_1-logloss:0.27217	validation_1-map:0.94993
# [79]	validation_0-error:0.04680	validation_0-logloss:0.14188	validation_0-map:0.99227	validation_1-error:0.11428	validation_1-logloss:0.27219	validation_1-map:0.94988
# [80]	validation_0-error:0.04630	validation_0-logloss:0.14111	validation_0-map:0.99243	validation_1-error:0.11428	validation_1-logloss:0.27210	validation_1-map:0.94997
# [81]	validation_0-error:0.04580	validation_0-logloss:0.14010	validation_0-map:0.99266	validation_1-error:0.11398	validation_1-logloss:0.27227	validation_1-map:0.94985
# [82]	validation_0-error:0.04520	validation_0-logloss:0.13948	validation_0-map:0.99276	validation_1-error:0.11398	validation_1-logloss:0.27253	validation_1-map:0.94974
# [83]	validation_0-error:0.04480	validation_0-logloss:0.13890	validation_0-map:0.99287	validation_1-error:0.11428	validation_1-logloss:0.27255	validation_1-map:0.94976
# [84]	validation_0-error:0.04410	validation_0-logloss:0.13804	validation_0-map:0.99310	validation_1-error:0.11458	validation_1-logloss:0.27264	validation_1-map:0.94972
# [85]	validation_0-error:0.04290	validation_0-logloss:0.13648	validation_0-map:0.99342	validation_1-error:0.11488	validation_1-logloss:0.27216	validation_1-map:0.95013
# [86]	validation_0-error:0.04240	validation_0-logloss:0.13491	validation_0-map:0.99376	validation_1-error:0.11548	validation_1-logloss:0.27231	validation_1-map:0.95005
# [87]	validation_0-error:0.04190	validation_0-logloss:0.13402	validation_0-map:0.99394	validation_1-error:0.11578	validation_1-logloss:0.27226	validation_1-map:0.95018
# [88]	validation_0-error:0.04200	validation_0-logloss:0.13271	validation_0-map:0.99413	validation_1-error:0.11518	validation_1-logloss:0.27227	validation_1-map:0.95025
# [89]	validation_0-error:0.04090	validation_0-logloss:0.13181	validation_0-map:0.99426	validation_1-error:0.11458	validation_1-logloss:0.27250	validation_1-map:0.95014
# [90]	validation_0-error:0.04050	validation_0-logloss:0.13138	validation_0-map:0.99432	validation_1-error:0.11488	validation_1-logloss:0.27232	validation_1-map:0.95017
# [91]	validation_0-error:0.04040	validation_0-logloss:0.13087	validation_0-map:0.99441	validation_1-error:0.11488	validation_1-logloss:0.27225	validation_1-map:0.95021
# [92]	validation_0-error:0.03940	validation_0-logloss:0.12962	validation_0-map:0.99471	validation_1-error:0.11458	validation_1-logloss:0.27213	validation_1-map:0.95027
# [93]	validation_0-error:0.03850	validation_0-logloss:0.12868	validation_0-map:0.99489	validation_1-error:0.11398	validation_1-logloss:0.27263	validation_1-map:0.95009
# [94]	validation_0-error:0.03840	validation_0-logloss:0.12809	validation_0-map:0.99498	validation_1-error:0.11338	validation_1-logloss:0.27262	validation_1-map:0.95007
# [95]	validation_0-error:0.03790	validation_0-logloss:0.12771	validation_0-map:0.99502	validation_1-error:0.11368	validation_1-logloss:0.27269	validation_1-map:0.95010
# [96]	validation_0-error:0.03810	validation_0-logloss:0.12711	validation_0-map:0.99509	validation_1-error:0.11278	validation_1-logloss:0.27270	validation_1-map:0.95016
# [97]	validation_0-error:0.03790	validation_0-logloss:0.12680	validation_0-map:0.99516	validation_1-error:0.11278	validation_1-logloss:0.27276	validation_1-map:0.95002
# [98]	validation_0-error:0.03650	validation_0-logloss:0.12591	validation_0-map:0.99530	validation_1-error:0.11368	validation_1-logloss:0.27255	validation_1-map:0.95003
# [99]	validation_0-error:0.03610	validation_0-logloss:0.12547	validation_0-map:0.99537	validation_1-error:0.11368	validation_1-logloss:0.27267	validation_1-map:0.94993
# [100]	validation_0-error:0.03590	validation_0-logloss:0.12514	validation_0-map:0.99540	validation_1-error:0.11398	validation_1-logloss:0.27263	validation_1-map:0.95005
# [101]	validation_0-error:0.03540	validation_0-logloss:0.12484	validation_0-map:0.99544	validation_1-error:0.11368	validation_1-logloss:0.27260	validation_1-map:0.95006
# [102]	validation_0-error:0.03490	validation_0-logloss:0.12431	validation_0-map:0.99553	validation_1-error:0.11338	validation_1-logloss:0.27285	validation_1-map:0.95000
# [103]	validation_0-error:0.03370	validation_0-logloss:0.12265	validation_0-map:0.99577	validation_1-error:0.11398	validation_1-logloss:0.27321	validation_1-map:0.94973
# [104]	validation_0-error:0.03360	validation_0-logloss:0.12220	validation_0-map:0.99582	validation_1-error:0.11428	validation_1-logloss:0.27351	validation_1-map:0.94963
# [105]	validation_0-error:0.03330	validation_0-logloss:0.12165	validation_0-map:0.99586	validation_1-error:0.11428	validation_1-logloss:0.27390	validation_1-map:0.94952
# [106]	validation_0-error:0.03300	validation_0-logloss:0.12106	validation_0-map:0.99596	validation_1-error:0.11428	validation_1-logloss:0.27419	validation_1-map:0.94950
# [107]	validation_0-error:0.03260	validation_0-logloss:0.12067	validation_0-map:0.99602	validation_1-error:0.11428	validation_1-logloss:0.27422	validation_1-map:0.94951
# [108]	validation_0-error:0.03250	validation_0-logloss:0.12028	validation_0-map:0.99607	validation_1-error:0.11428	validation_1-logloss:0.27417	validation_1-map:0.94957
# [109]	validation_0-error:0.03190	validation_0-logloss:0.11932	validation_0-map:0.99619	validation_1-error:0.11458	validation_1-logloss:0.27467	validation_1-map:0.94958
# [110]	validation_0-error:0.03140	validation_0-logloss:0.11832	validation_0-map:0.99636	validation_1-error:0.11458	validation_1-logloss:0.27476	validation_1-map:0.94957
# [111]	validation_0-error:0.03090	validation_0-logloss:0.11733	validation_0-map:0.99649	validation_1-error:0.11368	validation_1-logloss:0.27458	validation_1-map:0.94960
# [112]	validation_0-error:0.03030	validation_0-logloss:0.11650	validation_0-map:0.99668	validation_1-error:0.11368	validation_1-logloss:0.27480	validation_1-map:0.94955

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import auc, precision_recall_curve

precision_xg, recall_xg, _ = precision_recall_curve(y_mon_test, y_pred_xg)
auc_xg = auc(recall_xg, precision_xg)

plt.figure(figsize=(6, 6))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.plot(recall_xg, precision_xg, label=f'AP (XGBoost) = {auc_xg:.2f}')
plt.title('Precision-Recall Curve', size=16)
plt.xlabel('Recall', size=16)
plt.ylabel('Precision', size=16)
plt.legend(frameon=False,fontsize=16)
plt.show()

# %%
predictions = [round(value) for value in y_pred_xg]
accuracy = accuracy_score(y_mon_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))

results = classifier.evals_result()
epochs = len(results["validation_0"]["error"])
x_axis = range(0, epochs)


# plot log loss
fig, ax = plt.subplots(figsize=(7,5))
ax.plot(x_axis, results["validation_0"]["logloss"], label="Train")
ax.plot(x_axis, results["validation_1"]["logloss"], label="Validation")
ax.legend()
plt.ylabel("Log Loss")
plt.title("XGBoost Log Loss")
plt.show()

# plot classification error
fig, ax = plt.subplots(figsize=(7,5))
ax.plot(x_axis, results["validation_0"]["error"], label="Train")
ax.plot(x_axis, results["validation_1"]["error"], label="Validation")
ax.legend()
plt.ylabel("Classification Error")
plt.title("XGBoost Classification Error")
plt.show()
# Out:
# Accuracy: 88.05%

# %%
# XGBoost with the kinematic variables of the leptons

########################
# CLASSIFICATION SCORE #
########################

# Outputs for validation data set

pred_XG_SM = []
pred_XG_NP = []

for i in range(len(y_mon_test)):
    if y_mon_test[i] == 0:
        pred_XG_SM.append(y_pred_xg[i])
    else:
        pred_XG_NP.append(y_pred_xg[i])
        
        
print('Classification score:')
        
weights = np.ones_like(pred_XG_SM)/float(len(pred_XG_SM))
nSM, binsSM, patchesSM = plt.hist(pred_XG_SM, 50, weights=weights, range=[0,1], histtype='step', color='firebrick', linewidth=2, label='Background')

weights = np.ones_like(pred_XG_NP)/float(len(pred_XG_NP))
nNP, binsNP, patchesNP = plt.hist(pred_XG_NP, 50, weights=weights, range=[0,1], histtype='step', color='forestgreen', linewidth=2, label='Signal')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Classication score (XGBoost)",fontsize=15)
plt.ylabel("Fraction of events",fontsize=14)
plt.grid()
plt.legend(fontsize=12)

plt.show()
# Out:
# Classification score:
