# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import gridspec
from matplotlib import patches
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

import os
import math
import random

import keras
from keras.models import Sequential
from keras.layers import Input, Dense, Conv2D, Flatten, MaxPooling2D
from keras.layers import Dropout
from keras.callbacks import EarlyStopping

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn import preprocessing
from sklearn.metrics import roc_curve, roc_auc_score, auc

import scipy.stats as st
from scipy.stats import poisson
from scipy.interpolate import interp1d
from scipy.stats import norm
# Out:
# 2023-04-25 03:15:25.779247: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-25 03:15:25.905371: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-25 03:15:26.341652: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/andres/installROOT/lib
# 2023-04-25 03:15:26.341694: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/andres/installROOT/lib
# 2023-04-25 03:15:26.341697: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
from sklearn.neighbors import KernelDensity # paquete necesario
from sklearn.model_selection import GridSearchCV

import scipy.integrate as integrate

# %%
# !pip install xgboost

import xgboost
from xgboost import XGBRegressor, XGBClassifier
# Out:
# Requirement already satisfied: xgboost in /home/andres/anaconda3/lib/python3.9/site-packages (1.7.4)
# Requirement already satisfied: numpy in /home/andres/anaconda3/lib/python3.9/site-packages (from xgboost) (1.23.5)
# Requirement already satisfied: scipy in /home/andres/anaconda3/lib/python3.9/site-packages (from xgboost) (1.10.0)

# %%
import h5py

import glob
import numpy as np
import os.path as path
import imageio
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D
from keras.callbacks import EarlyStopping, TensorBoard
from datetime import datetime
import keras
from keras import regularizers
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score, average_precision_score, precision_recall_curve, auc,recall_score
from keras.optimizers import Adam
from keras.regularizers import l2
import h5py
from sklearn.model_selection import GridSearchCV
from keras.backend import cast, greater, clip, floatx,epsilon
from keras.wrappers.scikit_learn import KerasClassifier
from keras import backend as K
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# ### Load Data

# %%
filefolder = '../../data2024/processed/'

###################
# BACKGROUND FILE #
###################

filename_B = 'ER/ER_all.hdf5'


###############
# SIGNAL FILE #
###############

# select the DM mass
mDM = 500

filename_S = 'mDM' + str(mDM) + 'GeV/WP_mDM' + str(mDM) + 'GeV_sig1045.hdf5'

# %%
# OPEN THE SAVED FILE TO CHECK IT
f_B = h5py.File(filefolder+filename_B,'r')
f_S = h5py.File(filefolder+filename_S,'r')

# show the groups
print( f_B.keys() )

# should be more than 10k events in each group
print('\n Background Events: ')
for groups1 in f_B.keys():
    print(len(f_B[groups1].keys()))

print('\n Signal Events')
for groups1 in f_S.keys():
    print(len(f_S[groups1].keys()))
# Out:
# <KeysViewHDF5 ['HITS_bot', 'HITS_bot_img', 'HITS_top', 'HITS_top_img', 'peakS1_onlyhits', 'peakS1_raw', 'peakS2_onlyhits', 'peakS2_raw']>
#
#  Background Events:
# 17206
# 17206
# 17206
# 17206
# 17206
# 17206
# 17206
# 17206
#
#  Signal Events
# 12286
# 12286
# 12286
# 12286
# 12286
# 12286
# 12286
# 12286

# %%
#############################
# ONLY peakS2_onlyhits DATA #
#############################

# to normalize
scaler = preprocessing.MinMaxScaler()

# Number of data points (per-class) for the ML classifier
num_data = 10000


# First:
# The max len for the time series

max_pS2_B = 0
max_pS2_S = 0

for i in range(1, num_data+1):
    max_pS2_B = max(max_pS2_B, len( f_B['peakS2_onlyhits/ev_'+str(i)] ))
    max_pS2_S = max(max_pS2_S, len( f_S['peakS2_onlyhits/ev_'+str(i)] ))
    
    
max_pS2_both = max(max_pS2_B,max_pS2_S)

print('max_pS2_both lenght: ', max_pS2_both)



# Second:
# add the events in a matrix, but all with the same length -> fill with zeros

# how many elements do we need to make all the peak (S2 or S2) arrays with the same length
diff_elem_S2_B = max_pS2_both - len( f_B['peakS2_onlyhits/ev_1'][()] )
diff_elem_S2_S = max_pS2_both - len( f_S['peakS2_onlyhits/ev_1'][()] )

# add zeros at the end
peakS2_onlyhits_B = np.pad(f_B['peakS2_onlyhits/ev_1'][()], (0, diff_elem_S2_B), 'constant')
peakS2_onlyhits_S = np.pad(f_S['peakS2_onlyhits/ev_1'][()], (0, diff_elem_S2_S), 'constant')

for i in range(2, num_data+1):
    
    # how many elements do we need to make all the peak (S2 or S2) arrays with the same length
    diff_elem_S2_B = max_pS2_both - len( f_B['peakS2_onlyhits/ev_'+str(i)][()] )
    diff_elem_S2_S = max_pS2_both - len( f_S['peakS2_onlyhits/ev_'+str(i)][()] )
    
    # add zeros at the end
    aux_S2_B = np.pad(f_B['peakS2_onlyhits/ev_'+str(i)][()], (0, diff_elem_S2_B), 'constant')
    aux_S2_S = np.pad(f_S['peakS2_onlyhits/ev_'+str(i)][()], (0, diff_elem_S2_S), 'constant')
    
    # add new event to the matrix as a row
    peakS2_onlyhits_B = np.row_stack([peakS2_onlyhits_B,aux_S2_B])
    peakS2_onlyhits_S = np.row_stack([peakS2_onlyhits_S,aux_S2_S])
    
    

# close the h5 files
f_B.close()
f_S.close()

    
    

# X and Y for the classifier
X_mon = np.row_stack([peakS2_onlyhits_B,peakS2_onlyhits_S])
# normalize
X_mon = scaler.fit_transform(X_mon)

del peakS2_onlyhits_B
del peakS2_onlyhits_S

# labels
y_mon = np.concatenate([np.zeros(num_data),np.ones(num_data)])



# divide into train-val and test data samples
test_ratio = 1./3
val_ratio = 0.25


X_mon_aux, X_mon_test, y_mon_aux, y_mon_test = train_test_split(X_mon,
                                                                y_mon,
                                                                test_size=test_ratio,
                                                                random_state=42,
                                                                #stratify = y_mon,
                                                                shuffle=True)

del X_mon
del y_mon

X_mon_train, X_mon_val, y_mon_train, y_mon_val = train_test_split(X_mon_aux,
                                                                  y_mon_aux,
                                                                  test_size=val_ratio,
                                                                  random_state=42,
                                                                  #stratify = y_mon_aux,
                                                                  shuffle=True)

del X_mon_aux
del y_mon_aux

print('')
print('X_mon_train : ', X_mon_train.shape)
print('y_mon_train : ', y_mon_train.shape)
print('X_mon_val : ', X_mon_val.shape)
print('y_mon_val : ', y_mon_val.shape)
print('X_mon_test : ', X_mon_test.shape)
print('y_mon_test : ', y_mon_test.shape)
print('')
# Out:
# max_pS2_both lenght:  2244
#
# X_mon_train :  (9999, 2244)
# y_mon_train :  (9999,)
# X_mon_val :  (3334, 2244)
# y_mon_val :  (3334,)
# X_mon_test :  (6667, 2244)
# y_mon_test :  (6667,)

# %% [markdown]
# ### CLASSIFIER

# %%
# XGBoost with only the kinematic variables of the leptons

# CLASSIFIER
classifier = XGBClassifier(
    n_estimators=500,
    learning_rate=0.1,
    reg_lambda=0.0,reg_alpha=0.0,
    gamma=0.0,objective='binary:logistic',
    max_depth=5)

# FIT
classifier.fit(X_mon_train,y_mon_train,eval_set=[(X_mon_train, y_mon_train), (X_mon_val, y_mon_val)],
        eval_metric=["error", "logloss", "map"],early_stopping_rounds=50,#early stopping
        verbose=True)

# PREDICTIONS
y_pred_xg = classifier.predict_proba(X_mon_test).T[1]


# ROC
fpr_mon_xg, tpr_mon_xg, _ = roc_curve(y_mon_test, y_pred_xg)
roc_auc_xg = auc(fpr_mon_xg, tpr_mon_xg)


# PLOT THE ROC WITH AUC
fig = plt.figure(figsize=(6, 6))
gs = gridspec.GridSpec(1, 1) 
ax0 = plt.subplot(gs[0])
ax0.yaxis.set_ticks_position('both')
ax0.xaxis.set_ticks_position('both')
ax0.tick_params(direction="in",which="both")
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
ax0.minorticks_on()


plt.plot(tpr_mon_xg,1-fpr_mon_xg,label="$f_{1}$, AUC = %0.2f" % roc_auc_xg,color="orange",ls=":",lw=4)
plt.plot([1,0],[0,1],ls=":",color="grey")
plt.xlabel("True Positive Rate",fontsize=16)
plt.ylabel("1 $-$ False Positive Rate",fontsize=16)
plt.legend()
plt.xlim([0,1])
plt.ylim([0,1])
plt.yticks([0.2,0.4,0.6,0.8,1.])
plt.legend(frameon=False,fontsize=16)
plt.show()
# Out:
# /home/andres/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# /home/andres/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-error:0.16072	validation_0-logloss:0.64219	validation_0-map:0.87138	validation_1-error:0.18716	validation_1-logloss:0.64544	validation_1-map:0.86654
# [1]	validation_0-error:0.14621	validation_0-logloss:0.59954	validation_0-map:0.90136	validation_1-error:0.17187	validation_1-logloss:0.60535	validation_1-map:0.88881
# [2]	validation_0-error:0.14341	validation_0-logloss:0.56306	validation_0-map:0.91282	validation_1-error:0.16347	validation_1-logloss:0.57141	validation_1-map:0.89595
# [3]	validation_0-error:0.13931	validation_0-logloss:0.53238	validation_0-map:0.91880	validation_1-error:0.15987	validation_1-logloss:0.54308	validation_1-map:0.89856
# [4]	validation_0-error:0.13631	validation_0-logloss:0.50513	validation_0-map:0.92433	validation_1-error:0.16197	validation_1-logloss:0.51929	validation_1-map:0.90111
# [5]	validation_0-error:0.13531	validation_0-logloss:0.48116	validation_0-map:0.92713	validation_1-error:0.15957	validation_1-logloss:0.49850	validation_1-map:0.90076
# [6]	validation_0-error:0.13291	validation_0-logloss:0.45941	validation_0-map:0.92982	validation_1-error:0.15927	validation_1-logloss:0.48066	validation_1-map:0.90211
# [7]	validation_0-error:0.13041	validation_0-logloss:0.44047	validation_0-map:0.93180	validation_1-error:0.15837	validation_1-logloss:0.46459	validation_1-map:0.90288
# [8]	validation_0-error:0.12871	validation_0-logloss:0.42363	validation_0-map:0.93440	validation_1-error:0.15627	validation_1-logloss:0.45084	validation_1-map:0.90303
# [9]	validation_0-error:0.12811	validation_0-logloss:0.40895	validation_0-map:0.93554	validation_1-error:0.15747	validation_1-logloss:0.43900	validation_1-map:0.90357
# [10]	validation_0-error:0.12501	validation_0-logloss:0.39588	validation_0-map:0.93643	validation_1-error:0.15717	validation_1-logloss:0.42874	validation_1-map:0.90443
# [11]	validation_0-error:0.12281	validation_0-logloss:0.38413	validation_0-map:0.93938	validation_1-error:0.15507	validation_1-logloss:0.41868	validation_1-map:0.90827
# [12]	validation_0-error:0.12221	validation_0-logloss:0.37327	validation_0-map:0.94087	validation_1-error:0.15597	validation_1-logloss:0.41059	validation_1-map:0.90871
# [13]	validation_0-error:0.12141	validation_0-logloss:0.36340	validation_0-map:0.94186	validation_1-error:0.15657	validation_1-logloss:0.40281	validation_1-map:0.90945
# [14]	validation_0-error:0.11931	validation_0-logloss:0.35379	validation_0-map:0.94354	validation_1-error:0.15327	validation_1-logloss:0.39566	validation_1-map:0.91003
# [15]	validation_0-error:0.11791	validation_0-logloss:0.34565	validation_0-map:0.94415	validation_1-error:0.15417	validation_1-logloss:0.38985	validation_1-map:0.91039
# [16]	validation_0-error:0.11801	validation_0-logloss:0.33890	validation_0-map:0.94464	validation_1-error:0.15297	validation_1-logloss:0.38472	validation_1-map:0.91057
# [17]	validation_0-error:0.11881	validation_0-logloss:0.33230	validation_0-map:0.94532	validation_1-error:0.15477	validation_1-logloss:0.38079	validation_1-map:0.91064
# [18]	validation_0-error:0.11801	validation_0-logloss:0.32549	validation_0-map:0.94727	validation_1-error:0.15747	validation_1-logloss:0.37703	validation_1-map:0.91096
# [19]	validation_0-error:0.11721	validation_0-logloss:0.31957	validation_0-map:0.94818	validation_1-error:0.15657	validation_1-logloss:0.37363	validation_1-map:0.91122
# [20]	validation_0-error:0.11621	validation_0-logloss:0.31409	validation_0-map:0.94907	validation_1-error:0.15567	validation_1-logloss:0.37052	validation_1-map:0.91103
# [21]	validation_0-error:0.11521	validation_0-logloss:0.30907	validation_0-map:0.95005	validation_1-error:0.15567	validation_1-logloss:0.36769	validation_1-map:0.91120
# [22]	validation_0-error:0.11421	validation_0-logloss:0.30477	validation_0-map:0.95070	validation_1-error:0.15507	validation_1-logloss:0.36527	validation_1-map:0.91141
# [23]	validation_0-error:0.11361	validation_0-logloss:0.30013	validation_0-map:0.95173	validation_1-error:0.15507	validation_1-logloss:0.36329	validation_1-map:0.91140
# [24]	validation_0-error:0.11211	validation_0-logloss:0.29625	validation_0-map:0.95252	validation_1-error:0.15477	validation_1-logloss:0.36128	validation_1-map:0.91139
# [25]	validation_0-error:0.11191	validation_0-logloss:0.29223	validation_0-map:0.95355	validation_1-error:0.15717	validation_1-logloss:0.35959	validation_1-map:0.91193
# [26]	validation_0-error:0.11141	validation_0-logloss:0.28853	validation_0-map:0.95440	validation_1-error:0.15657	validation_1-logloss:0.35793	validation_1-map:0.91212
# [27]	validation_0-error:0.11041	validation_0-logloss:0.28520	validation_0-map:0.95512	validation_1-error:0.15657	validation_1-logloss:0.35659	validation_1-map:0.91205
# [28]	validation_0-error:0.11021	validation_0-logloss:0.28130	validation_0-map:0.95631	validation_1-error:0.15507	validation_1-logloss:0.35545	validation_1-map:0.91203
# [29]	validation_0-error:0.10901	validation_0-logloss:0.27828	validation_0-map:0.95701	validation_1-error:0.15567	validation_1-logloss:0.35422	validation_1-map:0.91293
# [30]	validation_0-error:0.10721	validation_0-logloss:0.27542	validation_0-map:0.95776	validation_1-error:0.15537	validation_1-logloss:0.35335	validation_1-map:0.91282
# [31]	validation_0-error:0.10581	validation_0-logloss:0.27296	validation_0-map:0.95848	validation_1-error:0.15537	validation_1-logloss:0.35253	validation_1-map:0.91287
# [32]	validation_0-error:0.10611	validation_0-logloss:0.27028	validation_0-map:0.95915	validation_1-error:0.15447	validation_1-logloss:0.35164	validation_1-map:0.91283
# [33]	validation_0-error:0.10541	validation_0-logloss:0.26778	validation_0-map:0.95964	validation_1-error:0.15507	validation_1-logloss:0.35051	validation_1-map:0.91319
# [34]	validation_0-error:0.10381	validation_0-logloss:0.26501	validation_0-map:0.96060	validation_1-error:0.15507	validation_1-logloss:0.34991	validation_1-map:0.91325
# [35]	validation_0-error:0.10361	validation_0-logloss:0.26322	validation_0-map:0.96116	validation_1-error:0.15507	validation_1-logloss:0.34971	validation_1-map:0.91304
# [36]	validation_0-error:0.10361	validation_0-logloss:0.26099	validation_0-map:0.96180	validation_1-error:0.15477	validation_1-logloss:0.34962	validation_1-map:0.91277
# [37]	validation_0-error:0.10281	validation_0-logloss:0.25899	validation_0-map:0.96247	validation_1-error:0.15417	validation_1-logloss:0.34923	validation_1-map:0.91279
# [38]	validation_0-error:0.10241	validation_0-logloss:0.25764	validation_0-map:0.96275	validation_1-error:0.15417	validation_1-logloss:0.34893	validation_1-map:0.91290
# [39]	validation_0-error:0.10181	validation_0-logloss:0.25620	validation_0-map:0.96309	validation_1-error:0.15327	validation_1-logloss:0.34858	validation_1-map:0.91311
# [40]	validation_0-error:0.10131	validation_0-logloss:0.25442	validation_0-map:0.96385	validation_1-error:0.15417	validation_1-logloss:0.34785	validation_1-map:0.91408
# [41]	validation_0-error:0.09941	validation_0-logloss:0.25168	validation_0-map:0.96514	validation_1-error:0.15417	validation_1-logloss:0.34754	validation_1-map:0.91447
# [42]	validation_0-error:0.09921	validation_0-logloss:0.25058	validation_0-map:0.96544	validation_1-error:0.15417	validation_1-logloss:0.34713	validation_1-map:0.91467
# [43]	validation_0-error:0.09861	validation_0-logloss:0.24905	validation_0-map:0.96621	validation_1-error:0.15417	validation_1-logloss:0.34703	validation_1-map:0.91472
# [44]	validation_0-error:0.09811	validation_0-logloss:0.24734	validation_0-map:0.96664	validation_1-error:0.15267	validation_1-logloss:0.34661	validation_1-map:0.91477
# [45]	validation_0-error:0.09711	validation_0-logloss:0.24619	validation_0-map:0.96700	validation_1-error:0.15267	validation_1-logloss:0.34662	validation_1-map:0.91447
# [46]	validation_0-error:0.09631	validation_0-logloss:0.24437	validation_0-map:0.96777	validation_1-error:0.15117	validation_1-logloss:0.34628	validation_1-map:0.91438
# [47]	validation_0-error:0.09541	validation_0-logloss:0.24281	validation_0-map:0.96835	validation_1-error:0.15147	validation_1-logloss:0.34611	validation_1-map:0.91436
# [48]	validation_0-error:0.09531	validation_0-logloss:0.24192	validation_0-map:0.96879	validation_1-error:0.15177	validation_1-logloss:0.34619	validation_1-map:0.91446
# [49]	validation_0-error:0.09431	validation_0-logloss:0.24041	validation_0-map:0.96952	validation_1-error:0.15237	validation_1-logloss:0.34624	validation_1-map:0.91444
# [50]	validation_0-error:0.09341	validation_0-logloss:0.23917	validation_0-map:0.97004	validation_1-error:0.15207	validation_1-logloss:0.34643	validation_1-map:0.91436
# [51]	validation_0-error:0.09281	validation_0-logloss:0.23809	validation_0-map:0.97041	validation_1-error:0.15147	validation_1-logloss:0.34649	validation_1-map:0.91436
# [52]	validation_0-error:0.09241	validation_0-logloss:0.23693	validation_0-map:0.97077	validation_1-error:0.15237	validation_1-logloss:0.34656	validation_1-map:0.91428
# [53]	validation_0-error:0.09201	validation_0-logloss:0.23638	validation_0-map:0.97092	validation_1-error:0.15267	validation_1-logloss:0.34655	validation_1-map:0.91434
# [54]	validation_0-error:0.09151	validation_0-logloss:0.23523	validation_0-map:0.97125	validation_1-error:0.15267	validation_1-logloss:0.34660	validation_1-map:0.91444
# [55]	validation_0-error:0.09091	validation_0-logloss:0.23383	validation_0-map:0.97184	validation_1-error:0.15207	validation_1-logloss:0.34660	validation_1-map:0.91423
# [56]	validation_0-error:0.09061	validation_0-logloss:0.23327	validation_0-map:0.97203	validation_1-error:0.15147	validation_1-logloss:0.34646	validation_1-map:0.91419
# [57]	validation_0-error:0.09051	validation_0-logloss:0.23173	validation_0-map:0.97248	validation_1-error:0.15267	validation_1-logloss:0.34627	validation_1-map:0.91424
# [58]	validation_0-error:0.09021	validation_0-logloss:0.23102	validation_0-map:0.97279	validation_1-error:0.15297	validation_1-logloss:0.34618	validation_1-map:0.91448
# [59]	validation_0-error:0.08981	validation_0-logloss:0.23050	validation_0-map:0.97287	validation_1-error:0.15237	validation_1-logloss:0.34601	validation_1-map:0.91455
# [60]	validation_0-error:0.08881	validation_0-logloss:0.22951	validation_0-map:0.97319	validation_1-error:0.15327	validation_1-logloss:0.34603	validation_1-map:0.91445
# [61]	validation_0-error:0.08841	validation_0-logloss:0.22889	validation_0-map:0.97351	validation_1-error:0.15267	validation_1-logloss:0.34607	validation_1-map:0.91439
# [62]	validation_0-error:0.08711	validation_0-logloss:0.22739	validation_0-map:0.97405	validation_1-error:0.15297	validation_1-logloss:0.34586	validation_1-map:0.91444
# [63]	validation_0-error:0.08611	validation_0-logloss:0.22646	validation_0-map:0.97431	validation_1-error:0.15267	validation_1-logloss:0.34557	validation_1-map:0.91459
# [64]	validation_0-error:0.08601	validation_0-logloss:0.22559	validation_0-map:0.97445	validation_1-error:0.15297	validation_1-logloss:0.34570	validation_1-map:0.91454
# [65]	validation_0-error:0.08401	validation_0-logloss:0.22441	validation_0-map:0.97486	validation_1-error:0.15357	validation_1-logloss:0.34563	validation_1-map:0.91451
# [66]	validation_0-error:0.08311	validation_0-logloss:0.22367	validation_0-map:0.97519	validation_1-error:0.15237	validation_1-logloss:0.34565	validation_1-map:0.91454
# [67]	validation_0-error:0.08281	validation_0-logloss:0.22286	validation_0-map:0.97535	validation_1-error:0.15297	validation_1-logloss:0.34572	validation_1-map:0.91452
# [68]	validation_0-error:0.08231	validation_0-logloss:0.22220	validation_0-map:0.97567	validation_1-error:0.15267	validation_1-logloss:0.34589	validation_1-map:0.91440
# [69]	validation_0-error:0.08041	validation_0-logloss:0.22041	validation_0-map:0.97643	validation_1-error:0.15207	validation_1-logloss:0.34582	validation_1-map:0.91441
# [70]	validation_0-error:0.07911	validation_0-logloss:0.21949	validation_0-map:0.97694	validation_1-error:0.15267	validation_1-logloss:0.34590	validation_1-map:0.91440
# [71]	validation_0-error:0.07921	validation_0-logloss:0.21897	validation_0-map:0.97714	validation_1-error:0.15267	validation_1-logloss:0.34615	validation_1-map:0.91417
# [72]	validation_0-error:0.07931	validation_0-logloss:0.21851	validation_0-map:0.97724	validation_1-error:0.15237	validation_1-logloss:0.34626	validation_1-map:0.91402
# [73]	validation_0-error:0.07911	validation_0-logloss:0.21787	validation_0-map:0.97741	validation_1-error:0.15207	validation_1-logloss:0.34603	validation_1-map:0.91410
# [74]	validation_0-error:0.07811	validation_0-logloss:0.21677	validation_0-map:0.97777	validation_1-error:0.15267	validation_1-logloss:0.34592	validation_1-map:0.91417
# [75]	validation_0-error:0.07751	validation_0-logloss:0.21603	validation_0-map:0.97814	validation_1-error:0.15267	validation_1-logloss:0.34590	validation_1-map:0.91413
# [76]	validation_0-error:0.07701	validation_0-logloss:0.21544	validation_0-map:0.97835	validation_1-error:0.15297	validation_1-logloss:0.34607	validation_1-map:0.91406
# [77]	validation_0-error:0.07661	validation_0-logloss:0.21498	validation_0-map:0.97852	validation_1-error:0.15327	validation_1-logloss:0.34617	validation_1-map:0.91401
# [78]	validation_0-error:0.07621	validation_0-logloss:0.21417	validation_0-map:0.97878	validation_1-error:0.15327	validation_1-logloss:0.34640	validation_1-map:0.91388
# [79]	validation_0-error:0.07601	validation_0-logloss:0.21368	validation_0-map:0.97895	validation_1-error:0.15327	validation_1-logloss:0.34647	validation_1-map:0.91392
# [80]	validation_0-error:0.07561	validation_0-logloss:0.21316	validation_0-map:0.97908	validation_1-error:0.15357	validation_1-logloss:0.34638	validation_1-map:0.91401
# [81]	validation_0-error:0.07531	validation_0-logloss:0.21213	validation_0-map:0.97936	validation_1-error:0.15447	validation_1-logloss:0.34635	validation_1-map:0.91418
# [82]	validation_0-error:0.07471	validation_0-logloss:0.21138	validation_0-map:0.97971	validation_1-error:0.15417	validation_1-logloss:0.34623	validation_1-map:0.91448
# [83]	validation_0-error:0.07461	validation_0-logloss:0.21084	validation_0-map:0.97989	validation_1-error:0.15327	validation_1-logloss:0.34617	validation_1-map:0.91452
# [84]	validation_0-error:0.07441	validation_0-logloss:0.21052	validation_0-map:0.98000	validation_1-error:0.15357	validation_1-logloss:0.34616	validation_1-map:0.91456
# [85]	validation_0-error:0.07401	validation_0-logloss:0.21011	validation_0-map:0.98011	validation_1-error:0.15327	validation_1-logloss:0.34622	validation_1-map:0.91458
# [86]	validation_0-error:0.07261	validation_0-logloss:0.20853	validation_0-map:0.98055	validation_1-error:0.15327	validation_1-logloss:0.34584	validation_1-map:0.91465
# [87]	validation_0-error:0.07201	validation_0-logloss:0.20764	validation_0-map:0.98082	validation_1-error:0.15267	validation_1-logloss:0.34578	validation_1-map:0.91476
# [88]	validation_0-error:0.07161	validation_0-logloss:0.20702	validation_0-map:0.98100	validation_1-error:0.15297	validation_1-logloss:0.34595	validation_1-map:0.91472
# [89]	validation_0-error:0.07021	validation_0-logloss:0.20531	validation_0-map:0.98181	validation_1-error:0.15297	validation_1-logloss:0.34579	validation_1-map:0.91462
# [90]	validation_0-error:0.06951	validation_0-logloss:0.20464	validation_0-map:0.98204	validation_1-error:0.15327	validation_1-logloss:0.34574	validation_1-map:0.91472
# [91]	validation_0-error:0.06851	validation_0-logloss:0.20379	validation_0-map:0.98227	validation_1-error:0.15387	validation_1-logloss:0.34565	validation_1-map:0.91470
# [92]	validation_0-error:0.06791	validation_0-logloss:0.20323	validation_0-map:0.98241	validation_1-error:0.15387	validation_1-logloss:0.34599	validation_1-map:0.91464
# [93]	validation_0-error:0.06761	validation_0-logloss:0.20234	validation_0-map:0.98273	validation_1-error:0.15357	validation_1-logloss:0.34580	validation_1-map:0.91471
# [94]	validation_0-error:0.06701	validation_0-logloss:0.20103	validation_0-map:0.98317	validation_1-error:0.15357	validation_1-logloss:0.34565	validation_1-map:0.91483
# [95]	validation_0-error:0.06641	validation_0-logloss:0.20007	validation_0-map:0.98344	validation_1-error:0.15267	validation_1-logloss:0.34579	validation_1-map:0.91477
# [96]	validation_0-error:0.06581	validation_0-logloss:0.19906	validation_0-map:0.98369	validation_1-error:0.15297	validation_1-logloss:0.34573	validation_1-map:0.91470
# [97]	validation_0-error:0.06541	validation_0-logloss:0.19845	validation_0-map:0.98389	validation_1-error:0.15357	validation_1-logloss:0.34579	validation_1-map:0.91477
# [98]	validation_0-error:0.06521	validation_0-logloss:0.19808	validation_0-map:0.98399	validation_1-error:0.15357	validation_1-logloss:0.34585	validation_1-map:0.91478
# [99]	validation_0-error:0.06491	validation_0-logloss:0.19764	validation_0-map:0.98407	validation_1-error:0.15357	validation_1-logloss:0.34596	validation_1-map:0.91477
# [100]	validation_0-error:0.06391	validation_0-logloss:0.19621	validation_0-map:0.98462	validation_1-error:0.15387	validation_1-logloss:0.34622	validation_1-map:0.91466
# [101]	validation_0-error:0.06341	validation_0-logloss:0.19560	validation_0-map:0.98478	validation_1-error:0.15447	validation_1-logloss:0.34626	validation_1-map:0.91469
# [102]	validation_0-error:0.06301	validation_0-logloss:0.19466	validation_0-map:0.98515	validation_1-error:0.15477	validation_1-logloss:0.34632	validation_1-map:0.91454
# [103]	validation_0-error:0.06261	validation_0-logloss:0.19407	validation_0-map:0.98533	validation_1-error:0.15477	validation_1-logloss:0.34628	validation_1-map:0.91450
# [104]	validation_0-error:0.06221	validation_0-logloss:0.19338	validation_0-map:0.98553	validation_1-error:0.15507	validation_1-logloss:0.34642	validation_1-map:0.91434
# [105]	validation_0-error:0.06171	validation_0-logloss:0.19259	validation_0-map:0.98570	validation_1-error:0.15537	validation_1-logloss:0.34648	validation_1-map:0.91418
# [106]	validation_0-error:0.06061	validation_0-logloss:0.19150	validation_0-map:0.98612	validation_1-error:0.15507	validation_1-logloss:0.34684	validation_1-map:0.91398
# [107]	validation_0-error:0.06001	validation_0-logloss:0.19083	validation_0-map:0.98632	validation_1-error:0.15447	validation_1-logloss:0.34704	validation_1-map:0.91385
# [108]	validation_0-error:0.05911	validation_0-logloss:0.19005	validation_0-map:0.98654	validation_1-error:0.15537	validation_1-logloss:0.34719	validation_1-map:0.91368
# [109]	validation_0-error:0.05881	validation_0-logloss:0.18963	validation_0-map:0.98665	validation_1-error:0.15567	validation_1-logloss:0.34737	validation_1-map:0.91359
# [110]	validation_0-error:0.05841	validation_0-logloss:0.18901	validation_0-map:0.98685	validation_1-error:0.15537	validation_1-logloss:0.34753	validation_1-map:0.91359
# [111]	validation_0-error:0.05771	validation_0-logloss:0.18803	validation_0-map:0.98713	validation_1-error:0.15507	validation_1-logloss:0.34739	validation_1-map:0.91365
# [112]	validation_0-error:0.05741	validation_0-logloss:0.18772	validation_0-map:0.98720	validation_1-error:0.15477	validation_1-logloss:0.34743	validation_1-map:0.91366
# [113]	validation_0-error:0.05721	validation_0-logloss:0.18745	validation_0-map:0.98728	validation_1-error:0.15537	validation_1-logloss:0.34757	validation_1-map:0.91362
# [114]	validation_0-error:0.05691	validation_0-logloss:0.18706	validation_0-map:0.98736	validation_1-error:0.15567	validation_1-logloss:0.34779	validation_1-map:0.91339
# [115]	validation_0-error:0.05601	validation_0-logloss:0.18566	validation_0-map:0.98777	validation_1-error:0.15567	validation_1-logloss:0.34777	validation_1-map:0.91325
# [116]	validation_0-error:0.05601	validation_0-logloss:0.18531	validation_0-map:0.98783	validation_1-error:0.15567	validation_1-logloss:0.34770	validation_1-map:0.91327
# [117]	validation_0-error:0.05551	validation_0-logloss:0.18499	validation_0-map:0.98787	validation_1-error:0.15537	validation_1-logloss:0.34779	validation_1-map:0.91323
# [118]	validation_0-error:0.05511	validation_0-logloss:0.18434	validation_0-map:0.98809	validation_1-error:0.15537	validation_1-logloss:0.34780	validation_1-map:0.91316
# [119]	validation_0-error:0.05451	validation_0-logloss:0.18392	validation_0-map:0.98823	validation_1-error:0.15597	validation_1-logloss:0.34766	validation_1-map:0.91322
# [120]	validation_0-error:0.05411	validation_0-logloss:0.18316	validation_0-map:0.98842	validation_1-error:0.15657	validation_1-logloss:0.34765	validation_1-map:0.91326
# [121]	validation_0-error:0.05411	validation_0-logloss:0.18270	validation_0-map:0.98856	validation_1-error:0.15687	validation_1-logloss:0.34767	validation_1-map:0.91325
# [122]	validation_0-error:0.05391	validation_0-logloss:0.18204	validation_0-map:0.98870	validation_1-error:0.15717	validation_1-logloss:0.34776	validation_1-map:0.91319
# [123]	validation_0-error:0.05361	validation_0-logloss:0.18171	validation_0-map:0.98878	validation_1-error:0.15657	validation_1-logloss:0.34771	validation_1-map:0.91321
# [124]	validation_0-error:0.05291	validation_0-logloss:0.18120	validation_0-map:0.98891	validation_1-error:0.15657	validation_1-logloss:0.34774	validation_1-map:0.91324
# [125]	validation_0-error:0.05261	validation_0-logloss:0.18069	validation_0-map:0.98900	validation_1-error:0.15687	validation_1-logloss:0.34785	validation_1-map:0.91317
# [126]	validation_0-error:0.05281	validation_0-logloss:0.18017	validation_0-map:0.98913	validation_1-error:0.15657	validation_1-logloss:0.34777	validation_1-map:0.91321
# [127]	validation_0-error:0.05241	validation_0-logloss:0.17966	validation_0-map:0.98929	validation_1-error:0.15597	validation_1-logloss:0.34777	validation_1-map:0.91328
# [128]	validation_0-error:0.05211	validation_0-logloss:0.17924	validation_0-map:0.98937	validation_1-error:0.15537	validation_1-logloss:0.34774	validation_1-map:0.91328
# [129]	validation_0-error:0.05171	validation_0-logloss:0.17871	validation_0-map:0.98950	validation_1-error:0.15507	validation_1-logloss:0.34775	validation_1-map:0.91321
# [130]	validation_0-error:0.05131	validation_0-logloss:0.17813	validation_0-map:0.98962	validation_1-error:0.15567	validation_1-logloss:0.34779	validation_1-map:0.91320
# [131]	validation_0-error:0.05101	validation_0-logloss:0.17782	validation_0-map:0.98969	validation_1-error:0.15597	validation_1-logloss:0.34787	validation_1-map:0.91325
# [132]	validation_0-error:0.05071	validation_0-logloss:0.17736	validation_0-map:0.98981	validation_1-error:0.15627	validation_1-logloss:0.34782	validation_1-map:0.91328
# [133]	validation_0-error:0.05051	validation_0-logloss:0.17706	validation_0-map:0.98989	validation_1-error:0.15627	validation_1-logloss:0.34791	validation_1-map:0.91324
# [134]	validation_0-error:0.05011	validation_0-logloss:0.17631	validation_0-map:0.99006	validation_1-error:0.15507	validation_1-logloss:0.34810	validation_1-map:0.91304
# [135]	validation_0-error:0.04910	validation_0-logloss:0.17540	validation_0-map:0.99034	validation_1-error:0.15507	validation_1-logloss:0.34821	validation_1-map:0.91278
# [136]	validation_0-error:0.04900	validation_0-logloss:0.17476	validation_0-map:0.99044	validation_1-error:0.15537	validation_1-logloss:0.34821	validation_1-map:0.91277
# [137]	validation_0-error:0.04860	validation_0-logloss:0.17351	validation_0-map:0.99076	validation_1-error:0.15507	validation_1-logloss:0.34855	validation_1-map:0.91239
# [138]	validation_0-error:0.04820	validation_0-logloss:0.17332	validation_0-map:0.99078	validation_1-error:0.15537	validation_1-logloss:0.34864	validation_1-map:0.91236
# [139]	validation_0-error:0.04750	validation_0-logloss:0.17216	validation_0-map:0.99104	validation_1-error:0.15567	validation_1-logloss:0.34885	validation_1-map:0.91229
# [140]	validation_0-error:0.04680	validation_0-logloss:0.17043	validation_0-map:0.99154	validation_1-error:0.15477	validation_1-logloss:0.34914	validation_1-map:0.91217
# [141]	validation_0-error:0.04600	validation_0-logloss:0.16918	validation_0-map:0.99174	validation_1-error:0.15537	validation_1-logloss:0.34880	validation_1-map:0.91249
# [142]	validation_0-error:0.04520	validation_0-logloss:0.16835	validation_0-map:0.99203	validation_1-error:0.15597	validation_1-logloss:0.34907	validation_1-map:0.91220
# [143]	validation_0-error:0.04440	validation_0-logloss:0.16726	validation_0-map:0.99228	validation_1-error:0.15687	validation_1-logloss:0.34898	validation_1-map:0.91244
# [144]	validation_0-error:0.04440	validation_0-logloss:0.16700	validation_0-map:0.99233	validation_1-error:0.15717	validation_1-logloss:0.34908	validation_1-map:0.91239

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import auc, precision_recall_curve

precision_xg, recall_xg, _ = precision_recall_curve(y_mon_test, y_pred_xg)
auc_xg = auc(recall_xg, precision_xg)

plt.figure(figsize=(6, 6))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.plot(recall_xg, precision_xg, label=f'AP (XGBoost) = {auc_xg:.2f}')
plt.title('Precision-Recall Curve', size=16)
plt.xlabel('Recall', size=16)
plt.ylabel('Precision', size=16)
plt.legend(frameon=False,fontsize=16)
plt.show()

# %%
predictions = [round(value) for value in y_pred_xg]
accuracy = accuracy_score(y_mon_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))

results = classifier.evals_result()
epochs = len(results["validation_0"]["error"])
x_axis = range(0, epochs)


# plot log loss
fig, ax = plt.subplots(figsize=(7,5))
ax.plot(x_axis, results["validation_0"]["logloss"], label="Train")
ax.plot(x_axis, results["validation_1"]["logloss"], label="Validation")
ax.legend()
plt.ylabel("Log Loss")
plt.title("XGBoost Log Loss")
plt.show()

# plot classification error
fig, ax = plt.subplots(figsize=(7,5))
ax.plot(x_axis, results["validation_0"]["error"], label="Train")
ax.plot(x_axis, results["validation_1"]["error"], label="Validation")
ax.legend()
plt.ylabel("Classification Error")
plt.title("XGBoost Classification Error")
plt.show()
# Out:
# Accuracy: 84.00%

# %%
# XGBoost with the kinematic variables of the leptons

########################
# CLASSIFICATION SCORE #
########################

# Outputs for validation data set

pred_XG_SM = []
pred_XG_NP = []

for i in range(len(y_mon_test)):
    if y_mon_test[i] == 0:
        pred_XG_SM.append(y_pred_xg[i])
    else:
        pred_XG_NP.append(y_pred_xg[i])
        
        
print('Classification score:')
        
weights = np.ones_like(pred_XG_SM)/float(len(pred_XG_SM))
nSM, binsSM, patchesSM = plt.hist(pred_XG_SM, 50, weights=weights, range=[0,1], histtype='step', color='firebrick', linewidth=2, label='Background')

weights = np.ones_like(pred_XG_NP)/float(len(pred_XG_NP))
nNP, binsNP, patchesNP = plt.hist(pred_XG_NP, 50, weights=weights, range=[0,1], histtype='step', color='forestgreen', linewidth=2, label='Signal')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Classication score (XGBoost)",fontsize=15)
plt.ylabel("Fraction of events",fontsize=14)
plt.grid()
plt.legend(fontsize=12)

plt.show()
# Out:
# Classification score:
