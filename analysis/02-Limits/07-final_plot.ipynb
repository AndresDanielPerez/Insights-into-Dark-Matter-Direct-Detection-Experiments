# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate

# %% [markdown]
# ### XENON

# %%
x_XENON1T_1tonyr_down = [6.055606916561549, 6.823778108538652, 7.726215280067716, 8.582423845905856, 9.904912022713336, 11.596190805697788, 14.105146244789573, 17.91067828986308, 22.419318490487267, 28.741287837312296, 37.55681861498598, 46.12118051468561, 57.18227249733948, 70.55823652254493, 95.79168238706818, 141.05146244789574, 199.9078624971397, 281.97296360054435, 435.5160347143599, 663.0965425825532, 1004.7885762566482]
y_XENON1T_1tonyr_down = [2.122997019253291e-44, 6.830827595149092e-45, 2.5565879564232304e-45, 1.0450855592138182e-45, 3.814128748283239e-46, 1.6397373222443297e-46, 7.13879927716957e-47, 3.4375712618817914e-47, 2.296937143881235e-47, 1.807931378879487e-47, 1.5939048066202329e-47, 1.57394815950498e-47, 1.6141144911444228e-47, 1.7629420229546865e-47, 2.1840435093891482e-47, 2.99267938153686e-47, 4.3126768942716094e-47, 5.984360998261109e-47, 9.301141506038491e-47, 1.4275218465524083e-46, 2.218713527075558e-46]

x_XENON1T_1tonyr_up = [5.998025375267653, 6.694623244123534, 7.837740338641554, 9.176046414544945, 10.340054351159923, 12.047941859795849, 14.240556819126223, 17.57167968977445, 22.419318490487267, 28.604313898938127, 36.495613101538225, 45.03259469748133, 54.77586085235927, 70.22197324875098, 93.0849924905222, 139.0444078719906, 196.1241707554598, 274.00553519070826, 411.25186818001043, 650.5459961419798, 995.2342449249492]
y_XENON1T_1tonyr_up = [8.70579590515474e-44, 3.137473218474891e-44, 8.046532229280133e-45, 2.7573536821266015e-45, 1.2156689420722025e-45, 5.6367138959821105e-46, 2.7486819276573736e-46, 1.4639514554724662e-46, 8.956129880675696e-47, 6.702940894624926e-47, 5.909433198208975e-47, 5.909433198208975e-47, 6.293693784124586e-47, 6.873996431179536e-47, 8.409314634569101e-47, 1.1236099983376527e-46, 1.5013107289081836e-46, 2.057166738834862e-46, 3.0401858742608336e-46, 4.785094961345878e-46, 7.252122247218222e-46]

x_XENON1T_1tonyr_dat = [5.940991365202825, 6.5679129168455805, 7.616277137894846, 8.874272903135752, 10.340054351159923, 11.990524319733609, 14.308748811391741, 17.156940060795215, 20.76956429087212, 25.142875087521656, 30.147625520495286, 36.14858369857204, 45.901378264580416, 60.267473771664314, 83.39918867052648, 123.98267316495033, 183.43638249062232, 276.63601106438455, 407.34135734995056, 638.2329961306843, 990.4912022713337]
y_XENON1T_1tonyr_dat = [2.4080691095438086e-44, 9.84373819664703e-45, 2.936650461687786e-45, 1.0320004592606233e-45, 4.492941663683521e-46, 2.362985258610077e-46, 1.2744862586397517e-46, 7.699400454191772e-47, 5.479161357412966e-47, 4.422734147010833e-47, 4.1007103760403667e-47, 4.2586795849318555e-47, 4.830527157087775e-47, 5.984360998261109e-47, 7.797023884122048e-47, 1.1095417251641934e-46, 1.5989333808583735e-46, 2.3333992615362496e-46, 3.448416377736618e-46, 5.427628610945291e-46, 8.542806062673913e-46]

# %%
f_XE_up = interpolate.interp1d(x_XENON1T_1tonyr_up, y_XENON1T_1tonyr_up)
f_XE_down = interpolate.interp1d(x_XENON1T_1tonyr_down, y_XENON1T_1tonyr_down)

# %% [markdown]
# ### ML results

# %% [markdown]
# #### 0. cs1 cs2

# %%
cross_cs1cs2 = np.loadtxt('results/cs1cs2.txt')[0]
cross_cs1cs2_up = np.loadtxt('results/cs1cs2.txt')[1]
cross_cs1cs2_down =np.loadtxt('results/cs1cs2.txt')[2]

cross_cs1cs2_MLL = np.loadtxt('results/cs1cs2_MLL.txt')[0]
cross_cs1cs2_MLL_up = np.loadtxt('results/cs1cs2_MLL.txt')[1]
cross_cs1cs2_MLL_down = np.loadtxt('results/cs1cs2_MLL.txt')[2]


cross_cs1cs2ratio = np.loadtxt('results/cs1cs2ratio.txt')[0]
cross_cs1cs2ratio_up = np.loadtxt('results/cs1cs2ratio.txt')[1]
cross_cs1cs2ratio_down =np.loadtxt('results/cs1cs2ratio.txt')[2]

cross_cs1cs2ratio_MLL = np.loadtxt('results/cs1cs2ratio_MLL.txt')[0]
cross_cs1cs2ratio_MLL_up = np.loadtxt('results/cs1cs2ratio_MLL.txt')[1]
cross_cs1cs2ratio_MLL_down = np.loadtxt('results/cs1cs2ratio_MLL.txt')[2]

# %% [markdown]
# #### 1. Compressed Features

# %%
cross_17feats = np.loadtxt('results/17feats.txt')[0]
cross_17feats_up = np.loadtxt('results/17feats.txt')[1]
cross_17feats_down =np.loadtxt('results/17feats.txt')[2]

cross_17feats_MLL = np.loadtxt('results/17feats_MLL.txt')[0]
cross_17feats_MLL_up = np.loadtxt('results/17feats_MLL.txt')[1]
cross_17feats_MLL_down = np.loadtxt('results/17feats_MLL.txt')[2]


cross_16feats = np.loadtxt('results/16feats.txt')[0]
cross_16feats_up = np.loadtxt('results/16feats.txt')[1]
cross_16feats_down =np.loadtxt('results/16feats.txt')[2]

cross_16feats_MLL = np.loadtxt('results/16feats_MLL.txt')[0]
cross_16feats_MLL_up = np.loadtxt('results/16feats_MLL.txt')[1]
cross_16feats_MLL_down = np.loadtxt('results/16feats_MLL.txt')[2]

# %%
cross_15feats = np.loadtxt('results/15feats.txt')[0]
cross_15feats_up = np.loadtxt('results/15feats.txt')[1]
cross_15feats_down =np.loadtxt('results/15feats.txt')[2]

cross_15feats_MLL = np.loadtxt('results/15feats_MLL.txt')[0]
cross_15feats_MLL_up = np.loadtxt('results/15feats_MLL.txt')[1]
cross_15feats_MLL_down = np.loadtxt('results/15feats_MLL.txt')[2]


cross_14feats = np.loadtxt('results/14feats.txt')[0]
cross_14feats_up = np.loadtxt('results/14feats.txt')[1]
cross_14feats_down =np.loadtxt('results/14feats.txt')[2]

cross_14feats_MLL = np.loadtxt('results/14feats_MLL.txt')[0]
cross_14feats_MLL_up = np.loadtxt('results/14feats_MLL.txt')[1]
cross_14feats_MLL_down = np.loadtxt('results/14feats_MLL.txt')[2]

# %% [markdown]
# #### 3. Raw data as arrays

# %%
cross_arrays = np.loadtxt('results/arrays.txt')[0]
cross_arrays_up = np.loadtxt('results/arrays.txt')[1]
cross_arrays_down =np.loadtxt('results/arrays.txt')[2]

cross_arrays_MLL = np.loadtxt('results/arrays_MLL.txt')[0]
cross_arrays_MLL_up = np.loadtxt('results/arrays_MLL.txt')[1]
cross_arrays_MLL_down =np.loadtxt('results/arrays_MLL.txt')[2]


cross_arraysdt = np.loadtxt('results/arraysdt.txt')[0]
cross_arraysdt_up = np.loadtxt('results/arraysdt.txt')[1]
cross_arraysdt_down =np.loadtxt('results/arraysdt.txt')[2]

cross_arraysdt_MLL = np.loadtxt('results/arraysdt_MLL.txt')[0]
cross_arraysdt_MLL_up = np.loadtxt('results/arraysdt_MLL.txt')[1]
cross_arraysdt_MLL_down =np.loadtxt('results/arraysdt_MLL.txt')[2]


cross_arrays17feats = np.loadtxt('results/arrays17feats.txt')[0]
cross_arrays17feats_up = np.loadtxt('results/arrays17feats.txt')[1]
cross_arrays17feats_down =np.loadtxt('results/arrays17feats.txt')[2]

cross_arrays17feats_MLL = np.loadtxt('results/arrays17feats_MLL.txt')[0]
cross_arrays17feats_MLL_up = np.loadtxt('results/arrays17feats_MLL.txt')[1]
cross_arrays17feats_MLL_down =np.loadtxt('results/arrays17feats_MLL.txt')[2]

# %% [markdown]
# #### 4. Raw data as images

# %%
cross_images = np.loadtxt('results/images.txt')[0]
cross_images_up = np.loadtxt('results/images.txt')[1]
cross_images_down =np.loadtxt('results/images.txt')[2]

cross_images_MLL = np.loadtxt('results/images_MLL.txt')[0]
cross_images_MLL_up = np.loadtxt('results/images_MLL.txt')[1]
cross_images_MLL_down =np.loadtxt('results/images_MLL.txt')[2]


cross_imagesdt = np.loadtxt('results/imagesdt.txt')[0]
cross_imagesdt_up = np.loadtxt('results/imagesdt.txt')[1]
cross_imagesdt_down =np.loadtxt('results/imagesdt.txt')[2]

cross_imagesdt_MLL = np.loadtxt('results/imagesdt_MLL.txt')[0]
cross_imagesdt_MLL_up = np.loadtxt('results/imagesdt_MLL.txt')[1]
cross_imagesdt_MLL_down =np.loadtxt('results/imagesdt_MLL.txt')[2]


cross_images17feats = np.loadtxt('results/images17feats.txt')[0]
cross_images17feats_up = np.loadtxt('results/images17feats.txt')[1]
cross_images17feats_down =np.loadtxt('results/images17feats.txt')[2]

cross_images17feats_MLL = np.loadtxt('results/images17feats_MLL.txt')[0]
cross_images17feats_MLL_up = np.loadtxt('results/images17feats_MLL.txt')[1]
cross_images17feats_MLL_down =np.loadtxt('results/images17feats_MLL.txt')[2]

# %%
mDM_mDM = [10, 20, 35, 50, 100, 200, 500]

# %%
# plot
plt.figure()
lw = 2

plt.plot(mDM_mDM, cross_cs1cs2, '-', color='red', lw=lw, label=r'cS1, cS2 (BL)')
plt.plot(mDM_mDM, cross_cs1cs2_up, ':', color='red', lw=lw) 
plt.plot(mDM_mDM, cross_cs1cs2_down, ':', color='red', lw=lw)
plt.plot(mDM_mDM, cross_cs1cs2_MLL, '-', color='darkorange', lw=lw, label=r'cS2, cS1 (MLL)')
plt.plot(mDM_mDM, cross_cs1cs2_MLL_up, ':', color='darkorange', lw=lw) 
plt.plot(mDM_mDM, cross_cs1cs2_MLL_down, ':', color='darkorange', lw=lw)
plt.plot(mDM_mDM, cross_cs1cs2ratio, '-', color='blue', lw=lw, label=r'cS2/cS1')
plt.plot(mDM_mDM, cross_cs1cs2ratio_up, ':', color='blue', lw=lw) 
plt.plot(mDM_mDM, cross_cs1cs2ratio_down, ':', color='blue', lw=lw)
plt.plot(mDM_mDM, cross_cs1cs2ratio_MLL, '-', color='dodgerblue', lw=lw, label=r'cS2/cS1 (MLL)')
plt.plot(mDM_mDM, cross_cs1cs2ratio_MLL_up, ':', color='dodgerblue', lw=lw) 
plt.plot(mDM_mDM, cross_cs1cs2ratio_MLL_down, ':', color='dodgerblue', lw=lw)
#plt.plot(x_XENON1T_1tonyr_dat, y_XENON1T_1tonyr_dat, '--', color='green', lw=lw, label='XENON1T')
plt.plot(x_XENON1T_1tonyr_up, y_XENON1T_1tonyr_up, ':', color='black', lw=lw, label='XENON1T, 1 ton.yr (1$\sigma$ band)')
plt.plot(x_XENON1T_1tonyr_down, y_XENON1T_1tonyr_down, ':', color='black', lw=lw)


plt.xscale('log')
plt.yscale('log')
plt.xlim(6,1000)
plt.ylim(1e-47, 1e-43)
plt.xlabel(r'$m_{dm}$ [GeV]', fontsize=14)
plt.ylabel(r'$\sigma$ [cm$^2$]', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.legend(loc="upper right", fontsize=12)
plt.show()

# %%
# plot
plt.figure()
lw = 2

plt.plot(mDM_mDM, cross_cs1cs2, '-', color='red', lw=lw, label=r'cS1, cS2')
plt.plot(mDM_mDM, cross_cs1cs2_up, ':', color='red', lw=lw) 
plt.plot(mDM_mDM, cross_cs1cs2_down, ':', color='red', lw=lw)
plt.plot(mDM_mDM, cross_cs1cs2ratio, '-', color='blue', lw=lw, label=r'cS2/cS1')
plt.plot(mDM_mDM, cross_cs1cs2ratio_up, ':', color='blue', lw=lw) 
plt.plot(mDM_mDM, cross_cs1cs2ratio_down, ':', color='blue', lw=lw)

plt.plot(mDM_mDM, cross_17feats, '-', color='green', lw=lw, label=r'17 resumed features')
plt.plot(mDM_mDM, cross_17feats_up, ':', color='green', lw=lw) 
plt.plot(mDM_mDM, cross_17feats_down, ':', color='green', lw=lw)
plt.plot(mDM_mDM, cross_16feats, '-', color='magenta', lw=lw, label=r'16 resumed features')
plt.plot(mDM_mDM, cross_16feats_up, ':', color='magenta', lw=lw) 
plt.plot(mDM_mDM, cross_16feats_down, ':', color='magenta', lw=lw)


plt.plot(mDM_mDM, cross_arrays17feats, '-', color='darkorange', lw=lw, label=r'Raw data (array) + 17 features')
plt.plot(mDM_mDM, cross_arrays17feats_up, ':', color='darkorange', lw=lw) 
plt.plot(mDM_mDM, cross_arrays17feats_down, ':', color='darkorange', lw=lw)
plt.plot(mDM_mDM, cross_arrays, '-', color='dodgerblue', lw=lw, label=r'Raw data (array)')
plt.plot(mDM_mDM, cross_arrays_up, ':', color='dodgerblue', lw=lw) 
plt.plot(mDM_mDM, cross_arrays_down, ':', color='dodgerblue', lw=lw)


plt.plot(mDM_mDM, cross_images17feats, '-', color='limegreen', lw=lw, label=r'Raw data (images) + 17 features')
plt.plot(mDM_mDM, cross_images17feats_up, ':', color='limegreen', lw=lw) 
plt.plot(mDM_mDM, cross_images17feats_down, ':', color='limegreen', lw=lw)
plt.plot(mDM_mDM, cross_images, '-', color='purple', lw=lw, label=r'Raw data (images)')
plt.plot(mDM_mDM, cross_images_up, ':', color='purple', lw=lw) 
plt.plot(mDM_mDM, cross_images_down, ':', color='purple', lw=lw)

#plt.plot(x_XENON1T_1tonyr_dat, y_XENON1T_1tonyr_dat, '--', color='green', lw=lw, label='XENON1T')
plt.plot(x_XENON1T_1tonyr_up, y_XENON1T_1tonyr_up, ':', color='black', lw=lw, label='XENON1T, 1 ton.yr (1$\sigma$ band)')
plt.plot(x_XENON1T_1tonyr_down, y_XENON1T_1tonyr_down, ':', color='black', lw=lw)


plt.xscale('log')
plt.yscale('log')
plt.xlim(10,1000)
plt.ylim(1e-47, 2e-44)
plt.xlabel(r'$m_{dm}$ [GeV]', fontsize=14)
plt.ylabel(r'$\sigma$ [cm$^2$]', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.legend(loc="upper right", fontsize=12)
plt.show()

# %%
# plot
plt.figure()
lw = 2

plt.plot(mDM_mDM, cross_cs1cs2, '-', color='red', lw=lw, label=r'cS1, cS2')
plt.plot(mDM_mDM, cross_cs1cs2_up, ':', color='red', lw=lw) 
plt.plot(mDM_mDM, cross_cs1cs2_down, ':', color='red', lw=lw)
plt.plot(mDM_mDM, cross_cs1cs2ratio, '-', color='magenta', lw=lw, label=r'cS2/cS1')
plt.plot(mDM_mDM, cross_cs1cs2ratio_up, ':', color='magenta', lw=lw) 
plt.plot(mDM_mDM, cross_cs1cs2ratio_down, ':', color='magenta', lw=lw)

# plt.plot(mDM_mDM, cross_17feats, '-', color='green', lw=lw, label=r'17 resumed features')
# plt.plot(mDM_mDM, cross_17feats_up, ':', color='green', lw=lw) 
# plt.plot(mDM_mDM, cross_17feats_down, ':', color='green', lw=lw)
# plt.plot(mDM_mDM, cross_16feats, '-', color='magenta', lw=lw, label=r'16 resumed features')
# plt.plot(mDM_mDM, cross_16feats_up, ':', color='magenta', lw=lw) 
# plt.plot(mDM_mDM, cross_16feats_down, ':', color='magenta', lw=lw)


# plt.plot(mDM_mDM, cross_arrays17feats, '-', color='darkorange', lw=lw, label=r'Raw data (array) + 17 features')
# plt.plot(mDM_mDM, cross_arrays17feats_up, ':', color='darkorange', lw=lw) 
# plt.plot(mDM_mDM, cross_arrays17feats_down, ':', color='darkorange', lw=lw)
# plt.plot(mDM_mDM, cross_arrays, '-', color='dodgerblue', lw=lw, label=r'Raw data (array)')
# plt.plot(mDM_mDM, cross_arrays_up, ':', color='dodgerblue', lw=lw) 
# plt.plot(mDM_mDM, cross_arrays_down, ':', color='dodgerblue', lw=lw)


# plt.plot(mDM_mDM, cross_images17feats, '-', color='limegreen', lw=lw, label=r'Raw data (images) + 17 features')
# plt.plot(mDM_mDM, cross_images17feats_up, ':', color='limegreen', lw=lw) 
# plt.plot(mDM_mDM, cross_images17feats_down, ':', color='limegreen', lw=lw)
plt.plot(mDM_mDM, cross_images, '-', color='dodgerblue', lw=lw, label=r'Raw data (images)')
plt.plot(mDM_mDM, cross_images_up, ':', color='dodgerblue', lw=lw) 
plt.plot(mDM_mDM, cross_images_down, ':', color='dodgerblue', lw=lw)

#plt.plot(x_XENON1T_1tonyr_dat, y_XENON1T_1tonyr_dat, '--', color='green', lw=lw, label='XENON1T')
plt.plot(x_XENON1T_1tonyr_up, y_XENON1T_1tonyr_up, ':', color='black', lw=lw, label='XENON1T, 1 ton.yr (1$\sigma$ band)')
plt.plot(x_XENON1T_1tonyr_down, y_XENON1T_1tonyr_down, ':', color='black', lw=lw)


plt.title('Binned Analysis', fontsize=14)
plt.xscale('log')
plt.yscale('log')
plt.xlim(10,500)
plt.ylim(1e-47, 2e-44)
plt.xlabel(r'$m_{dm}$ [GeV]', fontsize=14)
plt.ylabel(r'$\sigma^{SI}_{dm-\mathcal{N}}$ [cm$^2$]', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.legend(loc="upper right", fontsize=12)
# plt.savefig('limits1.pdf',bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(2,1,figsize=(6,5.7), gridspec_kw={'height_ratios': [3, 1]})

lw = 2

# things to plots
p_aux1 = cross_cs1cs2
p_aux1_up = cross_cs1cs2_up
p_aux1_down = cross_cs1cs2_down
c1 = 'coral'
l1 = r'cS1, cS2'

p_aux2 = cross_images
p_aux2_up = cross_images_up
p_aux2_down = cross_images_down
c2 = 'dodgerblue'
l2 = r'Raw data (images)'

p_aux3 = cross_arrays
p_aux3_up = cross_arrays_up
p_aux3_down = cross_arrays_down
c3 = 'magenta'
l3 = r'Raw data (arrays)'

p_aux4 = cross_16feats
p_aux4_up = cross_16feats_up
p_aux4_down = cross_16feats_down
c4 = 'seagreen'
l4 = r'16 resumed features'

axs[0].plot(mDM_mDM, mDM_mDM, '-', color=None, alpha=0., lw=3, label='Binned Analysis:')

axs[0].plot(mDM_mDM, p_aux1, '-', color=c1, lw=3, label=l1)
axs[0].plot(mDM_mDM, p_aux1_up, ':', color=c1, lw=lw)
axs[0].plot(mDM_mDM, p_aux1_down, ':', color=c1, lw=lw)

axs[0].plot(mDM_mDM, p_aux4, '-', color=c4, lw=3, label=l4)
axs[0].plot(mDM_mDM, p_aux4_up, ':', color=c4, lw=lw)
axs[0].plot(mDM_mDM, p_aux4_down, ':', color=c4, lw=lw)

axs[0].plot(mDM_mDM, p_aux2, '-', color=c2, lw=3, label=l2)
axs[0].plot(mDM_mDM, p_aux2_up, ':', color=c2, lw=lw)
axs[0].plot(mDM_mDM, p_aux2_down, ':', color=c2, lw=lw)

axs[0].plot(mDM_mDM, p_aux3, '-', color=c3, lw=3, label=l3)
axs[0].plot(mDM_mDM, p_aux3_up, ':', color=c3, lw=lw)
axs[0].plot(mDM_mDM, p_aux3_down, ':', color=c3, lw=lw)

axs[0].fill(
    np.append(x_XENON1T_1tonyr_up, x_XENON1T_1tonyr_down[::-1]),
    np.append(y_XENON1T_1tonyr_up, y_XENON1T_1tonyr_down[::-1]), color = 'gray', edgecolor=None, alpha=0.3,
    label='XENON1T, 1 ton.yr (1$\sigma$ band)'
)


# Normalize
norm = p_aux1

Np_aux1 = [ a/b for a, b in zip(p_aux1,norm)]
Np_aux1_up = [ a/b for a, b in zip(p_aux1_up,norm)]
Np_aux1_down = [ a/b for a, b in zip(p_aux1_down,norm)]

Np_aux2 = [ a/b for a, b in zip(p_aux2,norm)]
Np_aux2_up = [ a/b for a, b in zip(p_aux2_up,norm)]
Np_aux2_down = [ a/b for a, b in zip(p_aux2_down,norm)]

Np_aux3 = [ a/b for a, b in zip(p_aux3,norm)]
Np_aux3_up = [ a/b for a, b in zip(p_aux3_up,norm)]
Np_aux3_down = [ a/b for a, b in zip(p_aux3_down,norm)]

Np_aux4 = [ a/b for a, b in zip(p_aux4,norm)]
Np_aux4_up = [ a/b for a, b in zip(p_aux4_up,norm)]
Np_aux4_down = [ a/b for a, b in zip(p_aux4_down,norm)]

Np_XE_up = [ a/b for a, b in zip(f_XE_up(mDM_mDM),norm)]
Np_XE_down = [ a/b for a, b in zip(f_XE_down(mDM_mDM),norm)]





axs[1].plot(mDM_mDM, Np_aux1, '-', color=c1, lw=3, label=l1)
axs[1].plot(mDM_mDM, Np_aux1_up, ':', color=c1, lw=lw)
axs[1].plot(mDM_mDM, Np_aux1_down, ':', color=c1, lw=lw)

axs[1].plot(mDM_mDM, Np_aux4, '-', color=c4, lw=3, label=l4)
axs[1].plot(mDM_mDM, Np_aux4_up, ':', color=c4, lw=lw)
axs[1].plot(mDM_mDM, Np_aux4_down, ':', color=c4, lw=lw)

axs[1].plot(mDM_mDM, Np_aux2, '-', color=c2, lw=3, label=l2)
axs[1].plot(mDM_mDM, Np_aux2_up, ':', color=c2, lw=lw)
axs[1].plot(mDM_mDM, Np_aux2_down, ':', color=c2, lw=lw)

axs[1].plot(mDM_mDM, Np_aux3, '-', color=c3, lw=3, label=l3)
axs[1].plot(mDM_mDM, Np_aux3_up, ':', color=c3, lw=lw)
axs[1].plot(mDM_mDM, Np_aux3_down, ':', color=c3, lw=lw)


axs[1].fill(
    np.append(mDM_mDM, mDM_mDM[::-1]),
    np.append(Np_XE_up, Np_XE_down[::-1]), color = 'gray', edgecolor=None, alpha=0.3,
    label='XENON1T, 1 ton.yr (1$\sigma$ band)'
)


axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[1].set_xscale('log')
# axs[1].set_yscale('log')

axs[0].set_xlim([10, 500])
axs[0].set_ylim([1e-47, 2e-44])
axs[1].set_xlim([10, 500])
axs[1].set_ylim([0,3.5])
axs[0].set_ylabel(r'$\sigma^{SI}_{dm-\mathcal{N}}$ [cm$^2$]', fontsize=14)
axs[1].set_xlabel(r'$m_{dm}$ [GeV]', fontsize=14)
axs[1].set_ylabel(r'Normalized', fontsize=14)

axs[0].yaxis.set_tick_params(labelsize=14)
axs[0].xaxis.set_tick_params(labelsize=14)
axs[0].xaxis.set_ticklabels([])
axs[1].yaxis.set_ticks([0,1,2,3])
axs[1].xaxis.set_tick_params(labelsize=14)
axs[1].yaxis.set_tick_params(labelsize=14)

axs[0].grid()
axs[1].grid()

# axs[0].set_title('Binned Analysis', fontsize=14)
axs[0].legend(loc="upper right", fontsize=12)
plt.tight_layout()
plt.savefig('limits1A.pdf', format="pdf", bbox_inches="tight")
plt.show()

# %%
fig, axs = plt.subplots(2,1,figsize=(6,5.7), gridspec_kw={'height_ratios': [3, 1]})

lw = 2

# things to plots
p_aux1 = cross_cs1cs2
p_aux1_up = cross_cs1cs2_up
p_aux1_down = cross_cs1cs2_down
c1 = 'coral'
l1 = r'cS1, cS2'

p_aux2 = cross_images
p_aux2_up = cross_images_up
p_aux2_down = cross_images_down
c2 = 'dodgerblue'
l2 = r'Raw data (images)'

p_aux3 = cross_arrays
p_aux3_up = cross_arrays_up
p_aux3_down = cross_arrays_down
c3 = 'magenta'
l3 = r'Raw data (arrays)'

p_aux4 = cross_14feats
p_aux4_up = cross_14feats_up
p_aux4_down = cross_14feats_down
c4 = 'seagreen'
l4 = r'14 resumed features'

axs[0].plot(mDM_mDM, mDM_mDM, '-', color=None, alpha=0., lw=3, label='Binned Analysis:')

axs[0].plot(mDM_mDM, p_aux1, '-', color=c1, lw=3, label=l1)
axs[0].plot(mDM_mDM, p_aux1_up, ':', color=c1, lw=lw)
axs[0].plot(mDM_mDM, p_aux1_down, ':', color=c1, lw=lw)

axs[0].plot(mDM_mDM, p_aux4, '-', color=c4, lw=3, label=l4)
axs[0].plot(mDM_mDM, p_aux4_up, ':', color=c4, lw=lw)
axs[0].plot(mDM_mDM, p_aux4_down, ':', color=c4, lw=lw)

axs[0].plot(mDM_mDM, p_aux2, '-', color=c2, lw=3, label=l2)
axs[0].plot(mDM_mDM, p_aux2_up, ':', color=c2, lw=lw)
axs[0].plot(mDM_mDM, p_aux2_down, ':', color=c2, lw=lw)

axs[0].plot(mDM_mDM, p_aux3, '-', color=c3, lw=3, label=l3)
axs[0].plot(mDM_mDM, p_aux3_up, ':', color=c3, lw=lw)
axs[0].plot(mDM_mDM, p_aux3_down, ':', color=c3, lw=lw)

axs[0].fill(
    np.append(x_XENON1T_1tonyr_up, x_XENON1T_1tonyr_down[::-1]),
    np.append(y_XENON1T_1tonyr_up, y_XENON1T_1tonyr_down[::-1]), color = 'gray', edgecolor=None, alpha=0.3,
    label='XENON1T, 1 ton.yr (1$\sigma$ band)'
)


# Normalize
norm = p_aux1

Np_aux1 = [ a/b for a, b in zip(p_aux1,norm)]
Np_aux1_up = [ a/b for a, b in zip(p_aux1_up,norm)]
Np_aux1_down = [ a/b for a, b in zip(p_aux1_down,norm)]

Np_aux2 = [ a/b for a, b in zip(p_aux2,norm)]
Np_aux2_up = [ a/b for a, b in zip(p_aux2_up,norm)]
Np_aux2_down = [ a/b for a, b in zip(p_aux2_down,norm)]

Np_aux3 = [ a/b for a, b in zip(p_aux3,norm)]
Np_aux3_up = [ a/b for a, b in zip(p_aux3_up,norm)]
Np_aux3_down = [ a/b for a, b in zip(p_aux3_down,norm)]

Np_aux4 = [ a/b for a, b in zip(p_aux4,norm)]
Np_aux4_up = [ a/b for a, b in zip(p_aux4_up,norm)]
Np_aux4_down = [ a/b for a, b in zip(p_aux4_down,norm)]

Np_XE_up = [ a/b for a, b in zip(f_XE_up(mDM_mDM),norm)]
Np_XE_down = [ a/b for a, b in zip(f_XE_down(mDM_mDM),norm)]





axs[1].plot(mDM_mDM, Np_aux1, '-', color=c1, lw=3, label=l1)
axs[1].plot(mDM_mDM, Np_aux1_up, ':', color=c1, lw=lw)
axs[1].plot(mDM_mDM, Np_aux1_down, ':', color=c1, lw=lw)

axs[1].plot(mDM_mDM, Np_aux4, '-', color=c4, lw=3, label=l4)
axs[1].plot(mDM_mDM, Np_aux4_up, ':', color=c4, lw=lw)
axs[1].plot(mDM_mDM, Np_aux4_down, ':', color=c4, lw=lw)

axs[1].plot(mDM_mDM, Np_aux2, '-', color=c2, lw=3, label=l2)
axs[1].plot(mDM_mDM, Np_aux2_up, ':', color=c2, lw=lw)
axs[1].plot(mDM_mDM, Np_aux2_down, ':', color=c2, lw=lw)

axs[1].plot(mDM_mDM, Np_aux3, '-', color=c3, lw=3, label=l3)
axs[1].plot(mDM_mDM, Np_aux3_up, ':', color=c3, lw=lw)
axs[1].plot(mDM_mDM, Np_aux3_down, ':', color=c3, lw=lw)


axs[1].fill(
    np.append(mDM_mDM, mDM_mDM[::-1]),
    np.append(Np_XE_up, Np_XE_down[::-1]), color = 'gray', edgecolor=None, alpha=0.3,
    label='XENON1T, 1 ton.yr (1$\sigma$ band)'
)


axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[1].set_xscale('log')
# axs[1].set_yscale('log')

axs[0].set_xlim([10, 500])
axs[0].set_ylim([1e-47, 2e-44])
axs[1].set_xlim([10, 500])
axs[1].set_ylim([0,3.5])
axs[0].set_ylabel(r'$\sigma^{SI}_{dm-\mathcal{N}}$ [cm$^2$]', fontsize=14)
axs[1].set_xlabel(r'$m_{dm}$ [GeV]', fontsize=14)
axs[1].set_ylabel(r'Normalized', fontsize=14)

axs[0].yaxis.set_tick_params(labelsize=14)
axs[0].xaxis.set_tick_params(labelsize=14)
axs[0].xaxis.set_ticklabels([])
axs[1].yaxis.set_ticks([0,1,2,3])
axs[1].xaxis.set_tick_params(labelsize=14)
axs[1].yaxis.set_tick_params(labelsize=14)

axs[0].grid()
axs[1].grid()

# axs[0].set_title('Binned Analysis', fontsize=14)
axs[0].legend(loc="upper right", fontsize=12)
plt.tight_layout()
plt.savefig('limits1A_14feats.pdf', format="pdf", bbox_inches="tight")
plt.show()

# %%
# plot
plt.figure()
lw = 2

plt.plot(mDM_mDM, cross_cs1cs2, '-', color='red', lw=lw, label=r'cS1, cS2')
plt.plot(mDM_mDM, cross_cs1cs2_up, ':', color='red', lw=lw) 
plt.plot(mDM_mDM, cross_cs1cs2_down, ':', color='red', lw=lw)
# plt.plot(mDM_mDM, cross_cs1cs2ratio, '-', color='blue', lw=lw, label=r'cS2/cS1')
# plt.plot(mDM_mDM, cross_cs1cs2ratio_up, ':', color='blue', lw=lw) 
# plt.plot(mDM_mDM, cross_cs1cs2ratio_down, ':', color='blue', lw=lw)

plt.plot(mDM_mDM, cross_17feats, '-', color='green', lw=lw, label=r'17 resumed features')
plt.plot(mDM_mDM, cross_17feats_up, ':', color='green', lw=lw) 
plt.plot(mDM_mDM, cross_17feats_down, ':', color='green', lw=lw)
# plt.plot(mDM_mDM, cross_16feats, '-', color='magenta', lw=lw, label=r'16 resumed features')
# plt.plot(mDM_mDM, cross_16feats_up, ':', color='magenta', lw=lw) 
# plt.plot(mDM_mDM, cross_16feats_down, ':', color='magenta', lw=lw)


plt.plot(mDM_mDM, cross_arrays17feats, '-', color='darkorange', lw=lw, label=r'Raw data (array) + 17 features')
plt.plot(mDM_mDM, cross_arrays17feats_up, ':', color='darkorange', lw=lw) 
plt.plot(mDM_mDM, cross_arrays17feats_down, ':', color='darkorange', lw=lw)
# plt.plot(mDM_mDM, cross_arrays, '-', color='dodgerblue', lw=lw, label=r'Raw data (array)')
# plt.plot(mDM_mDM, cross_arrays_up, ':', color='dodgerblue', lw=lw) 
# plt.plot(mDM_mDM, cross_arrays_down, ':', color='dodgerblue', lw=lw)


plt.plot(mDM_mDM, cross_images17feats, '-', color='blue', lw=lw, label=r'Raw data (images) + 17 features')
plt.plot(mDM_mDM, cross_images17feats_up, ':', color='blue', lw=lw) 
plt.plot(mDM_mDM, cross_images17feats_down, ':', color='blue', lw=lw)
# plt.plot(mDM_mDM, cross_images, '-', color='purple', lw=lw, label=r'Raw data (images)')
# plt.plot(mDM_mDM, cross_images_up, ':', color='purple', lw=lw) 
# plt.plot(mDM_mDM, cross_images_down, ':', color='purple', lw=lw)

#plt.plot(x_XENON1T_1tonyr_dat, y_XENON1T_1tonyr_dat, '--', color='green', lw=lw, label='XENON1T')
plt.plot(x_XENON1T_1tonyr_up, y_XENON1T_1tonyr_up, ':', color='black', lw=lw, label='XENON1T, 1 ton.yr (1$\sigma$ band)')
plt.plot(x_XENON1T_1tonyr_down, y_XENON1T_1tonyr_down, ':', color='black', lw=lw)

plt.title('Binned Analysis', fontsize=14)
plt.xscale('log')
plt.yscale('log')
plt.xlim(10,500)
plt.ylim(1e-47, 2e-44)
plt.xlabel(r'$m_{dm}$ [GeV]', fontsize=14)
plt.ylabel(r'$\sigma^{SI}_{dm-\mathcal{N}}$ [cm$^2$]', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.legend(loc="upper right", fontsize=12)
# plt.savefig('limits2.pdf',bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(2,1,figsize=(6,5.7), gridspec_kw={'height_ratios': [3, 1]})

lw = 2

# things to plots
p_aux1 = cross_cs1cs2
p_aux1_up = cross_cs1cs2_up
p_aux1_down = cross_cs1cs2_down
c1 = 'coral'
l1 = r'cS1, cS2'

p_aux2 = cross_17feats
p_aux2_up = cross_17feats_up
p_aux2_down = cross_17feats_down
c2 = 'seagreen'
l2 = r'16 resumed features + $\Delta t$'

p_aux3 = cross_arraysdt
p_aux3_up = cross_arrays_up
p_aux3_down = cross_arraysdt_down
c3 = 'magenta'
l3 = r'Raw data (array) + $\Delta t$'

p_aux4 = cross_imagesdt
p_aux4_up = cross_imagesdt_up
p_aux4_down = cross_imagesdt_down
c4 = 'dodgerblue'
l4 = r'Raw data (images) + $\Delta t$'

axs[0].plot(mDM_mDM, p_aux1, '-', color=c1, lw=3, label=l1)
axs[0].plot(mDM_mDM, p_aux1_up, ':', color=c1, lw=lw)
axs[0].plot(mDM_mDM, p_aux1_down, ':', color=c1, lw=lw)

axs[0].plot(mDM_mDM, p_aux2, '-', color=c2, lw=3, label=l2)
axs[0].plot(mDM_mDM, p_aux2_up, ':', color=c2, lw=lw)
axs[0].plot(mDM_mDM, p_aux2_down, ':', color=c2, lw=lw)

axs[0].plot(mDM_mDM, p_aux3, '-', color=c3, lw=3, label=l3)
axs[0].plot(mDM_mDM, p_aux3_up, ':', color=c3, lw=lw)
axs[0].plot(mDM_mDM, p_aux3_down, ':', color=c3, lw=lw)

axs[0].plot(mDM_mDM, p_aux4, '-', color=c4, lw=3, label=l4)
axs[0].plot(mDM_mDM, p_aux4_up, ':', color=c4, lw=lw)
axs[0].plot(mDM_mDM, p_aux4_down, ':', color=c4, lw=lw)

axs[0].fill(
    np.append(x_XENON1T_1tonyr_up, x_XENON1T_1tonyr_down[::-1]),
    np.append(y_XENON1T_1tonyr_up, y_XENON1T_1tonyr_down[::-1]), color = 'gray', edgecolor=None, alpha=0.3,
    label='XENON1T, 1 ton.yr (1$\sigma$ band)'
)


# Normalize
norm = p_aux1

Np_aux1 = [ a/b for a, b in zip(p_aux1,norm)]
Np_aux1_up = [ a/b for a, b in zip(p_aux1_up,norm)]
Np_aux1_down = [ a/b for a, b in zip(p_aux1_down,norm)]

Np_aux2 = [ a/b for a, b in zip(p_aux2,norm)]
Np_aux2_up = [ a/b for a, b in zip(p_aux2_up,norm)]
Np_aux2_down = [ a/b for a, b in zip(p_aux2_down,norm)]

Np_aux3 = [ a/b for a, b in zip(p_aux3,norm)]
Np_aux3_up = [ a/b for a, b in zip(p_aux3_up,norm)]
Np_aux3_down = [ a/b for a, b in zip(p_aux3_down,norm)]

Np_aux4 = [ a/b for a, b in zip(p_aux4,norm)]
Np_aux4_up = [ a/b for a, b in zip(p_aux4_up,norm)]
Np_aux4_down = [ a/b for a, b in zip(p_aux4_down,norm)]

Np_XE_up = [ a/b for a, b in zip(f_XE_up(mDM_mDM),norm)]
Np_XE_down = [ a/b for a, b in zip(f_XE_down(mDM_mDM),norm)]





axs[1].plot(mDM_mDM, Np_aux1, '-', color=c1, lw=3, label=l1)
axs[1].plot(mDM_mDM, Np_aux1_up, ':', color=c1, lw=lw)
axs[1].plot(mDM_mDM, Np_aux1_down, ':', color=c1, lw=lw)

axs[1].plot(mDM_mDM, Np_aux2, '-', color=c2, lw=3, label=l2)
axs[1].plot(mDM_mDM, Np_aux2_up, ':', color=c2, lw=lw)
axs[1].plot(mDM_mDM, Np_aux2_down, ':', color=c2, lw=lw)

axs[1].plot(mDM_mDM, Np_aux3, '-', color=c3, lw=3, label=l3)
axs[1].plot(mDM_mDM, Np_aux3_up, ':', color=c3, lw=lw)
axs[1].plot(mDM_mDM, Np_aux3_down, ':', color=c3, lw=lw)

axs[1].plot(mDM_mDM, Np_aux4, '-', color=c4, lw=3, label=l4)
axs[1].plot(mDM_mDM, Np_aux4_up, ':', color=c4, lw=lw)
axs[1].plot(mDM_mDM, Np_aux4_down, ':', color=c4, lw=lw)


axs[1].fill(
    np.append(mDM_mDM, mDM_mDM[::-1]),
    np.append(Np_XE_up, Np_XE_down[::-1]), color = 'gray', edgecolor=None, alpha=0.3,
    label='XENON1T, 1 ton.yr (1$\sigma$ band)'
)


axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[1].set_xscale('log')
# axs[1].set_yscale('log')

axs[0].set_xlim([10, 500])
axs[0].set_ylim([1e-47, 1e-44])
axs[1].set_xlim([10, 500])
axs[1].set_ylim([0.,3.5])
axs[0].set_ylabel(r'$\sigma^{SI}_{dm-\mathcal{N}}$ [cm$^2$]', fontsize=14)
axs[1].set_xlabel(r'$m_{dm}$ [GeV]', fontsize=14)
axs[1].set_ylabel(r'Normalized', fontsize=14)

axs[0].yaxis.set_tick_params(labelsize=14)
axs[0].xaxis.set_tick_params(labelsize=14)
axs[0].xaxis.set_ticklabels([])
axs[1].yaxis.set_ticks([0,1,2,3])
axs[1].xaxis.set_tick_params(labelsize=14)
axs[1].yaxis.set_tick_params(labelsize=14)

axs[0].grid()
axs[1].grid()

axs[0].set_title('Binned Analysis', fontsize=14)
axs[0].legend(loc="upper right", fontsize=12)
plt.tight_layout()
plt.savefig('limits2A.pdf', format="pdf", bbox_inches="tight")
plt.show()

# %%
fig, axs = plt.subplots(2,1,figsize=(6,5.7), gridspec_kw={'height_ratios': [3, 1]})

lw = 2

# things to plots
p_aux1 = cross_cs1cs2
p_aux1_up = cross_cs1cs2_up
p_aux1_down = cross_cs1cs2_down
c1 = 'coral'
l1 = r'cS1, cS2'

p_aux2 = cross_15feats
p_aux2_up = cross_15feats_up
p_aux2_down = cross_15feats_down
c2 = 'seagreen'
l2 = r'14 resumed features + $\Delta t$'

p_aux3 = cross_arraysdt
p_aux3_up = cross_arrays_up
p_aux3_down = cross_arraysdt_down
c3 = 'magenta'
l3 = r'Raw data (array) + $\Delta t$'

p_aux4 = cross_imagesdt
p_aux4_up = cross_imagesdt_up
p_aux4_down = cross_imagesdt_down
c4 = 'dodgerblue'
l4 = r'Raw data (images) + $\Delta t$'

axs[0].plot(mDM_mDM, p_aux1, '-', color=c1, lw=3, label=l1)
axs[0].plot(mDM_mDM, p_aux1_up, ':', color=c1, lw=lw)
axs[0].plot(mDM_mDM, p_aux1_down, ':', color=c1, lw=lw)

axs[0].plot(mDM_mDM, p_aux2, '-', color=c2, lw=3, label=l2)
axs[0].plot(mDM_mDM, p_aux2_up, ':', color=c2, lw=lw)
axs[0].plot(mDM_mDM, p_aux2_down, ':', color=c2, lw=lw)

axs[0].plot(mDM_mDM, p_aux3, '-', color=c3, lw=3, label=l3)
axs[0].plot(mDM_mDM, p_aux3_up, ':', color=c3, lw=lw)
axs[0].plot(mDM_mDM, p_aux3_down, ':', color=c3, lw=lw)

axs[0].plot(mDM_mDM, p_aux4, '-', color=c4, lw=3, label=l4)
axs[0].plot(mDM_mDM, p_aux4_up, ':', color=c4, lw=lw)
axs[0].plot(mDM_mDM, p_aux4_down, ':', color=c4, lw=lw)

axs[0].fill(
    np.append(x_XENON1T_1tonyr_up, x_XENON1T_1tonyr_down[::-1]),
    np.append(y_XENON1T_1tonyr_up, y_XENON1T_1tonyr_down[::-1]), color = 'gray', edgecolor=None, alpha=0.3,
    label='XENON1T, 1 ton.yr (1$\sigma$ band)'
)


# Normalize
norm = p_aux1

Np_aux1 = [ a/b for a, b in zip(p_aux1,norm)]
Np_aux1_up = [ a/b for a, b in zip(p_aux1_up,norm)]
Np_aux1_down = [ a/b for a, b in zip(p_aux1_down,norm)]

Np_aux2 = [ a/b for a, b in zip(p_aux2,norm)]
Np_aux2_up = [ a/b for a, b in zip(p_aux2_up,norm)]
Np_aux2_down = [ a/b for a, b in zip(p_aux2_down,norm)]

Np_aux3 = [ a/b for a, b in zip(p_aux3,norm)]
Np_aux3_up = [ a/b for a, b in zip(p_aux3_up,norm)]
Np_aux3_down = [ a/b for a, b in zip(p_aux3_down,norm)]

Np_aux4 = [ a/b for a, b in zip(p_aux4,norm)]
Np_aux4_up = [ a/b for a, b in zip(p_aux4_up,norm)]
Np_aux4_down = [ a/b for a, b in zip(p_aux4_down,norm)]

Np_XE_up = [ a/b for a, b in zip(f_XE_up(mDM_mDM),norm)]
Np_XE_down = [ a/b for a, b in zip(f_XE_down(mDM_mDM),norm)]





axs[1].plot(mDM_mDM, Np_aux1, '-', color=c1, lw=3, label=l1)
axs[1].plot(mDM_mDM, Np_aux1_up, ':', color=c1, lw=lw)
axs[1].plot(mDM_mDM, Np_aux1_down, ':', color=c1, lw=lw)

axs[1].plot(mDM_mDM, Np_aux2, '-', color=c2, lw=3, label=l2)
axs[1].plot(mDM_mDM, Np_aux2_up, ':', color=c2, lw=lw)
axs[1].plot(mDM_mDM, Np_aux2_down, ':', color=c2, lw=lw)

axs[1].plot(mDM_mDM, Np_aux3, '-', color=c3, lw=3, label=l3)
axs[1].plot(mDM_mDM, Np_aux3_up, ':', color=c3, lw=lw)
axs[1].plot(mDM_mDM, Np_aux3_down, ':', color=c3, lw=lw)

axs[1].plot(mDM_mDM, Np_aux4, '-', color=c4, lw=3, label=l4)
axs[1].plot(mDM_mDM, Np_aux4_up, ':', color=c4, lw=lw)
axs[1].plot(mDM_mDM, Np_aux4_down, ':', color=c4, lw=lw)


axs[1].fill(
    np.append(mDM_mDM, mDM_mDM[::-1]),
    np.append(Np_XE_up, Np_XE_down[::-1]), color = 'gray', edgecolor=None, alpha=0.3,
    label='XENON1T, 1 ton.yr (1$\sigma$ band)'
)


axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[1].set_xscale('log')
# axs[1].set_yscale('log')

axs[0].set_xlim([10, 500])
axs[0].set_ylim([1e-47, 1e-44])
axs[1].set_xlim([10, 500])
axs[1].set_ylim([0.,3.5])
axs[0].set_ylabel(r'$\sigma^{SI}_{dm-\mathcal{N}}$ [cm$^2$]', fontsize=14)
axs[1].set_xlabel(r'$m_{dm}$ [GeV]', fontsize=14)
axs[1].set_ylabel(r'Normalized', fontsize=14)

axs[0].yaxis.set_tick_params(labelsize=14)
axs[0].xaxis.set_tick_params(labelsize=14)
axs[0].xaxis.set_ticklabels([])
axs[1].yaxis.set_ticks([0,1,2,3])
axs[1].xaxis.set_tick_params(labelsize=14)
axs[1].yaxis.set_tick_params(labelsize=14)

axs[0].grid()
axs[1].grid()

axs[0].set_title('Binned Analysis', fontsize=14)
axs[0].legend(loc="upper right", fontsize=12)
plt.tight_layout()
plt.savefig('limits2A_14feats.pdf', format="pdf", bbox_inches="tight")
plt.show()

# %%
# plot
plt.figure()
lw = 2

plt.plot(mDM_mDM, cross_cs1cs2_MLL, '-', color='red', lw=lw, label=r'cS1, cS2')
plt.plot(mDM_mDM, cross_cs1cs2_MLL_up, ':', color='red', lw=lw) 
plt.plot(mDM_mDM, cross_cs1cs2_MLL_down, ':', color='red', lw=lw)
# plt.plot(mDM_mDM, cross_cs1cs2ratio_MLL, '-', color='blue', lw=lw, label=r'cS2/cS1')
# plt.plot(mDM_mDM, cross_cs1cs2ratio_MLL_up, ':', color='blue', lw=lw) 
# plt.plot(mDM_mDM, cross_cs1cs2ratio_MLL_down, ':', color='blue', lw=lw)

plt.plot(mDM_mDM, cross_17feats_MLL, '-', color='green', lw=lw, label=r'17 resumed features')
plt.plot(mDM_mDM, cross_17feats_MLL_up, ':', color='green', lw=lw) 
plt.plot(mDM_mDM, cross_17feats_MLL_down, ':', color='green', lw=lw)
# plt.plot(mDM_mDM, cross_16feats_MLL, '-', color='magenta', lw=lw, label=r'16 resumed features')
# plt.plot(mDM_mDM, cross_16feats_MLL_up, ':', color='magenta', lw=lw) 
# plt.plot(mDM_mDM, cross_16feats_MLL_down, ':', color='magenta', lw=lw)


plt.plot(mDM_mDM, cross_arrays17feats_MLL, '-', color='darkorange', lw=lw, label=r'Raw data (array) + 17 features')
plt.plot(mDM_mDM, cross_arrays17feats_MLL_up, ':', color='darkorange', lw=lw) 
plt.plot(mDM_mDM, cross_arrays17feats_MLL_down, ':', color='darkorange', lw=lw)
# plt.plot(mDM_mDM, cross_arrays_MLL, '-', color='dodgerblue', lw=lw, label=r'Raw data (array)')
# plt.plot(mDM_mDM, cross_arrays_MLL_up, ':', color='dodgerblue', lw=lw) 
# plt.plot(mDM_mDM, cross_arrays_MLL_down, ':', color='dodgerblue', lw=lw)


plt.plot(mDM_mDM, cross_images17feats_MLL, '-', color='blue', lw=lw, label=r'Raw data (images) + 17 features')
plt.plot(mDM_mDM, cross_images17feats_MLL_up, ':', color='blue', lw=lw) 
plt.plot(mDM_mDM, cross_images17feats_MLL_down, ':', color='blue', lw=lw)
# plt.plot(mDM_mDM, cross_images_MLL, '-', color='purple', lw=lw, label=r'Raw data (images)')
# plt.plot(mDM_mDM, cross_images_MLL_up, ':', color='purple', lw=lw) 
# plt.plot(mDM_mDM, cross_images_MLL_down, ':', color='purple', lw=lw)

#plt.plot(x_XENON1T_1tonyr_dat, y_XENON1T_1tonyr_dat, '--', color='green', lw=lw, label='XENON1T')
plt.plot(x_XENON1T_1tonyr_up, y_XENON1T_1tonyr_up, ':', color='black', lw=lw, label='XENON1T, 1 ton.yr (1$\sigma$ band)')
plt.plot(x_XENON1T_1tonyr_down, y_XENON1T_1tonyr_down, ':', color='black', lw=lw)

plt.title('Unbinned Analysis', fontsize=14)
plt.xscale('log')
plt.yscale('log')
plt.xlim(10,500)
plt.ylim(1e-47, 1e-44)
plt.xlabel(r'$m_{dm}$ [GeV]', fontsize=14)
plt.ylabel(r'$\sigma^{SI}_{dm-\mathcal{N}}$ [cm$^2$]', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.legend(loc="upper right", fontsize=12)
# plt.savefig('limits3.pdf',bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(2,1,figsize=(6,5.7), gridspec_kw={'height_ratios': [3, 1]})

lw = 2

# things to plots
p_aux1 = cross_cs1cs2_MLL
p_aux1_up = cross_cs1cs2_MLL_up
p_aux1_down = cross_cs1cs2_MLL_down
c1 = 'coral'
l1 = r'cS1, cS2'

p_aux2 = cross_17feats_MLL
p_aux2_up = cross_17feats_MLL_up
p_aux2_down = cross_17feats_MLL_down
c2 = 'seagreen'
l2 = r'16 resumed features + $\Delta t$'

p_aux3 = cross_arraysdt_MLL
p_aux3_up = cross_arraysdt_MLL_up
p_aux3_down = cross_arraysdt_MLL_down
c3 = 'magenta'
l3 = r'Raw data (array) + $\Delta t$'

p_aux4 = cross_imagesdt_MLL
p_aux4_up = cross_imagesdt_MLL_up
p_aux4_down = cross_imagesdt_MLL_down
c4 = 'dodgerblue'
l4 = r'Raw data (images) + $\Delta t$'

axs[0].plot(mDM_mDM, p_aux1, '-', color=c1, lw=3, label=l1)
axs[0].plot(mDM_mDM, p_aux1_up, ':', color=c1, lw=lw)
axs[0].plot(mDM_mDM, p_aux1_down, ':', color=c1, lw=lw)

axs[0].plot(mDM_mDM, p_aux2, '-', color=c2, lw=3, label=l2)
axs[0].plot(mDM_mDM, p_aux2_up, ':', color=c2, lw=lw)
axs[0].plot(mDM_mDM, p_aux2_down, ':', color=c2, lw=lw)

axs[0].plot(mDM_mDM, p_aux3, '-', color=c3, lw=3, label=l3)
axs[0].plot(mDM_mDM, p_aux3_up, ':', color=c3, lw=lw)
axs[0].plot(mDM_mDM, p_aux3_down, ':', color=c3, lw=lw)

axs[0].plot(mDM_mDM, p_aux4, '-', color=c4, lw=3, label=l4)
axs[0].plot(mDM_mDM, p_aux4_up, ':', color=c4, lw=lw)
axs[0].plot(mDM_mDM, p_aux4_down, ':', color=c4, lw=lw)

axs[0].fill(
    np.append(x_XENON1T_1tonyr_up, x_XENON1T_1tonyr_down[::-1]),
    np.append(y_XENON1T_1tonyr_up, y_XENON1T_1tonyr_down[::-1]), color = 'gray', edgecolor=None, alpha=0.3,
    label='XENON1T, 1 ton.yr (1$\sigma$ band)'
)


# Normalize
norm = p_aux1

Np_aux1 = [ a/b for a, b in zip(p_aux1,norm)]
Np_aux1_up = [ a/b for a, b in zip(p_aux1_up,norm)]
Np_aux1_down = [ a/b for a, b in zip(p_aux1_down,norm)]

Np_aux2 = [ a/b for a, b in zip(p_aux2,norm)]
Np_aux2_up = [ a/b for a, b in zip(p_aux2_up,norm)]
Np_aux2_down = [ a/b for a, b in zip(p_aux2_down,norm)]

Np_aux3 = [ a/b for a, b in zip(p_aux3,norm)]
Np_aux3_up = [ a/b for a, b in zip(p_aux3_up,norm)]
Np_aux3_down = [ a/b for a, b in zip(p_aux3_down,norm)]

Np_aux4 = [ a/b for a, b in zip(p_aux4,norm)]
Np_aux4_up = [ a/b for a, b in zip(p_aux4_up,norm)]
Np_aux4_down = [ a/b for a, b in zip(p_aux4_down,norm)]

Np_XE_up = [ a/b for a, b in zip(f_XE_up(mDM_mDM),norm)]
Np_XE_down = [ a/b for a, b in zip(f_XE_down(mDM_mDM),norm)]





axs[1].plot(mDM_mDM, Np_aux1, '-', color=c1, lw=3, label=l1)
axs[1].plot(mDM_mDM, Np_aux1_up, ':', color=c1, lw=lw)
axs[1].plot(mDM_mDM, Np_aux1_down, ':', color=c1, lw=lw)

axs[1].plot(mDM_mDM, Np_aux2, '-', color=c2, lw=3, label=l2)
axs[1].plot(mDM_mDM, Np_aux2_up, ':', color=c2, lw=lw)
axs[1].plot(mDM_mDM, Np_aux2_down, ':', color=c2, lw=lw)

axs[1].plot(mDM_mDM, Np_aux3, '-', color=c3, lw=3, label=l3)
axs[1].plot(mDM_mDM, Np_aux3_up, ':', color=c3, lw=lw)
axs[1].plot(mDM_mDM, Np_aux3_down, ':', color=c3, lw=lw)

axs[1].plot(mDM_mDM, Np_aux4, '-', color=c4, lw=3, label=l4)
axs[1].plot(mDM_mDM, Np_aux4_up, ':', color=c4, lw=lw)
axs[1].plot(mDM_mDM, Np_aux4_down, ':', color=c4, lw=lw)


axs[1].fill(
    np.append(mDM_mDM, mDM_mDM[::-1]),
    np.append(Np_XE_up, Np_XE_down[::-1]), color = 'gray', edgecolor=None, alpha=0.3,
    label='XENON1T, 1 ton.yr (1$\sigma$ band)'
)


axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[1].set_xscale('log')
# axs[1].set_yscale('log')

axs[0].set_xlim([10, 500])
axs[0].set_ylim([1e-47, 1e-44])
axs[1].set_xlim([10, 500])
axs[1].set_ylim([0,3.5])
axs[0].set_ylabel(r'$\sigma^{SI}_{dm-\mathcal{N}}$ [cm$^2$]', fontsize=14)
axs[1].set_xlabel(r'$m_{dm}$ [GeV]', fontsize=14)
axs[1].set_ylabel(r'Normalized', fontsize=14)

axs[0].yaxis.set_tick_params(labelsize=14)
axs[0].xaxis.set_tick_params(labelsize=14)
axs[0].xaxis.set_ticklabels([])
axs[1].yaxis.set_ticks([0, 1, 2, 3])
axs[1].xaxis.set_tick_params(labelsize=14)
axs[1].yaxis.set_tick_params(labelsize=14)

axs[0].grid()
axs[1].grid()

axs[0].set_title('Unbinned Analysis', fontsize=14)
axs[0].legend(loc="upper right", fontsize=12)
plt.tight_layout()
plt.savefig('limits2B.pdf', format="pdf", bbox_inches="tight")
plt.show()

# %%
fig, axs = plt.subplots(2,1,figsize=(6,5.7), gridspec_kw={'height_ratios': [3, 1]})

lw = 2

# things to plots
p_aux1 = cross_cs1cs2_MLL
p_aux1_up = cross_cs1cs2_MLL_up
p_aux1_down = cross_cs1cs2_MLL_down
c1 = 'coral'
l1 = r'cS1, cS2'

p_aux2 = cross_15feats_MLL
p_aux2_up = cross_15feats_MLL_up
p_aux2_down = cross_15feats_MLL_down
c2 = 'seagreen'
l2 = r'14 resumed features + $\Delta t$'

p_aux3 = cross_arraysdt_MLL
p_aux3_up = cross_arraysdt_MLL_up
p_aux3_down = cross_arraysdt_MLL_down
c3 = 'magenta'
l3 = r'Raw data (array) + $\Delta t$'

p_aux4 = cross_imagesdt_MLL
p_aux4_up = cross_imagesdt_MLL_up
p_aux4_down = cross_imagesdt_MLL_down
c4 = 'dodgerblue'
l4 = r'Raw data (images) + $\Delta t$'

axs[0].plot(mDM_mDM, p_aux1, '-', color=c1, lw=3, label=l1)
axs[0].plot(mDM_mDM, p_aux1_up, ':', color=c1, lw=lw)
axs[0].plot(mDM_mDM, p_aux1_down, ':', color=c1, lw=lw)

axs[0].plot(mDM_mDM, p_aux2, '-', color=c2, lw=3, label=l2)
axs[0].plot(mDM_mDM, p_aux2_up, ':', color=c2, lw=lw)
axs[0].plot(mDM_mDM, p_aux2_down, ':', color=c2, lw=lw)

axs[0].plot(mDM_mDM, p_aux3, '-', color=c3, lw=3, label=l3)
axs[0].plot(mDM_mDM, p_aux3_up, ':', color=c3, lw=lw)
axs[0].plot(mDM_mDM, p_aux3_down, ':', color=c3, lw=lw)

axs[0].plot(mDM_mDM, p_aux4, '-', color=c4, lw=3, label=l4)
axs[0].plot(mDM_mDM, p_aux4_up, ':', color=c4, lw=lw)
axs[0].plot(mDM_mDM, p_aux4_down, ':', color=c4, lw=lw)

axs[0].fill(
    np.append(x_XENON1T_1tonyr_up, x_XENON1T_1tonyr_down[::-1]),
    np.append(y_XENON1T_1tonyr_up, y_XENON1T_1tonyr_down[::-1]), color = 'gray', edgecolor=None, alpha=0.3,
    label='XENON1T, 1 ton.yr (1$\sigma$ band)'
)


# Normalize
norm = p_aux1

Np_aux1 = [ a/b for a, b in zip(p_aux1,norm)]
Np_aux1_up = [ a/b for a, b in zip(p_aux1_up,norm)]
Np_aux1_down = [ a/b for a, b in zip(p_aux1_down,norm)]

Np_aux2 = [ a/b for a, b in zip(p_aux2,norm)]
Np_aux2_up = [ a/b for a, b in zip(p_aux2_up,norm)]
Np_aux2_down = [ a/b for a, b in zip(p_aux2_down,norm)]

Np_aux3 = [ a/b for a, b in zip(p_aux3,norm)]
Np_aux3_up = [ a/b for a, b in zip(p_aux3_up,norm)]
Np_aux3_down = [ a/b for a, b in zip(p_aux3_down,norm)]

Np_aux4 = [ a/b for a, b in zip(p_aux4,norm)]
Np_aux4_up = [ a/b for a, b in zip(p_aux4_up,norm)]
Np_aux4_down = [ a/b for a, b in zip(p_aux4_down,norm)]

Np_XE_up = [ a/b for a, b in zip(f_XE_up(mDM_mDM),norm)]
Np_XE_down = [ a/b for a, b in zip(f_XE_down(mDM_mDM),norm)]





axs[1].plot(mDM_mDM, Np_aux1, '-', color=c1, lw=3, label=l1)
axs[1].plot(mDM_mDM, Np_aux1_up, ':', color=c1, lw=lw)
axs[1].plot(mDM_mDM, Np_aux1_down, ':', color=c1, lw=lw)

axs[1].plot(mDM_mDM, Np_aux2, '-', color=c2, lw=3, label=l2)
axs[1].plot(mDM_mDM, Np_aux2_up, ':', color=c2, lw=lw)
axs[1].plot(mDM_mDM, Np_aux2_down, ':', color=c2, lw=lw)

axs[1].plot(mDM_mDM, Np_aux3, '-', color=c3, lw=3, label=l3)
axs[1].plot(mDM_mDM, Np_aux3_up, ':', color=c3, lw=lw)
axs[1].plot(mDM_mDM, Np_aux3_down, ':', color=c3, lw=lw)

axs[1].plot(mDM_mDM, Np_aux4, '-', color=c4, lw=3, label=l4)
axs[1].plot(mDM_mDM, Np_aux4_up, ':', color=c4, lw=lw)
axs[1].plot(mDM_mDM, Np_aux4_down, ':', color=c4, lw=lw)


axs[1].fill(
    np.append(mDM_mDM, mDM_mDM[::-1]),
    np.append(Np_XE_up, Np_XE_down[::-1]), color = 'gray', edgecolor=None, alpha=0.3,
    label='XENON1T, 1 ton.yr (1$\sigma$ band)'
)


axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[1].set_xscale('log')
# axs[1].set_yscale('log')

axs[0].set_xlim([10, 500])
axs[0].set_ylim([1e-47, 1e-44])
axs[1].set_xlim([10, 500])
axs[1].set_ylim([0,3.5])
axs[0].set_ylabel(r'$\sigma^{SI}_{dm-\mathcal{N}}$ [cm$^2$]', fontsize=14)
axs[1].set_xlabel(r'$m_{dm}$ [GeV]', fontsize=14)
axs[1].set_ylabel(r'Normalized', fontsize=14)

axs[0].yaxis.set_tick_params(labelsize=14)
axs[0].xaxis.set_tick_params(labelsize=14)
axs[0].xaxis.set_ticklabels([])
axs[1].yaxis.set_ticks([0, 1, 2, 3])
axs[1].xaxis.set_tick_params(labelsize=14)
axs[1].yaxis.set_tick_params(labelsize=14)

axs[0].grid()
axs[1].grid()

axs[0].set_title('Unbinned Analysis', fontsize=14)
axs[0].legend(loc="upper right", fontsize=12)
plt.tight_layout()
plt.savefig('limits2B_14feats.pdf', format="pdf", bbox_inches="tight")
plt.show()

# %%
fig, axs = plt.subplots(2,1,figsize=(6,5.7), gridspec_kw={'height_ratios': [3, 1]})

lw = 2

# things to plots
p_aux1 = cross_cs1cs2
p_aux1_up = cross_cs1cs2_up
p_aux1_down = cross_cs1cs2_down
c1 = 'coral'
l1 = r'cS1, cS2 (Binned)'

p_aux2 = cross_cs1cs2_MLL
p_aux2_up = cross_cs1cs2_MLL_up
p_aux2_down = cross_cs1cs2_MLL_down
c2 = 'darkviolet'
l2 = r'cS1, cS2 (Unbinned)'


axs[0].plot(mDM_mDM, p_aux1, '-', color=c1, lw=3, label=l1)
axs[0].plot(mDM_mDM, p_aux1_up, ':', color=c1, lw=lw)
axs[0].plot(mDM_mDM, p_aux1_down, ':', color=c1, lw=lw)

axs[0].plot(mDM_mDM, p_aux2, '-', color=c2, lw=3, label=l2)
axs[0].plot(mDM_mDM, p_aux2_up, ':', color=c2, lw=lw)
axs[0].plot(mDM_mDM, p_aux2_down, ':', color=c2, lw=lw)


axs[0].fill(
    np.append(x_XENON1T_1tonyr_up, x_XENON1T_1tonyr_down[::-1]),
    np.append(y_XENON1T_1tonyr_up, y_XENON1T_1tonyr_down[::-1]), color = 'gray', edgecolor=None, alpha=0.3,
    label='XENON1T, 1 ton.yr (1$\sigma$ band)'
)


# Normalize
norm = p_aux1

Np_aux1 = [ a/b for a, b in zip(p_aux1,norm)]
Np_aux1_up = [ a/b for a, b in zip(p_aux1_up,norm)]
Np_aux1_down = [ a/b for a, b in zip(p_aux1_down,norm)]

Np_aux2 = [ a/b for a, b in zip(p_aux2,norm)]
Np_aux2_up = [ a/b for a, b in zip(p_aux2_up,norm)]
Np_aux2_down = [ a/b for a, b in zip(p_aux2_down,norm)]


Np_XE_up = [ a/b for a, b in zip(f_XE_up(mDM_mDM),norm)]
Np_XE_down = [ a/b for a, b in zip(f_XE_down(mDM_mDM),norm)]





axs[1].plot(mDM_mDM, Np_aux1, '-', color=c1, lw=3, label=l1)
axs[1].plot(mDM_mDM, Np_aux1_up, ':', color=c1, lw=lw)
axs[1].plot(mDM_mDM, Np_aux1_down, ':', color=c1, lw=lw)

axs[1].plot(mDM_mDM, Np_aux2, '-', color=c2, lw=3, label=l2)
axs[1].plot(mDM_mDM, Np_aux2_up, ':', color=c2, lw=lw)
axs[1].plot(mDM_mDM, Np_aux2_down, ':', color=c2, lw=lw)



axs[1].fill(
    np.append(mDM_mDM, mDM_mDM[::-1]),
    np.append(Np_XE_up, Np_XE_down[::-1]), color = 'gray', edgecolor=None, alpha=0.3,
    label='XENON1T, 1 ton.yr (1$\sigma$ band)'
)


axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[1].set_xscale('log')
# axs[1].set_yscale('log')

axs[0].set_xlim([10, 500])
axs[0].set_ylim([1e-47, 2e-44])
axs[1].set_xlim([10, 500])
axs[1].set_ylim([0,2])
axs[0].set_ylabel(r'$\sigma^{SI}_{dm-\mathcal{N}}$ [cm$^2$]', fontsize=14)
axs[1].set_xlabel(r'$m_{dm}$ [GeV]', fontsize=14)
axs[1].set_ylabel(r'Normalized', fontsize=14)

axs[0].yaxis.set_tick_params(labelsize=14)
axs[0].xaxis.set_tick_params(labelsize=14)
axs[0].xaxis.set_ticklabels([])
# axs[1].yaxis.set_ticks([0, 1, 2])
axs[1].xaxis.set_tick_params(labelsize=14)
axs[1].yaxis.set_tick_params(labelsize=14)

axs[0].grid()
axs[1].grid()

# axs[0].set_title('Unbinned Analysis', fontsize=14)
axs[0].legend(loc="upper right", fontsize=12)
plt.tight_layout()
plt.savefig('limits1B.pdf', format="pdf", bbox_inches="tight")
plt.show()

# %%
# Trained with all mDM

cross_cs1cs2_general_mALL = np.loadtxt('results/general/cs1cs2_mDM_ALL.txt')[0]
cross_cs1cs2_general_mALL_up = np.loadtxt('results/general/cs1cs2_mDM_ALL.txt')[1]
cross_cs1cs2_general_mALL_down =np.loadtxt('results/general/cs1cs2_mDM_ALL.txt')[2]

cross_cs1cs2_general_mALL_MLL = np.loadtxt('results/general/cs1cs2_mDM_ALL_MLL.txt')[0]
cross_cs1cs2_general_mALL_MLL_up = np.loadtxt('results/general/cs1cs2_mDM_ALL_MLL.txt')[1]
cross_cs1cs2_general_mALL_MLL_down = np.loadtxt('results/general/cs1cs2_mDM_ALL_MLL.txt')[2]

# %%
fig, axs = plt.subplots(2,1,figsize=(6,5.7), gridspec_kw={'height_ratios': [3, 1]})

lw = 2

# things to plots
p_aux1 = cross_cs1cs2
p_aux1_up = cross_cs1cs2_up
p_aux1_down = cross_cs1cs2_down
c1 = 'coral'
l1 = r'cS1, cS2 - Binned - $m_{DM}$ dependent'

p_aux8 = cross_cs1cs2_general_mALL
p_aux8_up = cross_cs1cs2_general_mALL_up
p_aux8_down = cross_cs1cs2_general_mALL_down
c8 = 'red'
l8 = r'cS1, cS2 - Binned - $m_{DM}$ independent'

p_aux2 = cross_cs1cs2_MLL
p_aux2_up = cross_cs1cs2_MLL_up
p_aux2_down = cross_cs1cs2_MLL_down
c2 = 'darkviolet'
l2 = r'cS1, cS2 - Unbinned - $m_{DM}$ dependent'

p_aux9 = cross_cs1cs2_general_mALL_MLL
p_aux9_up = cross_cs1cs2_general_mALL_MLL_up
p_aux9_down = cross_cs1cs2_general_mALL_MLL_down
c9 = 'blue'
l9 = r'cS1, cS2 - Unbinned - $m_{DM}$ independent'


axs[0].plot(mDM_mDM, p_aux1, '-', color=c1, lw=3, label=l1)
axs[0].plot(mDM_mDM, p_aux1_up, ':', color=c1, lw=lw)
axs[0].plot(mDM_mDM, p_aux1_down, ':', color=c1, lw=lw)

axs[0].plot(mDM_mDM, p_aux8, '--', color=c8, lw=3, label=l8)
axs[0].plot(mDM_mDM, p_aux8_up, ':', color=c8, lw=lw)
axs[0].plot(mDM_mDM, p_aux8_down, ':', color=c8, lw=lw)

axs[0].plot(mDM_mDM, p_aux2, '-', color=c2, lw=3, label=l2)
axs[0].plot(mDM_mDM, p_aux2_up, ':', color=c2, lw=lw)
axs[0].plot(mDM_mDM, p_aux2_down, ':', color=c2, lw=lw)

axs[0].plot(mDM_mDM, p_aux9, '--', color=c9, lw=3, label=l9)
axs[0].plot(mDM_mDM, p_aux9_up, ':', color=c9, lw=lw)
axs[0].plot(mDM_mDM, p_aux9_down, ':', color=c9, lw=lw)


axs[0].fill(
    np.append(x_XENON1T_1tonyr_up, x_XENON1T_1tonyr_down[::-1]),
    np.append(y_XENON1T_1tonyr_up, y_XENON1T_1tonyr_down[::-1]), color = 'gray', edgecolor=None, alpha=0.3,
    label='XENON1T, 1 ton.yr (1$\sigma$ band)'
)


# Normalize
norm = p_aux1

Np_aux1 = [ a/b for a, b in zip(p_aux1,norm)]
Np_aux1_up = [ a/b for a, b in zip(p_aux1_up,norm)]
Np_aux1_down = [ a/b for a, b in zip(p_aux1_down,norm)]

Np_aux2 = [ a/b for a, b in zip(p_aux2,norm)]
Np_aux2_up = [ a/b for a, b in zip(p_aux2_up,norm)]
Np_aux2_down = [ a/b for a, b in zip(p_aux2_down,norm)]

Np_aux8 = [ a/b for a, b in zip(p_aux8,norm)]
Np_aux8_up = [ a/b for a, b in zip(p_aux8_up,norm)]
Np_aux8_down = [ a/b for a, b in zip(p_aux8_down,norm)]

Np_aux9 = [ a/b for a, b in zip(p_aux9,norm)]
Np_aux9_up = [ a/b for a, b in zip(p_aux9_up,norm)]
Np_aux9_down = [ a/b for a, b in zip(p_aux9_down,norm)]


Np_XE_up = [ a/b for a, b in zip(f_XE_up(mDM_mDM),norm)]
Np_XE_down = [ a/b for a, b in zip(f_XE_down(mDM_mDM),norm)]





axs[1].plot(mDM_mDM, Np_aux1, '-', color=c1, lw=3, label=l1)
axs[1].plot(mDM_mDM, Np_aux1_up, ':', color=c1, lw=lw)
axs[1].plot(mDM_mDM, Np_aux1_down, ':', color=c1, lw=lw)

axs[1].plot(mDM_mDM, Np_aux8, '--', color=c8, lw=3, label=l8)
axs[1].plot(mDM_mDM, Np_aux8_up, ':', color=c8, lw=lw)
axs[1].plot(mDM_mDM, Np_aux8_down, ':', color=c8, lw=lw)

axs[1].plot(mDM_mDM, Np_aux2, '-', color=c2, lw=3, label=l2)
axs[1].plot(mDM_mDM, Np_aux2_up, ':', color=c2, lw=lw)
axs[1].plot(mDM_mDM, Np_aux2_down, ':', color=c2, lw=lw)

axs[1].plot(mDM_mDM, Np_aux9, '--', color=c9, lw=3, label=l9)
axs[1].plot(mDM_mDM, Np_aux9_up, ':', color=c9, lw=lw)
axs[1].plot(mDM_mDM, Np_aux9_down, ':', color=c9, lw=lw)



axs[1].fill(
    np.append(mDM_mDM, mDM_mDM[::-1]),
    np.append(Np_XE_up, Np_XE_down[::-1]), color = 'gray', edgecolor=None, alpha=0.3,
    label='XENON1T, 1 ton.yr (1$\sigma$ band)'
)


axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[1].set_xscale('log')
# axs[1].set_yscale('log')

axs[0].set_xlim([10, 500])
axs[0].set_ylim([1e-47, 2e-44])
axs[1].set_xlim([10, 500])
axs[1].set_ylim([0,2])
axs[0].set_ylabel(r'$\sigma^{SI}_{dm-\mathcal{N}}$ [cm$^2$]', fontsize=14)
axs[1].set_xlabel(r'$m_{dm}$ [GeV]', fontsize=14)
axs[1].set_ylabel(r'Normalized', fontsize=14)

axs[0].yaxis.set_tick_params(labelsize=14)
axs[0].xaxis.set_tick_params(labelsize=14)
axs[0].xaxis.set_ticklabels([])
# axs[1].yaxis.set_ticks([0, 1, 2])
axs[1].xaxis.set_tick_params(labelsize=14)
axs[1].yaxis.set_tick_params(labelsize=14)

axs[0].grid()
axs[1].grid()

# axs[0].set_title('Binned Analysis', fontsize=14)
axs[0].legend(loc="upper right", fontsize=12)
plt.tight_layout()
# plt.savefig('limits4A.pdf', format="pdf", bbox_inches="tight")
plt.show()

# %%
fig, axs = plt.subplots(2,1,figsize=(6,5.7), gridspec_kw={'height_ratios': [3, 1]})

lw = 2

# things to plots
p_aux1 = cross_cs1cs2
p_aux1_up = cross_cs1cs2_up
p_aux1_down = cross_cs1cs2_down
c1 = 'coral'
l1 = r'cS1, cS2 - $m_{DM}$ dependent'

p_aux8 = cross_cs1cs2_general_mALL
p_aux8_up = cross_cs1cs2_general_mALL_up
p_aux8_down = cross_cs1cs2_general_mALL_down
c8 = 'red'
l8 = r'cS1, cS2 - $m_{DM}$ independent'

p_aux2 = cross_cs1cs2_MLL
p_aux2_up = cross_cs1cs2_MLL_up
p_aux2_down = cross_cs1cs2_MLL_down
c2 = 'darkviolet'
l2 = r'cS1, cS2 - $m_{DM}$ dependent'

p_aux9 = cross_cs1cs2_general_mALL_MLL
p_aux9_up = cross_cs1cs2_general_mALL_MLL_up
p_aux9_down = cross_cs1cs2_general_mALL_MLL_down
c9 = 'blue'
l9 = r'cS1, cS2 - $m_{DM}$ independent'


axs[0].plot(mDM_mDM, p_aux1, '-', color=c1, lw=3, label=l1)
axs[0].plot(mDM_mDM, p_aux1_up, ':', color=c1, lw=lw)
axs[0].plot(mDM_mDM, p_aux1_down, ':', color=c1, lw=lw)

axs[0].plot(mDM_mDM, p_aux8, '--', color=c8, lw=3, label=l8)
axs[0].plot(mDM_mDM, p_aux8_up, ':', color=c8, lw=lw)
axs[0].plot(mDM_mDM, p_aux8_down, ':', color=c8, lw=lw)

# axs[0].plot(mDM_mDM, p_aux2, '-', color=c2, lw=3, label=l2)
# axs[0].plot(mDM_mDM, p_aux2_up, ':', color=c2, lw=lw)
# axs[0].plot(mDM_mDM, p_aux2_down, ':', color=c2, lw=lw)

# axs[0].plot(mDM_mDM, p_aux9, '--', color=c9, lw=3, label=l9)
# axs[0].plot(mDM_mDM, p_aux9_up, ':', color=c9, lw=lw)
# axs[0].plot(mDM_mDM, p_aux9_down, ':', color=c9, lw=lw)


axs[0].fill(
    np.append(x_XENON1T_1tonyr_up, x_XENON1T_1tonyr_down[::-1]),
    np.append(y_XENON1T_1tonyr_up, y_XENON1T_1tonyr_down[::-1]), color = 'gray', edgecolor=None, alpha=0.3,
    label='XENON1T, 1 ton.yr (1$\sigma$ band)'
)


# Normalize
norm = p_aux1

Np_aux1 = [ a/b for a, b in zip(p_aux1,norm)]
Np_aux1_up = [ a/b for a, b in zip(p_aux1_up,norm)]
Np_aux1_down = [ a/b for a, b in zip(p_aux1_down,norm)]

Np_aux2 = [ a/b for a, b in zip(p_aux2,norm)]
Np_aux2_up = [ a/b for a, b in zip(p_aux2_up,norm)]
Np_aux2_down = [ a/b for a, b in zip(p_aux2_down,norm)]

Np_aux8 = [ a/b for a, b in zip(p_aux8,norm)]
Np_aux8_up = [ a/b for a, b in zip(p_aux8_up,norm)]
Np_aux8_down = [ a/b for a, b in zip(p_aux8_down,norm)]

Np_aux9 = [ a/b for a, b in zip(p_aux9,norm)]
Np_aux9_up = [ a/b for a, b in zip(p_aux9_up,norm)]
Np_aux9_down = [ a/b for a, b in zip(p_aux9_down,norm)]


Np_XE_up = [ a/b for a, b in zip(f_XE_up(mDM_mDM),norm)]
Np_XE_down = [ a/b for a, b in zip(f_XE_down(mDM_mDM),norm)]





axs[1].plot(mDM_mDM, Np_aux1, '-', color=c1, lw=3, label=l1)
axs[1].plot(mDM_mDM, Np_aux1_up, ':', color=c1, lw=lw)
axs[1].plot(mDM_mDM, Np_aux1_down, ':', color=c1, lw=lw)

axs[1].plot(mDM_mDM, Np_aux8, '--', color=c8, lw=3, label=l8)
axs[1].plot(mDM_mDM, Np_aux8_up, ':', color=c8, lw=lw)
axs[1].plot(mDM_mDM, Np_aux8_down, ':', color=c8, lw=lw)

# axs[1].plot(mDM_mDM, Np_aux2, '-', color=c2, lw=3, label=l2)
# axs[1].plot(mDM_mDM, Np_aux2_up, ':', color=c2, lw=lw)
# axs[1].plot(mDM_mDM, Np_aux2_down, ':', color=c2, lw=lw)

# axs[1].plot(mDM_mDM, Np_aux9, '--', color=c9, lw=3, label=l9)
# axs[1].plot(mDM_mDM, Np_aux9_up, ':', color=c9, lw=lw)
# axs[1].plot(mDM_mDM, Np_aux9_down, ':', color=c9, lw=lw)



axs[1].fill(
    np.append(mDM_mDM, mDM_mDM[::-1]),
    np.append(Np_XE_up, Np_XE_down[::-1]), color = 'gray', edgecolor=None, alpha=0.3,
    label='XENON1T, 1 ton.yr (1$\sigma$ band)'
)


axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[1].set_xscale('log')
# axs[1].set_yscale('log')

axs[0].set_xlim([10, 500])
axs[0].set_ylim([1e-47, 1e-44])
axs[1].set_xlim([10, 500])
axs[1].set_ylim([0,2])
axs[0].set_ylabel(r'$\sigma^{SI}_{dm-\mathcal{N}}$ [cm$^2$]', fontsize=14)
axs[1].set_xlabel(r'$m_{dm}$ [GeV]', fontsize=14)
axs[1].set_ylabel(r'Normalized', fontsize=14)

axs[0].yaxis.set_tick_params(labelsize=14)
axs[0].xaxis.set_tick_params(labelsize=14)
axs[0].xaxis.set_ticklabels([])
# axs[1].yaxis.set_ticks([0, 1, 2])
axs[1].xaxis.set_tick_params(labelsize=14)
axs[1].yaxis.set_tick_params(labelsize=14)

axs[0].grid()
axs[1].grid()

axs[0].set_title('Binned Analysis', fontsize=14)
axs[0].legend(loc="upper right", fontsize=12)
plt.tight_layout()
plt.savefig('limits4A.pdf', format="pdf", bbox_inches="tight")
plt.show()

# %%
fig, axs = plt.subplots(2,1,figsize=(6,5.7), gridspec_kw={'height_ratios': [3, 1]})

lw = 2

# things to plots
p_aux1 = cross_cs1cs2
p_aux1_up = cross_cs1cs2_up
p_aux1_down = cross_cs1cs2_down
c1 = 'coral'
l1 = r'cS1, cS2 - $m_{DM}$ dependent'

p_aux8 = cross_cs1cs2_general_mALL
p_aux8_up = cross_cs1cs2_general_mALL_up
p_aux8_down = cross_cs1cs2_general_mALL_down
c8 = 'red'
l8 = r'cS1, cS2 - $m_{DM}$ independent'

p_aux2 = cross_cs1cs2_MLL
p_aux2_up = cross_cs1cs2_MLL_up
p_aux2_down = cross_cs1cs2_MLL_down
c2 = 'darkviolet'
l2 = r'cS1, cS2 - $m_{DM}$ dependent'

p_aux9 = cross_cs1cs2_general_mALL_MLL
p_aux9_up = cross_cs1cs2_general_mALL_MLL_up
p_aux9_down = cross_cs1cs2_general_mALL_MLL_down
c9 = 'blue'
l9 = r'cS1, cS2 - $m_{DM}$ independent'


# axs[0].plot(mDM_mDM, p_aux1, '-', color=c1, lw=3, label=l1)
# axs[0].plot(mDM_mDM, p_aux1_up, ':', color=c1, lw=lw)
# axs[0].plot(mDM_mDM, p_aux1_down, ':', color=c1, lw=lw)

# axs[0].plot(mDM_mDM, p_aux8, '--', color=c8, lw=3, label=l8)
# axs[0].plot(mDM_mDM, p_aux8_up, ':', color=c8, lw=lw)
# axs[0].plot(mDM_mDM, p_aux8_down, ':', color=c8, lw=lw)

axs[0].plot(mDM_mDM, p_aux2, '-', color=c2, lw=3, label=l2)
axs[0].plot(mDM_mDM, p_aux2_up, ':', color=c2, lw=lw)
axs[0].plot(mDM_mDM, p_aux2_down, ':', color=c2, lw=lw)

axs[0].plot(mDM_mDM, p_aux9, '--', color=c9, lw=3, label=l9)
axs[0].plot(mDM_mDM, p_aux9_up, ':', color=c9, lw=lw)
axs[0].plot(mDM_mDM, p_aux9_down, ':', color=c9, lw=lw)


axs[0].fill(
    np.append(x_XENON1T_1tonyr_up, x_XENON1T_1tonyr_down[::-1]),
    np.append(y_XENON1T_1tonyr_up, y_XENON1T_1tonyr_down[::-1]), color = 'gray', edgecolor=None, alpha=0.3,
    label='XENON1T, 1 ton.yr (1$\sigma$ band)'
)


# Normalize
norm = p_aux2

Np_aux1 = [ a/b for a, b in zip(p_aux1,norm)]
Np_aux1_up = [ a/b for a, b in zip(p_aux1_up,norm)]
Np_aux1_down = [ a/b for a, b in zip(p_aux1_down,norm)]

Np_aux2 = [ a/b for a, b in zip(p_aux2,norm)]
Np_aux2_up = [ a/b for a, b in zip(p_aux2_up,norm)]
Np_aux2_down = [ a/b for a, b in zip(p_aux2_down,norm)]

Np_aux8 = [ a/b for a, b in zip(p_aux8,norm)]
Np_aux8_up = [ a/b for a, b in zip(p_aux8_up,norm)]
Np_aux8_down = [ a/b for a, b in zip(p_aux8_down,norm)]

Np_aux9 = [ a/b for a, b in zip(p_aux9,norm)]
Np_aux9_up = [ a/b for a, b in zip(p_aux9_up,norm)]
Np_aux9_down = [ a/b for a, b in zip(p_aux9_down,norm)]


Np_XE_up = [ a/b for a, b in zip(f_XE_up(mDM_mDM),norm)]
Np_XE_down = [ a/b for a, b in zip(f_XE_down(mDM_mDM),norm)]





# axs[1].plot(mDM_mDM, Np_aux1, '-', color=c1, lw=3, label=l1)
# axs[1].plot(mDM_mDM, Np_aux1_up, ':', color=c1, lw=lw)
# axs[1].plot(mDM_mDM, Np_aux1_down, ':', color=c1, lw=lw)

# axs[1].plot(mDM_mDM, Np_aux8, '--', color=c8, lw=3, label=l8)
# axs[1].plot(mDM_mDM, Np_aux8_up, ':', color=c8, lw=lw)
# axs[1].plot(mDM_mDM, Np_aux8_down, ':', color=c8, lw=lw)

axs[1].plot(mDM_mDM, Np_aux2, '-', color=c2, lw=3, label=l2)
axs[1].plot(mDM_mDM, Np_aux2_up, ':', color=c2, lw=lw)
axs[1].plot(mDM_mDM, Np_aux2_down, ':', color=c2, lw=lw)

axs[1].plot(mDM_mDM, Np_aux9, '--', color=c9, lw=3, label=l9)
axs[1].plot(mDM_mDM, Np_aux9_up, ':', color=c9, lw=lw)
axs[1].plot(mDM_mDM, Np_aux9_down, ':', color=c9, lw=lw)



axs[1].fill(
    np.append(mDM_mDM, mDM_mDM[::-1]),
    np.append(Np_XE_up, Np_XE_down[::-1]), color = 'gray', edgecolor=None, alpha=0.3,
    label='XENON1T, 1 ton.yr (1$\sigma$ band)'
)


axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[1].set_xscale('log')
# axs[1].set_yscale('log')

axs[0].set_xlim([10, 500])
axs[0].set_ylim([1e-47, 1e-44])
axs[1].set_xlim([10, 500])
axs[1].set_ylim([0,3])
axs[0].set_ylabel(r'$\sigma^{SI}_{dm-\mathcal{N}}$ [cm$^2$]', fontsize=14)
axs[1].set_xlabel(r'$m_{dm}$ [GeV]', fontsize=14)
axs[1].set_ylabel(r'Normalized', fontsize=14)

axs[0].yaxis.set_tick_params(labelsize=14)
axs[0].xaxis.set_tick_params(labelsize=14)
axs[0].xaxis.set_ticklabels([])
axs[1].yaxis.set_ticks([0, 1, 2, 3])
axs[1].xaxis.set_tick_params(labelsize=14)
axs[1].yaxis.set_tick_params(labelsize=14)

axs[0].grid()
axs[1].grid()

axs[0].set_title('Unbinned Analysis', fontsize=14)
axs[0].legend(loc="upper right", fontsize=12)
plt.tight_layout()
plt.savefig('limits4B.pdf', format="pdf", bbox_inches="tight")
plt.show()
